# %%
import os
import matplotlib.pyplot as plt
import random
import numpy as np
import numpy
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.datasets import cifar10
from keras.layers import Add, Dense, Activation, BatchNormalization, Conv2D
from keras.layers import Flatten
from keras.layers.convolutional import MaxPooling2D
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import tensorflow_datasets as tfds
import tensorflow as tf
from keras.utils import np_utils
from keras.initializers import glorot_uniform
# %matplotlib inline

# %%
model_type = 'vgg16'

# %%
model_home_dir = os.path.join(os.getcwd(), 'CNN_TASK_ODED',"model_type")
print(model_home_dir)
if not os.path.isdir(model_home_dir):
    print('Inside mkdir')
    os.makedirs(model_home_dir)
# Out:
# /content/CNN_TASK_ODED/model_type

# %%
#Defining Variables

#Data set information
DATASET = 'tfds.image_classification.Malaria'
num_classes = 2
input_shape=(32,32,3)
epochs = 200
lrate = 0.01
decay = lrate/epochs
batch_size = 32
seed = 7
np.random.seed(seed)

validate_dir = os.path.join("data","test")
train_dir = os.path.join("data","train")

# Prepare model model saving directory.
save_dir = os.path.join(model_home_dir, 'saved_models')

model_name = DATASET+'_'+'%s_model.{epoch:03d}.h5' % model_type

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print("Model Type: ",model_type)
print("Model File: ",filepath)
# Out:
# Model Type:  vgg16
# Model File:  /content/CNN_TASK_ODED/model_type/saved_models/tfds.image_classification.Malaria_vgg16_model.{epoch:03d}.h5

# %%
def preprocess(img, label):
    return tf.image.resize(img, [HEIGHT, WIDTH]) / 255, label

HEIGHT = 32
WIDTH = 32
split = ['train[:85%]', 'train[85%:]']


trainDataset, testDataset = tfds.load('Malaria',
                         split = split,
                         batch_size=1, 
                         as_supervised=True)



trainDataset = trainDataset.map(preprocess)
testDataset = testDataset.map(preprocess)

train = list(tfds.as_numpy(trainDataset))
test = list(tfds.as_numpy(testDataset))

X_train = [e[0][0].astype('float32') for e in train]
X_test = [e[0][0].astype('float32') for e in test]

X_train = numpy.stack(X_train)
X_test = numpy.stack(X_test)

y_train = [e[1][0] for e in train]
y_test = [e[1][0] for e in test]

y_train = numpy.stack(y_train).reshape((-1,1)) 
y_test = numpy.stack(y_test).reshape((-1,1)) 

print(y_train.shape, y_test.shape)
print(X_train.shape, X_test.shape)
# Out:
# (23424, 1) (4134, 1)
# (23424, 32, 32, 3) (4134, 32, 32, 3)

# %%
class_names = ['parasitized', 'uninfected']

print("------------------concatenate train-------------------")
plt.figure(figsize=(10,10))
for i in range(25):
    j = random.randint(0,19773)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[j])
    plt.xlabel(class_names[y_train[j][0]])
plt.show()

print("------------------concatenate test-------------------")
plt.figure(figsize=(10,10))
for i in range(25):
    j = random.randint(0,3489) 
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_test[j])
    plt.xlabel(class_names[y_test[j][0]])
plt.show()
# Out:
# ------------------concatenate train-------------------
# ------------------concatenate test-------------------

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train_mean = np.mean(X_train)
X_train -= X_train_mean
X_test_mean = np.mean(X_test)
X_test -= X_test_mean

y_train = np_utils.to_categorical(y_train,)
y_test = np_utils.to_categorical(y_test,)
y_train = np.delete(y_train,1,1)
y_test = np.delete(y_test,1,1)
print(y_train.shape, y_test.shape)
# Out:
# (23424, 1) (4134, 1)

# %%
from tensorflow.keras.layers import Dropout
def vgg16(input_shape=(32,32,3), num_classes=2):
  model = Sequential()
  model.add(Conv2D(input_shape=input_shape,filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))


  model.add(Dropout(0.8))

  model.add(Conv2D(filters=16, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=16, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  # model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  # model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Flatten())
  model.add(Dense(units=4096,activation="relu"))
  model.add(Dense(units=4096,activation="relu"))
  model.add(Dense(units=1, activation="sigmoid"))

  return model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
# Prepare callbacks for model saving and for learning rate adjustment.

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler,early_stopping]

# %%
 model = vgg16(input_shape,num_classes)

# Compile model

# optimizer = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss= 'binary_crossentropy' , optimizer=optimizer, metrics=['accuracy'])
print("Model Summary of ",model_type)
print(model.summary())
# Out:
# Model Summary of  vgg16
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 32, 32, 64)        1792
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 16)        9232
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 16)        2320
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 4096)              4198400
#
#  dense_7 (Dense)             (None, 4096)              16781312
#
#  dense_8 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 21,034,081
# Trainable params: 21,034,081
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Score trained model.
history = model.fit(X_train, y_train,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=(X_test, y_test),
      shuffle=True,
      callbacks=callbacks)
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Learning rate:  0.001
# Epoch 1/200
# 731/732 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.8484
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 732/732 [==============================] - 9s 11ms/step - loss: 0.3293 - accuracy: 0.8486 - val_loss: 0.2340 - val_accuracy: 0.9315 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/200
# 728/732 [============================>.] - ETA: 0s - loss: 0.1573 - accuracy: 0.9526
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 732/732 [==============================] - 8s 10ms/step - loss: 0.1570 - accuracy: 0.9527 - val_loss: 0.1769 - val_accuracy: 0.9526 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/200
# 727/732 [============================>.] - ETA: 0s - loss: 0.1483 - accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 732/732 [==============================] - 7s 10ms/step - loss: 0.1484 - accuracy: 0.9530 - val_loss: 0.2107 - val_accuracy: 0.9519 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 727/732 [============================>.] - ETA: 0s - loss: 0.1453 - accuracy: 0.9556
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 732/732 [==============================] - 8s 10ms/step - loss: 0.1451 - accuracy: 0.9556 - val_loss: 0.2758 - val_accuracy: 0.9286 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 732/732 [==============================] - ETA: 0s - loss: 0.1417 - accuracy: 0.9556
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 732/732 [==============================] - 8s 10ms/step - loss: 0.1417 - accuracy: 0.9556 - val_loss: 0.2290 - val_accuracy: 0.9400 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 730/732 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9554
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 732/732 [==============================] - 7s 10ms/step - loss: 0.1436 - accuracy: 0.9554 - val_loss: 0.1897 - val_accuracy: 0.9497 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 730/732 [============================>.] - ETA: 0s - loss: 0.1367 - accuracy: 0.9568
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 732/732 [==============================] - 8s 10ms/step - loss: 0.1366 - accuracy: 0.9568 - val_loss: 0.2451 - val_accuracy: 0.9369 - lr: 3.1623e-04
# 130/130 [==============================] - 1s 4ms/step - loss: 0.1769 - accuracy: 0.9526
# Test loss: 0.17692434787750244
# Test accuracy: 0.9525883197784424

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
from sklearn.metrics import roc_curve, auc

y_pred = model.predict(X_test).ravel()

nn_fpr_keras, nn_tpr_keras, nn_thresholds_keras = roc_curve(y_test, y_pred)
auc_keras = auc(nn_fpr_keras, nn_tpr_keras)
plt.plot(nn_fpr_keras, nn_tpr_keras, marker='.', label='Neural Network (auc = %0.3f)' % auc_keras)
plt.title('ROC Curve')
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.show()

print(auc_keras)
# Out:
# 130/130 [==============================] - 0s 3ms/step
# 0.9803369655590845

# %%
from matplotlib import pyplot
predict_x=model.predict(X_test) 

parasitized_index = np.where(y_test.reshape(-1) == 0.)
parasitized = predict_x[parasitized_index]

uninfected_index = np.where(y_test.reshape(-1) == 1.)
uninfected = predict_x[uninfected_index]



bins = np.linspace(0, 1, 100)

pyplot.hist(parasitized, bins, alpha=0.5, label='parasitized')
pyplot.hist(uninfected, bins, alpha=0.5, label='uninfected')
pyplot.legend(loc='upper right')
pyplot.show()
# Out:
# 130/130 [==============================] - 0s 3ms/step

# %%
for X,Y in zip(predict_x,y_test):
    print("Model Score:", X, "actual score:", Y)
# Out:
# Model Score: [0.03687133] actual score: [0.]
# Model Score: [0.8883613] actual score: [1.]
# Model Score: [0.98268986] actual score: [1.]
# Model Score: [0.9424425] actual score: [1.]
# Model Score: [0.9203325] actual score: [1.]
# Model Score: [0.03561471] actual score: [0.]
# Model Score: [0.72690845] actual score: [1.]
# Model Score: [0.03605062] actual score: [0.]
# Model Score: [0.90592813] actual score: [1.]
# Model Score: [0.0401281] actual score: [1.]
# Model Score: [0.9809935] actual score: [1.]
# Model Score: [0.9335951] actual score: [1.]
# Model Score: [0.7384087] actual score: [1.]
# Model Score: [0.9993062] actual score: [1.]
# Model Score: [0.03613883] actual score: [0.]
# Model Score: [0.0354935] actual score: [0.]
# Model Score: [0.21267559] actual score: [0.]
# Model Score: [0.7529929] actual score: [1.]
# Model Score: [0.98217785] actual score: [1.]
# Model Score: [0.19027136] actual score: [0.]
# Model Score: [0.0375521] actual score: [0.]
# Model Score: [0.98421186] actual score: [1.]
# Model Score: [0.93442124] actual score: [1.]
# Model Score: [0.91251814] actual score: [1.]
# Model Score: [0.9877843] actual score: [1.]
# Model Score: [0.98005325] actual score: [1.]
# Model Score: [0.6309878] actual score: [1.]
# Model Score: [0.03823676] actual score: [0.]
# Model Score: [0.99152] actual score: [1.]
# Model Score: [0.97306687] actual score: [1.]
# Model Score: [0.07189104] actual score: [1.]
# Model Score: [0.8781457] actual score: [1.]
# Model Score: [0.70959616] actual score: [1.]
# Model Score: [0.03870042] actual score: [0.]
# Model Score: [0.94865745] actual score: [1.]
# Model Score: [0.7576364] actual score: [1.]
# Model Score: [0.90819585] actual score: [1.]
# Model Score: [0.03980898] actual score: [0.]
# Model Score: [0.994303] actual score: [1.]
# Model Score: [0.81975365] actual score: [1.]
# Model Score: [0.03689661] actual score: [1.]
# Model Score: [0.7838184] actual score: [1.]
# Model Score: [0.9727305] actual score: [1.]
# Model Score: [0.8465197] actual score: [1.]
# Model Score: [0.88483787] actual score: [1.]
# Model Score: [0.8229776] actual score: [1.]
# Model Score: [0.03705209] actual score: [0.]
# Model Score: [0.03681878] actual score: [0.]
# Model Score: [0.03963744] actual score: [0.]
# Model Score: [0.15524748] actual score: [0.]
# Model Score: [0.03725241] actual score: [0.]
# Model Score: [0.8548927] actual score: [1.]
# Model Score: [0.99507207] actual score: [1.]
# Model Score: [0.60341495] actual score: [1.]
# Model Score: [0.03763985] actual score: [0.]
# Model Score: [0.03779497] actual score: [0.]
# Model Score: [0.9809483] actual score: [1.]
# Model Score: [0.0368456] actual score: [0.]
# Model Score: [0.6042957] actual score: [1.]
# Model Score: [0.9779384] actual score: [1.]
# Model Score: [0.9855774] actual score: [1.]
# Model Score: [0.03601279] actual score: [0.]
# Model Score: [0.05414178] actual score: [0.]
# Model Score: [0.03551865] actual score: [0.]
# Model Score: [0.8991763] actual score: [1.]
# Model Score: [0.86455274] actual score: [1.]
# Model Score: [0.03592202] actual score: [0.]
# Model Score: [0.89193296] actual score: [1.]
# Model Score: [0.03934824] actual score: [0.]
# Model Score: [0.03685999] actual score: [0.]
# Model Score: [0.03715934] actual score: [0.]
# Model Score: [0.99640214] actual score: [1.]
# Model Score: [0.17127307] actual score: [0.]
# Model Score: [0.9425325] actual score: [1.]
# Model Score: [0.77709675] actual score: [1.]
# Model Score: [0.9255479] actual score: [1.]
# Model Score: [0.03882757] actual score: [0.]
# Model Score: [0.7443869] actual score: [1.]
# Model Score: [0.9792722] actual score: [1.]
# Model Score: [0.9517536] actual score: [1.]
# Model Score: [0.9963413] actual score: [1.]
# Model Score: [0.9555689] actual score: [1.]
# Model Score: [0.99177504] actual score: [1.]
# Model Score: [0.03733334] actual score: [0.]
# Model Score: [0.03782682] actual score: [0.]
# Model Score: [0.9303538] actual score: [1.]
# Model Score: [0.03809218] actual score: [0.]
# Model Score: [0.14564325] actual score: [0.]
# Model Score: [0.03732663] actual score: [0.]
# Model Score: [0.03630774] actual score: [0.]
# Model Score: [0.04138961] actual score: [0.]
# Model Score: [0.05227537] actual score: [0.]
# Model Score: [0.03920346] actual score: [1.]
# Model Score: [0.03754008] actual score: [0.]
# Model Score: [0.9571773] actual score: [1.]
# Model Score: [0.9909161] actual score: [1.]
# Model Score: [0.95882297] actual score: [1.]
# Model Score: [0.03817176] actual score: [0.]
# Model Score: [0.9793602] actual score: [1.]
# Model Score: [0.03837069] actual score: [0.]
# Model Score: [0.18808633] actual score: [0.]
# Model Score: [0.9579725] actual score: [1.]
# Model Score: [0.04503202] actual score: [0.]
# Model Score: [0.0388358] actual score: [0.]
# Model Score: [0.03613584] actual score: [0.]
# Model Score: [0.8290406] actual score: [1.]
# Model Score: [0.05693837] actual score: [0.]
# Model Score: [0.03569707] actual score: [0.]
# Model Score: [0.03534706] actual score: [0.]
# Model Score: [0.80654246] actual score: [1.]
# Model Score: [0.977271] actual score: [1.]
# Model Score: [0.03480046] actual score: [0.]
# Model Score: [0.03669548] actual score: [0.]
# Model Score: [0.66301525] actual score: [1.]
# Model Score: [0.98466706] actual score: [1.]
# Model Score: [0.03624691] actual score: [0.]
# Model Score: [0.6376236] actual score: [1.]
# Model Score: [0.03670286] actual score: [0.]
# Model Score: [0.04216094] actual score: [0.]
# Model Score: [0.77449244] actual score: [1.]
# Model Score: [0.87406653] actual score: [1.]
# Model Score: [0.03665325] actual score: [0.]
# Model Score: [0.16109358] actual score: [0.]
# Model Score: [0.98134226] actual score: [1.]
# Model Score: [0.03703013] actual score: [0.]
# Model Score: [0.03597422] actual score: [0.]
# Model Score: [0.03629285] actual score: [0.]
# Model Score: [0.03735543] actual score: [0.]
# Model Score: [0.9800352] actual score: [1.]
# Model Score: [0.8983113] actual score: [1.]
# Model Score: [0.985288] actual score: [1.]
# Model Score: [0.03664374] actual score: [1.]
# Model Score: [0.10495763] actual score: [0.]
# Model Score: [0.03537276] actual score: [0.]
# Model Score: [0.6252471] actual score: [1.]
# Model Score: [0.5208791] actual score: [1.]
# Model Score: [0.9751824] actual score: [1.]
# Model Score: [0.9453659] actual score: [1.]
# Model Score: [0.91976094] actual score: [1.]
# Model Score: [0.91885465] actual score: [1.]
# Model Score: [0.994163] actual score: [1.]
# Model Score: [0.03669566] actual score: [1.]
# Model Score: [0.8925807] actual score: [1.]
# Model Score: [0.96738505] actual score: [1.]
# Model Score: [0.94471586] actual score: [1.]
# Model Score: [0.99424744] actual score: [1.]
# Model Score: [0.04074811] actual score: [0.]
# Model Score: [0.03766263] actual score: [0.]
# Model Score: [0.12117668] actual score: [0.]
# Model Score: [0.94412786] actual score: [1.]
# Model Score: [0.0349762] actual score: [0.]
# Model Score: [0.98817664] actual score: [1.]
# Model Score: [0.03821139] actual score: [0.]
# Model Score: [0.97087425] actual score: [1.]
# Model Score: [0.85515565] actual score: [1.]
# Model Score: [0.0387852] actual score: [0.]
# Model Score: [0.97107893] actual score: [1.]
# Model Score: [0.03885831] actual score: [0.]
# Model Score: [0.03684662] actual score: [0.]
# Model Score: [0.03786036] actual score: [0.]
# Model Score: [0.91402054] actual score: [1.]
# Model Score: [0.83541864] actual score: [1.]
# Model Score: [0.929439] actual score: [1.]
# Model Score: [0.9787627] actual score: [1.]
# Model Score: [0.213307] actual score: [0.]
# Model Score: [0.60986716] actual score: [1.]
# Model Score: [0.03767729] actual score: [0.]
# Model Score: [0.03580714] actual score: [0.]
# Model Score: [0.9079498] actual score: [1.]
# Model Score: [0.0366536] actual score: [0.]
# Model Score: [0.07323209] actual score: [0.]
# Model Score: [0.936585] actual score: [1.]
# Model Score: [0.0355798] actual score: [0.]
# Model Score: [0.9397712] actual score: [1.]
# Model Score: [0.7502821] actual score: [1.]
# Model Score: [0.90127313] actual score: [1.]
# Model Score: [0.03600673] actual score: [0.]
# Model Score: [0.14522576] actual score: [1.]
# Model Score: [0.97624993] actual score: [1.]
# Model Score: [0.03806278] actual score: [0.]
# Model Score: [0.05132132] actual score: [0.]
# Model Score: [0.03356395] actual score: [0.]
# Model Score: [0.799006] actual score: [1.]
# Model Score: [0.04105242] actual score: [0.]
# Model Score: [0.992687] actual score: [1.]
# Model Score: [0.05566012] actual score: [0.]
# Model Score: [0.06577446] actual score: [0.]
# Model Score: [0.03983497] actual score: [0.]
# Model Score: [0.03794566] actual score: [0.]
# Model Score: [0.03717628] actual score: [0.]
# Model Score: [0.9738912] actual score: [1.]
# Model Score: [0.76070744] actual score: [1.]
# Model Score: [0.03574867] actual score: [0.]
# Model Score: [0.9774405] actual score: [1.]
# Model Score: [0.9275538] actual score: [1.]
# Model Score: [0.03658888] actual score: [0.]
# Model Score: [0.986254] actual score: [1.]
# Model Score: [0.03689443] actual score: [0.]
# Model Score: [0.03744581] actual score: [0.]
# Model Score: [0.0377598] actual score: [0.]
# Model Score: [0.72619146] actual score: [1.]
# Model Score: [0.03747301] actual score: [0.]
# Model Score: [0.03713589] actual score: [0.]
# Model Score: [0.03757356] actual score: [0.]
# Model Score: [0.03762116] actual score: [0.]
# Model Score: [0.0360724] actual score: [0.]
# Model Score: [0.97547066] actual score: [1.]
# Model Score: [0.9897898] actual score: [0.]
# Model Score: [0.0369692] actual score: [0.]
# Model Score: [0.97909456] actual score: [1.]
# Model Score: [0.9717611] actual score: [1.]
# Model Score: [0.0388564] actual score: [0.]
# Model Score: [0.03551596] actual score: [0.]
# Model Score: [0.03986783] actual score: [0.]
# Model Score: [0.03821208] actual score: [0.]
# Model Score: [0.03973677] actual score: [0.]
# Model Score: [0.997072] actual score: [1.]
# Model Score: [0.03589343] actual score: [0.]
# Model Score: [0.03700473] actual score: [0.]
# Model Score: [0.9421764] actual score: [1.]
# Model Score: [0.99158794] actual score: [1.]
# Model Score: [0.03607424] actual score: [1.]
# Model Score: [0.0394527] actual score: [0.]
# Model Score: [0.8961641] actual score: [1.]
# Model Score: [0.987906] actual score: [1.]
# Model Score: [0.81600136] actual score: [1.]
# Model Score: [0.99967587] actual score: [1.]
# Model Score: [0.91557777] actual score: [1.]
# Model Score: [0.14997719] actual score: [1.]
# Model Score: [0.03977097] actual score: [0.]
# Model Score: [0.91363037] actual score: [1.]
# Model Score: [0.89250416] actual score: [1.]
# Model Score: [0.97998583] actual score: [1.]
# Model Score: [0.03512093] actual score: [0.]
# Model Score: [0.03661178] actual score: [0.]
# Model Score: [0.03742234] actual score: [0.]
# Model Score: [0.03919587] actual score: [0.]
# Model Score: [0.9477001] actual score: [1.]
# Model Score: [0.8992371] actual score: [1.]
# Model Score: [0.03805534] actual score: [0.]
# Model Score: [0.99771845] actual score: [1.]
# Model Score: [0.0368004] actual score: [0.]
# Model Score: [0.96335995] actual score: [1.]
# Model Score: [0.03693591] actual score: [0.]
# Model Score: [0.9374818] actual score: [1.]
# Model Score: [0.90912026] actual score: [1.]
# Model Score: [0.0345755] actual score: [0.]
# Model Score: [0.03681765] actual score: [0.]
# Model Score: [0.6678889] actual score: [1.]
# Model Score: [0.03688418] actual score: [0.]
# Model Score: [0.8043038] actual score: [1.]
# Model Score: [0.03739462] actual score: [0.]
# Model Score: [0.9416426] actual score: [1.]
# Model Score: [0.5846756] actual score: [1.]
# Model Score: [0.03743863] actual score: [0.]
# Model Score: [0.726168] actual score: [1.]
# Model Score: [0.6916451] actual score: [1.]
# Model Score: [0.03543623] actual score: [0.]
# Model Score: [0.83565784] actual score: [1.]
# Model Score: [0.03605795] actual score: [0.]
# Model Score: [0.03553443] actual score: [0.]
# Model Score: [0.9610078] actual score: [1.]
# Model Score: [0.9597906] actual score: [1.]
# Model Score: [0.0375287] actual score: [0.]
# Model Score: [0.03684701] actual score: [0.]
# Model Score: [0.0362926] actual score: [0.]
# Model Score: [0.9685023] actual score: [1.]
# Model Score: [0.03690176] actual score: [0.]
# Model Score: [0.99222624] actual score: [1.]
# Model Score: [0.08263524] actual score: [0.]
# Model Score: [0.8337186] actual score: [1.]
# Model Score: [0.9977951] actual score: [1.]
# Model Score: [0.9985732] actual score: [1.]
# Model Score: [0.03662021] actual score: [0.]
# Model Score: [0.03674278] actual score: [0.]
# Model Score: [0.25011978] actual score: [0.]
# Model Score: [0.7233419] actual score: [1.]
# Model Score: [0.03976464] actual score: [0.]
# Model Score: [0.03559473] actual score: [0.]
# Model Score: [0.99058414] actual score: [1.]
# Model Score: [0.6809857] actual score: [1.]
# Model Score: [0.03555967] actual score: [0.]
# Model Score: [0.03841604] actual score: [0.]
# Model Score: [0.98078066] actual score: [1.]
# Model Score: [0.42065817] actual score: [1.]
# Model Score: [0.9981193] actual score: [1.]
# Model Score: [0.98473513] actual score: [1.]
# Model Score: [0.03682722] actual score: [0.]
# Model Score: [0.04031483] actual score: [0.]
# Model Score: [0.9859235] actual score: [1.]
# Model Score: [0.9924779] actual score: [1.]
# Model Score: [0.03836391] actual score: [0.]
# Model Score: [0.8596847] actual score: [1.]
# Model Score: [0.9789355] actual score: [1.]
# Model Score: [0.94185185] actual score: [1.]
# Model Score: [0.9643979] actual score: [1.]
# Model Score: [0.6304903] actual score: [1.]
# Model Score: [0.99352807] actual score: [1.]
# Model Score: [0.03752768] actual score: [0.]
# Model Score: [0.92768484] actual score: [1.]
# Model Score: [0.6565696] actual score: [1.]
# Model Score: [0.95239407] actual score: [1.]
# Model Score: [0.99568707] actual score: [1.]
# Model Score: [0.06778413] actual score: [0.]
# Model Score: [0.03749678] actual score: [0.]
# Model Score: [0.0413512] actual score: [0.]
# Model Score: [0.9741901] actual score: [1.]
# Model Score: [0.03688748] actual score: [0.]
# Model Score: [0.8467476] actual score: [1.]
# Model Score: [0.9942358] actual score: [1.]
# Model Score: [0.9913566] actual score: [1.]
# Model Score: [0.98283064] actual score: [1.]
# Model Score: [0.03644747] actual score: [0.]
# Model Score: [0.03650962] actual score: [0.]
# Model Score: [0.96737623] actual score: [1.]
# Model Score: [0.91802764] actual score: [1.]
# Model Score: [0.99407494] actual score: [1.]
# Model Score: [0.98825234] actual score: [1.]
# Model Score: [0.03913972] actual score: [0.]
# Model Score: [0.88218117] actual score: [1.]
# Model Score: [0.7850933] actual score: [1.]
# Model Score: [0.03735102] actual score: [0.]
# Model Score: [0.8771603] actual score: [1.]
# Model Score: [0.9951822] actual score: [1.]
# Model Score: [0.04053142] actual score: [0.]
# Model Score: [0.09440577] actual score: [0.]
# Model Score: [0.7587349] actual score: [1.]
# Model Score: [0.03745943] actual score: [0.]
# Model Score: [0.9741478] actual score: [1.]
# Model Score: [0.99672264] actual score: [1.]
# Model Score: [0.06326822] actual score: [0.]
# Model Score: [0.03594942] actual score: [0.]
# Model Score: [0.0402042] actual score: [0.]
# Model Score: [0.36632827] actual score: [1.]
# Model Score: [0.03805686] actual score: [0.]
# Model Score: [0.98746186] actual score: [1.]
# Model Score: [0.03625708] actual score: [0.]
# Model Score: [0.05765687] actual score: [0.]
# Model Score: [0.20142882] actual score: [0.]
# Model Score: [0.82917184] actual score: [1.]
# Model Score: [0.03792197] actual score: [0.]
# Model Score: [0.03868945] actual score: [1.]
# Model Score: [0.03684563] actual score: [0.]
# Model Score: [0.03761469] actual score: [0.]
# Model Score: [0.9348181] actual score: [1.]
# Model Score: [0.9959078] actual score: [1.]
# Model Score: [0.04706606] actual score: [0.]
# Model Score: [0.66129893] actual score: [1.]
# Model Score: [0.9844056] actual score: [1.]
# Model Score: [0.9307724] actual score: [1.]
# Model Score: [0.0357894] actual score: [0.]
# Model Score: [0.95821995] actual score: [1.]
# Model Score: [0.6865328] actual score: [1.]
# Model Score: [0.04855801] actual score: [0.]
# Model Score: [0.99353105] actual score: [1.]
# Model Score: [0.98495215] actual score: [1.]
# Model Score: [0.0369247] actual score: [0.]
# Model Score: [0.03623526] actual score: [0.]
# Model Score: [0.03480197] actual score: [0.]
# Model Score: [0.96475804] actual score: [1.]
# Model Score: [0.84703743] actual score: [1.]
# Model Score: [0.9585606] actual score: [1.]
# Model Score: [0.98704267] actual score: [1.]
# Model Score: [0.03610202] actual score: [1.]
# Model Score: [0.97875684] actual score: [1.]
# Model Score: [0.03649781] actual score: [0.]
# Model Score: [0.96323526] actual score: [1.]
# Model Score: [0.3969546] actual score: [0.]
# Model Score: [0.03825532] actual score: [0.]
# Model Score: [0.03721504] actual score: [0.]
# Model Score: [0.04509366] actual score: [1.]
# Model Score: [0.8966072] actual score: [1.]
# Model Score: [0.03672157] actual score: [0.]
# Model Score: [0.03690453] actual score: [0.]
# Model Score: [0.97945297] actual score: [1.]
# Model Score: [0.03702515] actual score: [0.]
# Model Score: [0.99382776] actual score: [1.]
# Model Score: [0.03828022] actual score: [0.]
# Model Score: [0.89206517] actual score: [1.]
# Model Score: [0.03613097] actual score: [0.]
# Model Score: [0.98775244] actual score: [1.]
# Model Score: [0.03726841] actual score: [0.]
# Model Score: [0.61739624] actual score: [1.]
# Model Score: [0.96307737] actual score: [1.]
# Model Score: [0.97761714] actual score: [1.]
# Model Score: [0.90226185] actual score: [1.]
# Model Score: [0.7519388] actual score: [1.]
# Model Score: [0.03697892] actual score: [0.]
# Model Score: [0.9752959] actual score: [1.]
# Model Score: [0.967259] actual score: [1.]
# Model Score: [0.5997046] actual score: [1.]
# Model Score: [0.85978466] actual score: [1.]
# Model Score: [0.9607402] actual score: [1.]
# Model Score: [0.6453212] actual score: [1.]
# Model Score: [0.0427918] actual score: [0.]
# Model Score: [0.9132719] actual score: [1.]
# Model Score: [0.8764377] actual score: [1.]
# Model Score: [0.94495845] actual score: [1.]
# Model Score: [0.03938039] actual score: [0.]
# Model Score: [0.8554856] actual score: [1.]
# Model Score: [0.03827085] actual score: [0.]
# Model Score: [0.0359755] actual score: [0.]
# Model Score: [0.93112236] actual score: [1.]
# Model Score: [0.04405115] actual score: [0.]
# Model Score: [0.03792769] actual score: [0.]
# Model Score: [0.03801773] actual score: [0.]
# Model Score: [0.44794908] actual score: [1.]
# Model Score: [0.16844614] actual score: [0.]
# Model Score: [0.0365365] actual score: [0.]
# Model Score: [0.06168649] actual score: [0.]
# Model Score: [0.9549842] actual score: [1.]
# Model Score: [0.9171944] actual score: [1.]
# Model Score: [0.9997825] actual score: [1.]
# Model Score: [0.8400666] actual score: [1.]
# Model Score: [0.03795839] actual score: [0.]
# Model Score: [0.03614089] actual score: [0.]
# Model Score: [0.03579471] actual score: [0.]
# Model Score: [0.03755401] actual score: [0.]
# Model Score: [0.98839426] actual score: [1.]
# Model Score: [0.03902445] actual score: [0.]
# Model Score: [0.03632415] actual score: [0.]
# Model Score: [0.5341683] actual score: [1.]
# Model Score: [0.040717] actual score: [1.]
# Model Score: [0.03817443] actual score: [0.]
# Model Score: [0.5257867] actual score: [1.]
# Model Score: [0.03781469] actual score: [0.]
# Model Score: [0.99565613] actual score: [1.]
# Model Score: [0.03444359] actual score: [0.]
# Model Score: [0.0373278] actual score: [0.]
# Model Score: [0.05315145] actual score: [0.]
# Model Score: [0.6634243] actual score: [1.]
# Model Score: [0.03707969] actual score: [0.]
# Model Score: [0.35773537] actual score: [0.]
# Model Score: [0.03644773] actual score: [0.]
# Model Score: [0.03412692] actual score: [0.]
# Model Score: [0.99098045] actual score: [1.]
# Model Score: [0.03924683] actual score: [0.]
# Model Score: [0.9768554] actual score: [1.]
# Model Score: [0.9817879] actual score: [1.]
# Model Score: [0.03749375] actual score: [0.]
# Model Score: [0.8984514] actual score: [1.]
# Model Score: [0.03673605] actual score: [0.]
# Model Score: [0.03699378] actual score: [0.]
# Model Score: [0.96678257] actual score: [1.]
# Model Score: [0.99581933] actual score: [1.]
# Model Score: [0.9924429] actual score: [1.]
# Model Score: [0.03797261] actual score: [0.]
# Model Score: [0.89009076] actual score: [1.]
# Model Score: [0.03837832] actual score: [0.]
# Model Score: [0.9466362] actual score: [1.]
# Model Score: [0.03776537] actual score: [0.]
# Model Score: [0.9907046] actual score: [1.]
# Model Score: [0.9772042] actual score: [1.]
# Model Score: [0.03675698] actual score: [0.]
# Model Score: [0.03866401] actual score: [0.]
# Model Score: [0.8057588] actual score: [1.]
# Model Score: [0.0798026] actual score: [0.]
# Model Score: [0.03846679] actual score: [0.]
# Model Score: [0.0376864] actual score: [0.]
# Model Score: [0.9543214] actual score: [1.]
# Model Score: [0.96963185] actual score: [1.]
# Model Score: [0.874734] actual score: [1.]
# Model Score: [0.985544] actual score: [1.]
# Model Score: [0.89332324] actual score: [1.]
# Model Score: [0.03809374] actual score: [0.]
# Model Score: [0.03926313] actual score: [0.]
# Model Score: [0.03894639] actual score: [0.]
# Model Score: [0.03876448] actual score: [0.]
# Model Score: [0.8647908] actual score: [1.]
# Model Score: [0.03911541] actual score: [0.]
# Model Score: [0.03808009] actual score: [0.]
# Model Score: [0.2397041] actual score: [0.]
# Model Score: [0.99953103] actual score: [0.]
# Model Score: [0.9115301] actual score: [1.]
# Model Score: [0.03726785] actual score: [0.]
# Model Score: [0.0384208] actual score: [0.]
# Model Score: [0.18797353] actual score: [0.]
# Model Score: [0.9782825] actual score: [1.]
# Model Score: [0.03670841] actual score: [0.]
# Model Score: [0.5107078] actual score: [0.]
# Model Score: [0.9966349] actual score: [1.]
# Model Score: [0.03704119] actual score: [0.]
# Model Score: [0.03730561] actual score: [0.]
# Model Score: [0.9547771] actual score: [1.]
# Model Score: [0.89792055] actual score: [1.]
# Model Score: [0.03710085] actual score: [0.]
# Model Score: [0.03790509] actual score: [0.]
# Model Score: [0.037037] actual score: [0.]
# Model Score: [0.03525468] actual score: [0.]
# Model Score: [0.03607907] actual score: [0.]
# Model Score: [0.03815348] actual score: [0.]
# Model Score: [0.9539022] actual score: [1.]
# Model Score: [0.98065317] actual score: [1.]
# Model Score: [0.9666444] actual score: [1.]
# Model Score: [0.03712331] actual score: [0.]
# Model Score: [0.03651116] actual score: [0.]
# Model Score: [0.9987275] actual score: [1.]
# Model Score: [0.03727283] actual score: [0.]
# Model Score: [0.9295395] actual score: [1.]
# Model Score: [0.9660258] actual score: [1.]
# Model Score: [0.04140411] actual score: [0.]
# Model Score: [0.9822788] actual score: [1.]
# Model Score: [0.03934449] actual score: [1.]
# Model Score: [0.4441755] actual score: [0.]
# Model Score: [0.03757793] actual score: [0.]
# Model Score: [0.03651577] actual score: [0.]
# Model Score: [0.03551157] actual score: [0.]
# Model Score: [0.03669789] actual score: [0.]
# Model Score: [0.03940675] actual score: [1.]
# Model Score: [0.03729495] actual score: [0.]
# Model Score: [0.7735327] actual score: [1.]
# Model Score: [0.03699552] actual score: [0.]
# Model Score: [0.29237622] actual score: [1.]
# Model Score: [0.03758868] actual score: [0.]
# Model Score: [0.03739119] actual score: [0.]
# Model Score: [0.7154042] actual score: [1.]
# Model Score: [0.99248064] actual score: [1.]
# Model Score: [0.828477] actual score: [1.]
# Model Score: [0.9990331] actual score: [1.]
# Model Score: [0.03471116] actual score: [0.]
# Model Score: [0.6307221] actual score: [1.]
# Model Score: [0.03778075] actual score: [0.]
# Model Score: [0.03762677] actual score: [0.]
# Model Score: [0.03692827] actual score: [0.]
# Model Score: [0.97080654] actual score: [1.]
# Model Score: [0.04138213] actual score: [0.]
# Model Score: [0.7393218] actual score: [1.]
# Model Score: [0.85288435] actual score: [1.]
# Model Score: [0.03809389] actual score: [0.]
# Model Score: [0.8482441] actual score: [1.]
# Model Score: [0.03924592] actual score: [0.]
# Model Score: [0.5688415] actual score: [0.]
# Model Score: [0.9914568] actual score: [1.]
# Model Score: [0.97287685] actual score: [1.]
# Model Score: [0.07637871] actual score: [0.]
# Model Score: [0.04045857] actual score: [0.]
# Model Score: [0.5974484] actual score: [1.]
# Model Score: [0.03692544] actual score: [0.]
# Model Score: [0.03535764] actual score: [0.]
# Model Score: [0.07298286] actual score: [0.]
# Model Score: [0.03725461] actual score: [0.]
# Model Score: [0.03917727] actual score: [0.]
# Model Score: [0.05815656] actual score: [0.]
# Model Score: [0.03758244] actual score: [1.]
# Model Score: [0.03633352] actual score: [0.]
# Model Score: [0.99507457] actual score: [1.]
# Model Score: [0.0379029] actual score: [0.]
# Model Score: [0.50716174] actual score: [1.]
# Model Score: [0.9881058] actual score: [1.]
# Model Score: [0.9489808] actual score: [1.]
# Model Score: [0.9822901] actual score: [1.]
# Model Score: [0.03813765] actual score: [0.]
# Model Score: [0.03605157] actual score: [0.]
# Model Score: [0.98323464] actual score: [1.]
# Model Score: [0.992459] actual score: [1.]
# Model Score: [0.96659017] actual score: [1.]
# Model Score: [0.03655447] actual score: [0.]
# Model Score: [0.94489557] actual score: [1.]
# Model Score: [0.03719366] actual score: [0.]
# Model Score: [0.11010309] actual score: [0.]
# Model Score: [0.90893114] actual score: [1.]
# Model Score: [0.9570543] actual score: [1.]
# Model Score: [0.03636133] actual score: [0.]
# Model Score: [0.03682909] actual score: [0.]
# Model Score: [0.03777711] actual score: [0.]
# Model Score: [0.58723676] actual score: [0.]
# Model Score: [0.03741511] actual score: [0.]
# Model Score: [0.03707754] actual score: [0.]
# Model Score: [0.95012105] actual score: [1.]
# Model Score: [0.03668672] actual score: [1.]
# Model Score: [0.9044532] actual score: [1.]
# Model Score: [0.9322651] actual score: [1.]
# Model Score: [0.03516395] actual score: [0.]
# Model Score: [0.08467071] actual score: [0.]
# Model Score: [0.9628376] actual score: [1.]
# Model Score: [0.03750644] actual score: [0.]
# Model Score: [0.23861143] actual score: [1.]
# Model Score: [0.04063474] actual score: [0.]
# Model Score: [0.0357948] actual score: [0.]
# Model Score: [0.0359592] actual score: [0.]
# Model Score: [0.03663172] actual score: [0.]
# Model Score: [0.67981404] actual score: [0.]
# Model Score: [0.9476735] actual score: [1.]
# Model Score: [0.98069006] actual score: [1.]
# Model Score: [0.04068384] actual score: [0.]
# Model Score: [0.03647839] actual score: [0.]
# Model Score: [0.95519453] actual score: [1.]
# Model Score: [0.03723687] actual score: [0.]
# Model Score: [0.03918321] actual score: [1.]
# Model Score: [0.99293435] actual score: [1.]
# Model Score: [0.03965078] actual score: [0.]
# Model Score: [0.03885387] actual score: [0.]
# Model Score: [0.9952341] actual score: [1.]
# Model Score: [0.5272772] actual score: [1.]
# Model Score: [0.9921427] actual score: [1.]
# Model Score: [0.80429524] actual score: [1.]
# Model Score: [0.7677138] actual score: [1.]
# Model Score: [0.04119891] actual score: [1.]
# Model Score: [0.94512135] actual score: [1.]
# Model Score: [0.03738268] actual score: [0.]
# Model Score: [0.97231174] actual score: [1.]
# Model Score: [0.03578637] actual score: [0.]
# Model Score: [0.03639273] actual score: [0.]
# Model Score: [0.98606503] actual score: [1.]
# Model Score: [0.6093561] actual score: [1.]
# Model Score: [0.9969289] actual score: [1.]
# Model Score: [0.03449525] actual score: [0.]
# Model Score: [0.03773021] actual score: [1.]
# Model Score: [0.9612979] actual score: [1.]
# Model Score: [0.937241] actual score: [1.]
# Model Score: [0.927929] actual score: [1.]
# Model Score: [0.03764121] actual score: [0.]
# Model Score: [0.88448286] actual score: [1.]
# Model Score: [0.97998923] actual score: [1.]
# Model Score: [0.03671421] actual score: [0.]
# Model Score: [0.04008587] actual score: [0.]
# Model Score: [0.03540779] actual score: [0.]
# Model Score: [0.8417174] actual score: [1.]
# Model Score: [0.8799106] actual score: [1.]
# Model Score: [0.9729064] actual score: [1.]
# Model Score: [0.7813455] actual score: [1.]
# Model Score: [0.7523052] actual score: [1.]
# Model Score: [0.9860902] actual score: [1.]
# Model Score: [0.9383645] actual score: [1.]
# Model Score: [0.03639706] actual score: [0.]
# Model Score: [0.99247134] actual score: [1.]
# Model Score: [0.03624876] actual score: [0.]
# Model Score: [0.21480708] actual score: [0.]
# Model Score: [0.03777226] actual score: [1.]
# Model Score: [0.03584159] actual score: [0.]
# Model Score: [0.0376742] actual score: [0.]
# Model Score: [0.98642206] actual score: [1.]
# Model Score: [0.99257237] actual score: [1.]
# Model Score: [0.0361898] actual score: [0.]
# Model Score: [0.9937313] actual score: [1.]
# Model Score: [0.0379395] actual score: [0.]
# Model Score: [0.96490157] actual score: [1.]
# Model Score: [0.99705493] actual score: [1.]
# Model Score: [0.5812668] actual score: [1.]
# Model Score: [0.03650018] actual score: [0.]
# Model Score: [0.03688416] actual score: [0.]
# Model Score: [0.03731579] actual score: [0.]
# Model Score: [0.039037] actual score: [1.]
# Model Score: [0.98391163] actual score: [1.]
# Model Score: [0.9989926] actual score: [1.]
# Model Score: [0.03709217] actual score: [0.]
# Model Score: [0.03662097] actual score: [0.]
# Model Score: [0.92217994] actual score: [1.]
# Model Score: [0.94965756] actual score: [1.]
# Model Score: [0.9999269] actual score: [1.]
# Model Score: [0.19276683] actual score: [0.]
# Model Score: [0.9818309] actual score: [1.]
# Model Score: [0.03613246] actual score: [0.]
# Model Score: [0.9973104] actual score: [1.]
# Model Score: [0.15032558] actual score: [0.]
# Model Score: [0.7519832] actual score: [0.]
# Model Score: [0.91446614] actual score: [1.]
# Model Score: [0.9841734] actual score: [1.]
# Model Score: [0.99290633] actual score: [1.]
# Model Score: [0.1732823] actual score: [0.]
# Model Score: [0.03576689] actual score: [0.]
# Model Score: [0.0381333] actual score: [0.]
# Model Score: [0.20424654] actual score: [0.]
# Model Score: [0.04321085] actual score: [1.]
# Model Score: [0.03856451] actual score: [0.]
# Model Score: [0.6941871] actual score: [1.]
# Model Score: [0.99353576] actual score: [1.]
# Model Score: [0.03875946] actual score: [0.]
# Model Score: [0.0399646] actual score: [0.]
# Model Score: [0.03963839] actual score: [1.]
# Model Score: [0.7000167] actual score: [1.]
# Model Score: [0.99131656] actual score: [1.]
# Model Score: [0.03617576] actual score: [0.]
# Model Score: [0.0359149] actual score: [0.]
# Model Score: [0.03650602] actual score: [0.]
# Model Score: [0.96965975] actual score: [1.]
# Model Score: [0.72098714] actual score: [0.]
# Model Score: [0.97231877] actual score: [1.]
# Model Score: [0.6312797] actual score: [1.]
# Model Score: [0.03555033] actual score: [0.]
# Model Score: [0.03652934] actual score: [0.]
# Model Score: [0.72338426] actual score: [1.]
# Model Score: [0.98196304] actual score: [1.]
# Model Score: [0.03604543] actual score: [0.]
# Model Score: [0.9466424] actual score: [1.]
# Model Score: [0.96457034] actual score: [1.]
# Model Score: [0.03976358] actual score: [1.]
# Model Score: [0.03906306] actual score: [0.]
# Model Score: [0.0383114] actual score: [0.]
# Model Score: [0.9976781] actual score: [1.]
# Model Score: [0.03932374] actual score: [0.]
# Model Score: [0.03599218] actual score: [0.]
# Model Score: [0.9292411] actual score: [1.]
# Model Score: [0.99495393] actual score: [1.]
# Model Score: [0.9354433] actual score: [1.]
# Model Score: [0.03656793] actual score: [0.]
# Model Score: [0.21958718] actual score: [0.]
# Model Score: [0.05590011] actual score: [0.]
# Model Score: [0.03827318] actual score: [0.]
# Model Score: [0.04426885] actual score: [0.]
# Model Score: [0.9857129] actual score: [1.]
# Model Score: [0.03489849] actual score: [0.]
# Model Score: [0.9383627] actual score: [1.]
# Model Score: [0.03555476] actual score: [0.]
# Model Score: [0.7193487] actual score: [1.]
# Model Score: [0.0370843] actual score: [0.]
# Model Score: [0.09311596] actual score: [0.]
# Model Score: [0.979286] actual score: [1.]
# Model Score: [0.03990787] actual score: [0.]
# Model Score: [0.0371315] actual score: [0.]
# Model Score: [0.7962053] actual score: [0.]
# Model Score: [0.9828084] actual score: [1.]
# Model Score: [0.99191296] actual score: [1.]
# Model Score: [0.9825242] actual score: [1.]
# Model Score: [0.99551564] actual score: [1.]
# Model Score: [0.8852418] actual score: [1.]
# Model Score: [0.99137324] actual score: [1.]
# Model Score: [0.03817488] actual score: [0.]
# Model Score: [0.97624505] actual score: [1.]
# Model Score: [0.9885278] actual score: [1.]
# Model Score: [0.03717029] actual score: [0.]
# Model Score: [0.03636792] actual score: [0.]
# Model Score: [0.03544142] actual score: [0.]
# Model Score: [0.05520987] actual score: [0.]
# Model Score: [0.97906876] actual score: [1.]
# Model Score: [0.03571588] actual score: [0.]
# Model Score: [0.0359602] actual score: [0.]
# Model Score: [0.03913007] actual score: [0.]
# Model Score: [0.9948394] actual score: [1.]
# Model Score: [0.9185248] actual score: [1.]
# Model Score: [0.03687314] actual score: [0.]
# Model Score: [0.03848397] actual score: [0.]
# Model Score: [0.04135146] actual score: [0.]
# Model Score: [0.03807932] actual score: [0.]
# Model Score: [0.95028234] actual score: [1.]
# Model Score: [0.971764] actual score: [1.]
# Model Score: [0.03587681] actual score: [0.]
# Model Score: [0.03837154] actual score: [0.]
# Model Score: [0.89175177] actual score: [1.]
# Model Score: [0.7649887] actual score: [1.]
# Model Score: [0.12552784] actual score: [0.]
# Model Score: [0.04373747] actual score: [0.]
# Model Score: [0.03775301] actual score: [0.]
# Model Score: [0.84124136] actual score: [1.]
# Model Score: [0.9361284] actual score: [1.]
# Model Score: [0.03786723] actual score: [0.]
# Model Score: [0.9994197] actual score: [1.]
# Model Score: [0.98433346] actual score: [1.]
# Model Score: [0.31759128] actual score: [0.]
# Model Score: [0.9324387] actual score: [1.]
# Model Score: [0.9776872] actual score: [1.]
# Model Score: [0.90072703] actual score: [1.]
# Model Score: [0.03719695] actual score: [0.]
# Model Score: [0.03639193] actual score: [0.]
# Model Score: [0.03618436] actual score: [0.]
# Model Score: [0.9163544] actual score: [1.]
# Model Score: [0.9971667] actual score: [1.]
# Model Score: [0.9977958] actual score: [1.]
# Model Score: [0.0350019] actual score: [0.]
# Model Score: [0.97683436] actual score: [1.]
# Model Score: [0.975184] actual score: [1.]
# Model Score: [0.06124001] actual score: [0.]
# Model Score: [0.74179524] actual score: [1.]
# Model Score: [0.9648619] actual score: [1.]
# Model Score: [0.6456873] actual score: [1.]
# Model Score: [0.03677845] actual score: [0.]
# Model Score: [0.03827097] actual score: [0.]
# Model Score: [0.03725961] actual score: [0.]
# Model Score: [0.03831361] actual score: [0.]
# Model Score: [0.03649013] actual score: [0.]
# Model Score: [0.03681031] actual score: [0.]
# Model Score: [0.03789542] actual score: [0.]
# Model Score: [0.0360191] actual score: [0.]
# Model Score: [0.03847582] actual score: [0.]
# Model Score: [0.03991422] actual score: [0.]
# Model Score: [0.8815192] actual score: [1.]
# Model Score: [0.03830894] actual score: [0.]
# Model Score: [0.96509695] actual score: [1.]
# Model Score: [0.92430705] actual score: [1.]
# Model Score: [0.03744651] actual score: [0.]
# Model Score: [0.91052] actual score: [1.]
# Model Score: [0.9964819] actual score: [1.]
# Model Score: [0.03804374] actual score: [0.]
# Model Score: [0.9662134] actual score: [1.]
# Model Score: [0.97814524] actual score: [1.]
# Model Score: [0.9324138] actual score: [1.]
# Model Score: [0.7114742] actual score: [1.]
# Model Score: [0.2225411] actual score: [0.]
# Model Score: [0.89010185] actual score: [1.]
# Model Score: [0.9920896] actual score: [1.]
# Model Score: [0.99516064] actual score: [1.]
# Model Score: [0.03913427] actual score: [0.]
# Model Score: [0.03695282] actual score: [0.]
# Model Score: [0.05647089] actual score: [0.]
# Model Score: [0.997279] actual score: [1.]
# Model Score: [0.31836617] actual score: [0.]
# Model Score: [0.03668216] actual score: [0.]
# Model Score: [0.9586265] actual score: [1.]
# Model Score: [0.1958601] actual score: [0.]
# Model Score: [0.03549827] actual score: [0.]
# Model Score: [0.03948887] actual score: [0.]
# Model Score: [0.0444507] actual score: [0.]
# Model Score: [0.9533107] actual score: [1.]
# Model Score: [0.89417213] actual score: [1.]
# Model Score: [0.94216555] actual score: [1.]
# Model Score: [0.9543215] actual score: [1.]
# Model Score: [0.9832669] actual score: [1.]
# Model Score: [0.9883414] actual score: [1.]
# Model Score: [0.93813384] actual score: [1.]
# Model Score: [0.97001845] actual score: [1.]
# Model Score: [0.03786277] actual score: [0.]
# Model Score: [0.03659661] actual score: [0.]
# Model Score: [0.0362547] actual score: [0.]
# Model Score: [0.03637568] actual score: [0.]
# Model Score: [0.03679549] actual score: [0.]
# Model Score: [0.99139446] actual score: [1.]
# Model Score: [0.03594365] actual score: [0.]
# Model Score: [0.0367639] actual score: [0.]
# Model Score: [0.98522043] actual score: [1.]
# Model Score: [0.85715723] actual score: [1.]
# Model Score: [0.9909367] actual score: [1.]
# Model Score: [0.03426999] actual score: [0.]
# Model Score: [0.89660907] actual score: [1.]
# Model Score: [0.18574819] actual score: [1.]
# Model Score: [0.03596527] actual score: [0.]
# Model Score: [0.03734769] actual score: [0.]
# Model Score: [0.9973277] actual score: [1.]
# Model Score: [0.0366287] actual score: [0.]
# Model Score: [0.03716243] actual score: [1.]
# Model Score: [0.9943144] actual score: [1.]
# Model Score: [0.92696023] actual score: [1.]
# Model Score: [0.03742422] actual score: [0.]
# Model Score: [0.89022464] actual score: [1.]
# Model Score: [0.0348054] actual score: [0.]
# Model Score: [0.9938717] actual score: [1.]
# Model Score: [0.75557137] actual score: [1.]
# Model Score: [0.9428383] actual score: [1.]
# Model Score: [0.03713714] actual score: [0.]
# Model Score: [0.8078555] actual score: [1.]
# Model Score: [0.1530604] actual score: [0.]
# Model Score: [0.03863895] actual score: [0.]
# Model Score: [0.03755913] actual score: [0.]
# Model Score: [0.90481174] actual score: [1.]
# Model Score: [0.76105165] actual score: [1.]
# Model Score: [0.03756585] actual score: [0.]
# Model Score: [0.9748868] actual score: [1.]
# Model Score: [0.91714853] actual score: [1.]
# Model Score: [0.04457278] actual score: [0.]
# Model Score: [0.9906302] actual score: [1.]
# Model Score: [0.9483443] actual score: [1.]
# Model Score: [0.7234066] actual score: [1.]
# Model Score: [0.9061267] actual score: [1.]
# Model Score: [0.0355574] actual score: [0.]
# Model Score: [0.8773083] actual score: [1.]
# Model Score: [0.9942966] actual score: [1.]
# Model Score: [0.54610914] actual score: [1.]
# Model Score: [0.03607093] actual score: [0.]
# Model Score: [0.03676946] actual score: [0.]
# Model Score: [0.9990357] actual score: [1.]
# Model Score: [0.9069535] actual score: [1.]
# Model Score: [0.03711019] actual score: [0.]
# Model Score: [0.03955135] actual score: [0.]
# Model Score: [0.93568105] actual score: [1.]
# Model Score: [0.03596425] actual score: [0.]
# Model Score: [0.03759246] actual score: [0.]
# Model Score: [0.9531619] actual score: [1.]
# Model Score: [0.9554345] actual score: [1.]
# Model Score: [0.9848934] actual score: [1.]
# Model Score: [0.09063496] actual score: [0.]
# Model Score: [0.03626551] actual score: [0.]
# Model Score: [0.94234055] actual score: [1.]
# Model Score: [0.8524559] actual score: [1.]
# Model Score: [0.03707174] actual score: [0.]
# Model Score: [0.94863933] actual score: [1.]
# Model Score: [0.98043174] actual score: [1.]
# Model Score: [0.8144348] actual score: [0.]
# Model Score: [0.03957113] actual score: [0.]
# Model Score: [0.9730031] actual score: [1.]
# Model Score: [0.8694597] actual score: [1.]
# Model Score: [0.03563104] actual score: [0.]
# Model Score: [0.9803966] actual score: [1.]
# Model Score: [0.03814766] actual score: [0.]
# Model Score: [0.0373142] actual score: [0.]
# Model Score: [0.03662411] actual score: [0.]
# Model Score: [0.05738572] actual score: [0.]
# Model Score: [0.03720837] actual score: [0.]
# Model Score: [0.03612389] actual score: [0.]
# Model Score: [0.03805693] actual score: [0.]
# Model Score: [0.03911739] actual score: [0.]
# Model Score: [0.04018601] actual score: [0.]
# Model Score: [0.2999328] actual score: [1.]
# Model Score: [0.03582547] actual score: [0.]
# Model Score: [0.90271187] actual score: [1.]
# Model Score: [0.03808696] actual score: [0.]
# Model Score: [0.10107896] actual score: [0.]
# Model Score: [0.03917439] actual score: [0.]
# Model Score: [0.62292814] actual score: [0.]
# Model Score: [0.8692767] actual score: [1.]
# Model Score: [0.03655626] actual score: [0.]
# Model Score: [0.10543276] actual score: [0.]
# Model Score: [0.84059376] actual score: [1.]
# Model Score: [0.9927055] actual score: [1.]
# Model Score: [0.03708326] actual score: [0.]
# Model Score: [0.51759106] actual score: [0.]
# Model Score: [0.994968] actual score: [1.]
# Model Score: [0.03835094] actual score: [0.]
# Model Score: [0.994859] actual score: [1.]
# Model Score: [0.9995622] actual score: [1.]
# Model Score: [0.03536067] actual score: [0.]
# Model Score: [0.03995143] actual score: [0.]
# Model Score: [0.9471049] actual score: [1.]
# Model Score: [0.06781508] actual score: [0.]
# Model Score: [0.963426] actual score: [1.]
# Model Score: [0.03739185] actual score: [0.]
# Model Score: [0.03701625] actual score: [0.]
# Model Score: [0.95577794] actual score: [1.]
# Model Score: [0.77832365] actual score: [1.]
# Model Score: [0.99277735] actual score: [1.]
# Model Score: [0.99142927] actual score: [1.]
# Model Score: [0.04517334] actual score: [0.]
# Model Score: [0.99630105] actual score: [1.]
# Model Score: [0.03637405] actual score: [0.]
# Model Score: [0.92995715] actual score: [1.]
# Model Score: [0.9437423] actual score: [1.]
# Model Score: [0.9088224] actual score: [1.]
# Model Score: [0.2162262] actual score: [0.]
# Model Score: [0.03810514] actual score: [0.]
# Model Score: [0.9551212] actual score: [1.]
# Model Score: [0.99479264] actual score: [1.]
# Model Score: [0.03509408] actual score: [0.]
# Model Score: [0.98340166] actual score: [1.]
# Model Score: [0.99911016] actual score: [1.]
# Model Score: [0.05426514] actual score: [0.]
# Model Score: [0.8307741] actual score: [1.]
# Model Score: [0.04994054] actual score: [0.]
# Model Score: [0.9011807] actual score: [1.]
# Model Score: [0.03704554] actual score: [0.]
# Model Score: [0.9777672] actual score: [1.]
# Model Score: [0.9974355] actual score: [1.]
# Model Score: [0.03744185] actual score: [0.]
# Model Score: [0.03975803] actual score: [0.]
# Model Score: [0.9197641] actual score: [1.]
# Model Score: [0.06200576] actual score: [0.]
# Model Score: [0.03939194] actual score: [0.]
# Model Score: [0.0369794] actual score: [0.]
# Model Score: [0.1059816] actual score: [1.]
# Model Score: [0.03685801] actual score: [0.]
# Model Score: [0.7897549] actual score: [1.]
# Model Score: [0.9900918] actual score: [1.]
# Model Score: [0.6472976] actual score: [0.]
# Model Score: [0.03966658] actual score: [0.]
# Model Score: [0.8441632] actual score: [1.]
# Model Score: [0.9222758] actual score: [1.]
# Model Score: [0.03640454] actual score: [0.]
# Model Score: [0.03555863] actual score: [0.]
# Model Score: [0.9836743] actual score: [1.]
# Model Score: [0.90380925] actual score: [1.]
# Model Score: [0.03468372] actual score: [0.]
# Model Score: [0.8281842] actual score: [1.]
# Model Score: [0.8953787] actual score: [1.]
# Model Score: [0.9696782] actual score: [1.]
# Model Score: [0.03551374] actual score: [0.]
# Model Score: [0.04663711] actual score: [0.]
# Model Score: [0.621159] actual score: [0.]
# Model Score: [0.03592205] actual score: [0.]
# Model Score: [0.14113188] actual score: [0.]
# Model Score: [0.03713727] actual score: [0.]
# Model Score: [0.82261056] actual score: [1.]
# Model Score: [0.50719005] actual score: [1.]
# Model Score: [0.96793973] actual score: [1.]
# Model Score: [0.9305419] actual score: [1.]
# Model Score: [0.9964379] actual score: [1.]
# Model Score: [0.03802944] actual score: [0.]
# Model Score: [0.9362266] actual score: [1.]
# Model Score: [0.9483099] actual score: [1.]
# Model Score: [0.93527263] actual score: [1.]
# Model Score: [0.98021394] actual score: [1.]
# Model Score: [0.8053679] actual score: [1.]
# Model Score: [0.03701351] actual score: [0.]
# Model Score: [0.03782148] actual score: [0.]
# Model Score: [0.88667774] actual score: [1.]
# Model Score: [0.9710525] actual score: [1.]
# Model Score: [0.654717] actual score: [1.]
# Model Score: [0.0350824] actual score: [0.]
# Model Score: [0.0363955] actual score: [0.]
# Model Score: [0.03776651] actual score: [0.]
# Model Score: [0.03780476] actual score: [0.]
# Model Score: [0.03757607] actual score: [0.]
# Model Score: [0.04333105] actual score: [0.]
# Model Score: [0.03766912] actual score: [0.]
# Model Score: [0.9966979] actual score: [1.]
# Model Score: [0.97240585] actual score: [1.]
# Model Score: [0.35393798] actual score: [1.]
# Model Score: [0.9340851] actual score: [1.]
# Model Score: [0.9884983] actual score: [1.]
# Model Score: [0.03615559] actual score: [0.]
# Model Score: [0.0368178] actual score: [0.]
# Model Score: [0.9362287] actual score: [1.]
# Model Score: [0.10303365] actual score: [1.]
# Model Score: [0.03495669] actual score: [0.]
# Model Score: [0.8661102] actual score: [1.]
# Model Score: [0.03654712] actual score: [0.]
# Model Score: [0.03678738] actual score: [0.]
# Model Score: [0.03665999] actual score: [0.]
# Model Score: [0.0368866] actual score: [0.]
# Model Score: [0.8189345] actual score: [1.]
# Model Score: [0.03577894] actual score: [0.]
# Model Score: [0.03994493] actual score: [0.]
# Model Score: [0.03803773] actual score: [0.]
# Model Score: [0.03542313] actual score: [0.]
# Model Score: [0.03510764] actual score: [0.]
# Model Score: [0.79349136] actual score: [1.]
# Model Score: [0.6394326] actual score: [0.]
# Model Score: [0.03642965] actual score: [0.]
# Model Score: [0.9790583] actual score: [1.]
# Model Score: [0.03512587] actual score: [0.]
# Model Score: [0.9161933] actual score: [1.]
# Model Score: [0.84801704] actual score: [1.]
# Model Score: [0.03585496] actual score: [0.]
# Model Score: [0.03610913] actual score: [0.]
# Model Score: [0.19257137] actual score: [0.]
# Model Score: [0.98154515] actual score: [1.]
# Model Score: [0.997968] actual score: [1.]
# Model Score: [0.799634] actual score: [1.]
# Model Score: [0.90022296] actual score: [1.]
# Model Score: [0.03555941] actual score: [0.]
# Model Score: [0.03967223] actual score: [0.]
# Model Score: [0.78837657] actual score: [1.]
# Model Score: [0.03760131] actual score: [0.]
# Model Score: [0.97159576] actual score: [1.]
# Model Score: [0.03579459] actual score: [0.]
# Model Score: [0.9945374] actual score: [1.]
# Model Score: [0.782846] actual score: [1.]
# Model Score: [0.96618885] actual score: [1.]
# Model Score: [0.0379801] actual score: [0.]
# Model Score: [0.9210241] actual score: [1.]
# Model Score: [0.96000266] actual score: [1.]
# Model Score: [0.9615655] actual score: [1.]
# Model Score: [0.904969] actual score: [1.]
# Model Score: [0.03830721] actual score: [0.]
# Model Score: [0.9089784] actual score: [1.]
# Model Score: [0.95041233] actual score: [1.]
# Model Score: [0.91078466] actual score: [1.]
# Model Score: [0.03903418] actual score: [0.]
# Model Score: [0.03779424] actual score: [0.]
# Model Score: [0.09275787] actual score: [0.]
# Model Score: [0.9971916] actual score: [1.]
# Model Score: [0.05545957] actual score: [1.]
# Model Score: [0.97900236] actual score: [1.]
# Model Score: [0.0394827] actual score: [0.]
# Model Score: [0.03880742] actual score: [0.]
# Model Score: [0.3622279] actual score: [1.]
# Model Score: [0.03619404] actual score: [0.]
# Model Score: [0.03641985] actual score: [0.]
# Model Score: [0.16242324] actual score: [0.]
# Model Score: [0.97798604] actual score: [1.]
# Model Score: [0.9798346] actual score: [1.]
# Model Score: [0.03779386] actual score: [0.]
# Model Score: [0.7953271] actual score: [1.]
# Model Score: [0.7778781] actual score: [1.]
# Model Score: [0.03722145] actual score: [0.]
# Model Score: [0.03685195] actual score: [0.]
# Model Score: [0.03750004] actual score: [0.]
# Model Score: [0.03757183] actual score: [0.]
# Model Score: [0.98278356] actual score: [1.]
# Model Score: [0.8763848] actual score: [1.]
# Model Score: [0.03612535] actual score: [0.]
# Model Score: [0.03888904] actual score: [0.]
# Model Score: [0.95704895] actual score: [1.]
# Model Score: [0.91374964] actual score: [1.]
# Model Score: [0.03556588] actual score: [0.]
# Model Score: [0.03766627] actual score: [0.]
# Model Score: [0.6997003] actual score: [1.]
# Model Score: [0.03974279] actual score: [0.]
# Model Score: [0.97986525] actual score: [1.]
# Model Score: [0.9155742] actual score: [1.]
# ...
# Model Score: [0.9041766] actual score: [1.]
# Model Score: [0.03542254] actual score: [0.]
# Model Score: [0.9803422] actual score: [1.]
# Model Score: [0.03640039] actual score: [0.]
# Model Score: [0.03639587] actual score: [0.]
# Model Score: [0.95332] actual score: [1.]
# Model Score: [0.9364429] actual score: [1.]
# Model Score: [0.7423464] actual score: [1.]
# Model Score: [0.03762991] actual score: [0.]
# Model Score: [0.03677868] actual score: [0.]
# Model Score: [0.03690119] actual score: [0.]
# Model Score: [0.07937267] actual score: [0.]
# Model Score: [0.9937285] actual score: [1.]
# Model Score: [0.9907878] actual score: [1.]
# Model Score: [0.9813642] actual score: [1.]
# Model Score: [0.8671262] actual score: [0.]
# Model Score: [0.88756794] actual score: [1.]
# Model Score: [0.0461732] actual score: [1.]
# Model Score: [0.80959696] actual score: [1.]
# Model Score: [0.03731] actual score: [0.]
# Model Score: [0.994056] actual score: [1.]
# Model Score: [0.8950208] actual score: [1.]
# Model Score: [0.03717786] actual score: [0.]
# Model Score: [0.6164439] actual score: [0.]
# Model Score: [0.8930457] actual score: [1.]
# Model Score: [0.04142047] actual score: [0.]
# Model Score: [0.8938287] actual score: [1.]
# Model Score: [0.9996257] actual score: [1.]
# Model Score: [0.64138407] actual score: [1.]
# Model Score: [0.25340584] actual score: [0.]
# Model Score: [0.86037445] actual score: [1.]
# Model Score: [0.03806392] actual score: [0.]
# Model Score: [0.92152804] actual score: [1.]
# Model Score: [0.6713274] actual score: [1.]
# Model Score: [0.9846615] actual score: [1.]
# Model Score: [0.83812743] actual score: [1.]
# Model Score: [0.996552] actual score: [1.]
# Model Score: [0.96489] actual score: [1.]
# Model Score: [0.03834667] actual score: [0.]
# Model Score: [0.03642415] actual score: [0.]
# Model Score: [0.894037] actual score: [1.]
# Model Score: [0.97830313] actual score: [1.]
# Model Score: [0.0379172] actual score: [0.]
# Model Score: [0.03790567] actual score: [0.]
# Model Score: [0.94087446] actual score: [1.]
# Model Score: [0.9601346] actual score: [1.]
# Model Score: [0.9275121] actual score: [1.]
# Model Score: [0.03614429] actual score: [0.]
# Model Score: [0.80970657] actual score: [1.]
# Model Score: [0.03581583] actual score: [0.]
# Model Score: [0.03997711] actual score: [0.]
# Model Score: [0.03579149] actual score: [0.]
# Model Score: [0.9314314] actual score: [1.]
# Model Score: [0.9958513] actual score: [1.]
# Model Score: [0.03513352] actual score: [0.]
# Model Score: [0.7508829] actual score: [1.]
# Model Score: [0.03947345] actual score: [0.]
# Model Score: [0.9953408] actual score: [1.]
# Model Score: [0.03895524] actual score: [0.]
# Model Score: [0.03504584] actual score: [0.]
# Model Score: [0.03651246] actual score: [0.]
# Model Score: [0.03809645] actual score: [0.]
# Model Score: [0.9970714] actual score: [1.]
# Model Score: [0.9554272] actual score: [1.]
# Model Score: [0.06406289] actual score: [0.]
# Model Score: [0.03825406] actual score: [0.]
# Model Score: [0.9993734] actual score: [1.]
# Model Score: [0.03989588] actual score: [0.]
# Model Score: [0.6432312] actual score: [0.]
# Model Score: [0.03766692] actual score: [0.]
# Model Score: [0.90555483] actual score: [1.]
# Model Score: [0.03761947] actual score: [0.]
# Model Score: [0.8904468] actual score: [1.]
# Model Score: [0.86038715] actual score: [1.]
# Model Score: [0.03553278] actual score: [0.]
# Model Score: [0.03902848] actual score: [0.]
# Model Score: [0.03736456] actual score: [0.]
# Model Score: [0.03512598] actual score: [0.]
# Model Score: [0.9246325] actual score: [1.]
# Model Score: [0.03714359] actual score: [0.]
# Model Score: [0.04936809] actual score: [0.]
# Model Score: [0.03942116] actual score: [0.]
# Model Score: [0.9668745] actual score: [1.]
# Model Score: [0.03523574] actual score: [0.]
# Model Score: [0.9216125] actual score: [1.]
# Model Score: [0.93217385] actual score: [1.]
# Model Score: [0.993192] actual score: [1.]
# Model Score: [0.03985127] actual score: [0.]
# Model Score: [0.03759453] actual score: [0.]
# Model Score: [0.03859493] actual score: [0.]
# Model Score: [0.5870671] actual score: [1.]
# Model Score: [0.03756889] actual score: [0.]
# Model Score: [0.03664352] actual score: [0.]
# Model Score: [0.9406028] actual score: [1.]
# Model Score: [0.94508386] actual score: [1.]
# Model Score: [0.03889506] actual score: [0.]
# Model Score: [0.88748765] actual score: [1.]
# Model Score: [0.03602904] actual score: [0.]
# Model Score: [0.9862873] actual score: [1.]
# Model Score: [0.97281885] actual score: [1.]
# Model Score: [0.97191894] actual score: [1.]
# Model Score: [0.96531415] actual score: [1.]
# Model Score: [0.8390464] actual score: [1.]
# Model Score: [0.0367204] actual score: [0.]
# Model Score: [0.03539278] actual score: [0.]
# Model Score: [0.9980416] actual score: [1.]
# Model Score: [0.9953868] actual score: [1.]
# Model Score: [0.03536839] actual score: [0.]
# Model Score: [0.746511] actual score: [0.]
# Model Score: [0.03911527] actual score: [0.]
# Model Score: [0.03937257] actual score: [0.]
# Model Score: [0.03698632] actual score: [0.]
# Model Score: [0.03537382] actual score: [0.]
# Model Score: [0.59732085] actual score: [1.]
# Model Score: [0.03873381] actual score: [0.]
# Model Score: [0.5557286] actual score: [1.]
# Model Score: [0.03637922] actual score: [0.]
# Model Score: [0.83527416] actual score: [1.]
# Model Score: [0.03694157] actual score: [0.]
# Model Score: [0.9931311] actual score: [1.]
# Model Score: [0.86269474] actual score: [1.]
# Model Score: [0.79487735] actual score: [1.]
# Model Score: [0.93699425] actual score: [1.]
# Model Score: [0.03789457] actual score: [0.]
# Model Score: [0.9531703] actual score: [1.]
# Model Score: [0.03749876] actual score: [0.]
# Model Score: [0.03512133] actual score: [0.]
# Model Score: [0.03549529] actual score: [0.]
# Model Score: [0.88790625] actual score: [1.]
# Model Score: [0.79111725] actual score: [1.]
# Model Score: [0.9695209] actual score: [1.]
# Model Score: [0.03917316] actual score: [0.]
# Model Score: [0.9470237] actual score: [1.]
# Model Score: [0.03956544] actual score: [0.]
# Model Score: [0.12659456] actual score: [1.]
# Model Score: [0.03711157] actual score: [0.]
# Model Score: [0.87023866] actual score: [1.]
# Model Score: [0.03705257] actual score: [0.]
# Model Score: [0.03577805] actual score: [0.]
# Model Score: [0.96165335] actual score: [1.]
# Model Score: [0.03658661] actual score: [0.]
# Model Score: [0.03899613] actual score: [0.]
# Model Score: [0.11221737] actual score: [0.]
# Model Score: [0.03865845] actual score: [1.]
# Model Score: [0.03631095] actual score: [0.]
# Model Score: [0.03710319] actual score: [0.]
# Model Score: [0.88671887] actual score: [1.]
# Model Score: [0.8934434] actual score: [1.]
# Model Score: [0.0370276] actual score: [0.]
# Model Score: [0.96471536] actual score: [1.]
# Model Score: [0.9710929] actual score: [1.]
# Model Score: [0.03749593] actual score: [0.]
# Model Score: [0.99889755] actual score: [1.]
# Model Score: [0.7885717] actual score: [1.]
# Model Score: [0.03595267] actual score: [0.]
# Model Score: [0.2633149] actual score: [0.]
# Model Score: [0.03700086] actual score: [0.]
# Model Score: [0.03714555] actual score: [0.]
# Model Score: [0.71500903] actual score: [1.]
# Model Score: [0.971033] actual score: [1.]
# Model Score: [0.14236034] actual score: [1.]
# Model Score: [0.03765928] actual score: [0.]
# Model Score: [0.03508967] actual score: [0.]
# Model Score: [0.18514736] actual score: [0.]
# Model Score: [0.77990043] actual score: [1.]
# Model Score: [0.03425675] actual score: [0.]
# Model Score: [0.03669173] actual score: [0.]
# Model Score: [0.848931] actual score: [1.]
# Model Score: [0.90781015] actual score: [1.]
# Model Score: [0.03906805] actual score: [0.]
# Model Score: [0.0377943] actual score: [0.]
# Model Score: [0.04577151] actual score: [1.]
# Model Score: [0.94867057] actual score: [1.]
# Model Score: [0.03892614] actual score: [0.]
# Model Score: [0.03547588] actual score: [0.]
# Model Score: [0.047658] actual score: [0.]
# Model Score: [0.94652563] actual score: [1.]
# Model Score: [0.7483972] actual score: [1.]
# Model Score: [0.03736936] actual score: [0.]
# Model Score: [0.03656205] actual score: [0.]
# Model Score: [0.03639405] actual score: [0.]
# Model Score: [0.03665928] actual score: [0.]
# Model Score: [0.7060459] actual score: [1.]
# Model Score: [0.918553] actual score: [1.]
# Model Score: [0.03756285] actual score: [0.]
# Model Score: [0.92669445] actual score: [1.]
# Model Score: [0.95627886] actual score: [1.]
# Model Score: [0.03877403] actual score: [0.]
# Model Score: [0.9788396] actual score: [1.]
# Model Score: [0.73961097] actual score: [0.]
# Model Score: [0.19805498] actual score: [0.]
# Model Score: [0.0350222] actual score: [0.]
# Model Score: [0.995368] actual score: [1.]
# Model Score: [0.03593554] actual score: [0.]
# Model Score: [0.98481673] actual score: [1.]
# Model Score: [0.9584755] actual score: [1.]
# Model Score: [0.92098117] actual score: [1.]
# Model Score: [0.9451357] actual score: [1.]
# Model Score: [0.9823283] actual score: [1.]
# Model Score: [0.03763752] actual score: [0.]
# Model Score: [0.03675269] actual score: [0.]
# Model Score: [0.20370798] actual score: [0.]
# Model Score: [0.998582] actual score: [1.]
# Model Score: [0.04284298] actual score: [1.]
# Model Score: [0.9425974] actual score: [1.]
# Model Score: [0.99412125] actual score: [1.]
# Model Score: [0.03605131] actual score: [0.]
# Model Score: [0.73816526] actual score: [1.]
# Model Score: [0.03717385] actual score: [0.]
# Model Score: [0.75087976] actual score: [1.]
# Model Score: [0.03871013] actual score: [0.]
# Model Score: [0.03633502] actual score: [0.]
# Model Score: [0.896082] actual score: [1.]
# Model Score: [0.03797042] actual score: [0.]
# Model Score: [0.991172] actual score: [1.]
# Model Score: [0.03978543] actual score: [0.]
# Model Score: [0.9192176] actual score: [1.]
# Model Score: [0.97900134] actual score: [1.]
# Model Score: [0.0389245] actual score: [0.]
# Model Score: [0.96122324] actual score: [1.]
# Model Score: [0.24576412] actual score: [0.]
# Model Score: [0.03735799] actual score: [0.]
# Model Score: [0.9804842] actual score: [1.]
# Model Score: [0.83306485] actual score: [1.]
# Model Score: [0.0338926] actual score: [0.]
# Model Score: [0.03551494] actual score: [0.]
# Model Score: [0.0379828] actual score: [0.]
# Model Score: [0.53179854] actual score: [1.]
# Model Score: [0.9968194] actual score: [1.]
# Model Score: [0.9427916] actual score: [1.]
# Model Score: [0.7016627] actual score: [1.]
# Model Score: [0.03626332] actual score: [0.]
# Model Score: [0.98880917] actual score: [1.]
# Model Score: [0.778879] actual score: [1.]
# Model Score: [0.03776668] actual score: [0.]
# Model Score: [0.03893434] actual score: [0.]
# Model Score: [0.03511472] actual score: [0.]
# Model Score: [0.9922752] actual score: [1.]
# Model Score: [0.97151655] actual score: [1.]
# Model Score: [0.9025988] actual score: [1.]
# Model Score: [0.03531036] actual score: [0.]
# Model Score: [0.03994728] actual score: [0.]
# Model Score: [0.03594764] actual score: [0.]
# Model Score: [0.03681169] actual score: [0.]
# Model Score: [0.03594441] actual score: [0.]
# Model Score: [0.9713301] actual score: [1.]
# Model Score: [0.82644045] actual score: [1.]
# Model Score: [0.9444195] actual score: [1.]
# Model Score: [0.03686887] actual score: [0.]
# Model Score: [0.03755512] actual score: [0.]
# Model Score: [0.03789676] actual score: [0.]
# Model Score: [0.98179203] actual score: [1.]
# Model Score: [0.03708164] actual score: [0.]
# Model Score: [0.03723926] actual score: [0.]
# Model Score: [0.04017198] actual score: [0.]
# Model Score: [0.7412505] actual score: [1.]
# Model Score: [0.0389213] actual score: [0.]
# Model Score: [0.8571725] actual score: [1.]
# Model Score: [0.03615807] actual score: [0.]
# Model Score: [0.03713875] actual score: [0.]
# Model Score: [0.98113155] actual score: [1.]
# Model Score: [0.95689416] actual score: [1.]
# Model Score: [0.05463851] actual score: [0.]
# Model Score: [0.03998164] actual score: [1.]
# Model Score: [0.03853374] actual score: [0.]
# Model Score: [0.7778397] actual score: [1.]
# Model Score: [0.04781115] actual score: [0.]
# Model Score: [0.99462587] actual score: [1.]
# Model Score: [0.03768172] actual score: [0.]
# Model Score: [0.98983115] actual score: [1.]
# Model Score: [0.99069184] actual score: [1.]
# Model Score: [0.97788644] actual score: [1.]
# Model Score: [0.03648286] actual score: [0.]
# Model Score: [0.85654217] actual score: [1.]
# Model Score: [0.99767023] actual score: [1.]
# Model Score: [0.03760294] actual score: [0.]
# Model Score: [0.03710137] actual score: [1.]
# Model Score: [0.06710124] actual score: [0.]
# Model Score: [0.7822597] actual score: [1.]
# Model Score: [0.04130666] actual score: [0.]
# Model Score: [0.03622475] actual score: [0.]
# Model Score: [0.72326803] actual score: [1.]
# Model Score: [0.07725964] actual score: [0.]
# Model Score: [0.0378734] actual score: [0.]
# Model Score: [0.03575249] actual score: [0.]
# Model Score: [0.95354325] actual score: [1.]
# Model Score: [0.03715108] actual score: [0.]
# Model Score: [0.03841862] actual score: [0.]
# Model Score: [0.965758] actual score: [1.]
# Model Score: [0.94293225] actual score: [1.]
# Model Score: [0.03770384] actual score: [0.]
# Model Score: [0.97567797] actual score: [1.]
# Model Score: [0.9925598] actual score: [1.]
# Model Score: [0.96103036] actual score: [1.]
# Model Score: [0.94307727] actual score: [1.]
# Model Score: [0.96360683] actual score: [1.]
# Model Score: [0.03504151] actual score: [0.]
# Model Score: [0.74928135] actual score: [1.]
# Model Score: [0.03626072] actual score: [0.]
# Model Score: [0.7274164] actual score: [1.]
# Model Score: [0.9884863] actual score: [1.]
# Model Score: [0.03905699] actual score: [0.]
# Model Score: [0.03563632] actual score: [0.]
# Model Score: [0.875796] actual score: [1.]
# Model Score: [0.37720892] actual score: [1.]
# Model Score: [0.9874756] actual score: [1.]
# Model Score: [0.86734796] actual score: [0.]
# Model Score: [0.03984813] actual score: [1.]
# Model Score: [0.9809445] actual score: [1.]
# Model Score: [0.99520594] actual score: [1.]
# Model Score: [0.9950453] actual score: [1.]
# Model Score: [0.03574041] actual score: [0.]
# Model Score: [0.98505175] actual score: [1.]
# Model Score: [0.9469803] actual score: [1.]
# Model Score: [0.98930043] actual score: [1.]
# Model Score: [0.86339843] actual score: [1.]
# Model Score: [0.03718787] actual score: [0.]
# Model Score: [0.57999396] actual score: [1.]
# Model Score: [0.8581389] actual score: [1.]
# Model Score: [0.80819464] actual score: [1.]
# Model Score: [0.85746616] actual score: [1.]
# Model Score: [0.03553914] actual score: [0.]
# Model Score: [0.03761525] actual score: [0.]
# Model Score: [0.03753796] actual score: [0.]
# Model Score: [0.9988538] actual score: [1.]
# Model Score: [0.96566266] actual score: [1.]
# Model Score: [0.93863255] actual score: [1.]
# Model Score: [0.62166137] actual score: [0.]
# Model Score: [0.03851055] actual score: [1.]
# Model Score: [0.0583475] actual score: [0.]
# Model Score: [0.03642328] actual score: [0.]
# Model Score: [0.97705483] actual score: [1.]
# Model Score: [0.96952796] actual score: [1.]
# Model Score: [0.03654421] actual score: [0.]
# Model Score: [0.89288116] actual score: [1.]
# Model Score: [0.04238] actual score: [0.]
# Model Score: [0.978986] actual score: [1.]
# Model Score: [0.6362447] actual score: [0.]
# Model Score: [0.24601246] actual score: [0.]
# Model Score: [0.03769238] actual score: [0.]
# Model Score: [0.5981794] actual score: [0.]
# Model Score: [0.9903554] actual score: [1.]
# Model Score: [0.0361013] actual score: [0.]
# Model Score: [0.98705274] actual score: [1.]
# Model Score: [0.03765425] actual score: [0.]
# Model Score: [0.03591935] actual score: [0.]
# Model Score: [0.03649824] actual score: [0.]
# Model Score: [0.03789153] actual score: [0.]
# Model Score: [0.03822151] actual score: [0.]
# Model Score: [0.03702603] actual score: [0.]
# Model Score: [0.03754801] actual score: [0.]
# Model Score: [0.98461795] actual score: [1.]
# Model Score: [0.9663223] actual score: [1.]
# Model Score: [0.84261245] actual score: [1.]
# Model Score: [0.09652115] actual score: [0.]
# Model Score: [0.03737487] actual score: [0.]
# Model Score: [0.03522388] actual score: [0.]
# Model Score: [0.9949951] actual score: [1.]
