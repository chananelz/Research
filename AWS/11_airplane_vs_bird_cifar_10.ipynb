# %%
import os
import matplotlib.pyplot as plt
import random
import numpy as np
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.datasets import cifar10
from keras.layers import Add, Dense, Activation, BatchNormalization, Conv2D
from keras.layers import Flatten
from keras.layers.convolutional import MaxPooling2D
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils
from keras.initializers import glorot_uniform
# %matplotlib inline

# %%
model_type = 'vgg16'

# %%
model_home_dir = os.path.join(os.getcwd(), 'CNN_TASK_ODED',"model_type")
print(model_home_dir)
if not os.path.isdir(model_home_dir):
    print('Inside mkdir')
    os.makedirs(model_home_dir)
# Out:
# /content/CNN_TASK_ODED/model_type
# Inside mkdir

# %%
#Defining Variables

#Data set information
DATASET = 'cifar-10'
num_classes = 2
input_shape=(32,32,3)
epochs = 200
lrate = 0.01
decay = lrate/epochs
batch_size = 32
seed = 7
np.random.seed(seed)

validate_dir = os.path.join("data","test")
train_dir = os.path.join("data","train")

# Prepare model model saving directory.
save_dir = os.path.join(model_home_dir, 'saved_models')

model_name = DATASET+'_'+'%s_model.{epoch:03d}.h5' % model_type

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print("Model Type: ",model_type)
print("Model File: ",filepath)
# Out:
# Model Type:  vgg16
# Model File:  /content/CNN_TASK_ODED/model_type/saved_models/cifar-10_vgg16_model.{epoch:03d}.h5

# %%
import numpy

(X_train, y_train),(X_test,y_test) = cifar10.load_data()
X_train.shape, X_test.shape, X_train.shape[1:],X_train.dtype

class_0_index = np.where(y_train.reshape(-1) == 0)
X_train_class_0 = X_train[class_0_index]
y_train_class_0 = y_train[class_0_index]

class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# print("------------------y_train_class_0-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train_class_0[i])
#     plt.xlabel(class_names[y_train_class_0[i][0]])
# plt.show()

class_2_index = np.where(y_train.reshape(-1) == 2)
X_train_class_2 = X_train[class_2_index]
y_train_class_2 = y_train[class_2_index]

# print("------------------y_train_class_2-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train_class_2[i])
#     plt.xlabel(class_names[y_train_class_2[i][0]])
# plt.show()


X_train = np.concatenate((X_train_class_0, X_train_class_2))
y_train = np.concatenate((y_train_class_0, y_train_class_2)).reshape(-1,1)

# print("------------------concatenate train-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     j = random.randint(0,10000)
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train[j])
#     plt.xlabel(class_names[y_train[j][0]])
# plt.show()

# ---------------------------------------------------------------------------

class_0_index = np.where(y_test.reshape(-1) == 0)
X_test_class_0 = X_test[class_0_index]
y_test_class_0 = y_test[class_0_index]

# print("------------------y_test_class_0-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test_class_0[i])
#     plt.xlabel(class_names[y_test_class_0[i][0]])
# plt.show()

class_2_index = np.where(y_test.reshape(-1) == 2)
X_test_class_2 = X_test[class_2_index]
y_test_class_2 = y_test[class_2_index]


# print("------------------y_test_class_2-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test_class_2[i])
#     plt.xlabel(class_names[y_test_class_2[i][0]])
# plt.show()


X_test = np.concatenate((X_test_class_0, X_test_class_2))
y_test = np.concatenate((y_test_class_0, y_test_class_2)).reshape(-1,1)

# print("------------------concatenate test-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     j = random.randint(0,2000) 
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test[j])
#     plt.xlabel(class_names[y_test[j][0]])
# plt.show()

print(y_train.shape, y_test.shape)
print(X_train.shape, X_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step
# (10000, 1) (2000, 1)
# (10000, 32, 32, 3) (2000, 32, 32, 3)

# %%
y_train = np.where(y_train > 0, 1, 0)
y_test = np.where(y_test > 0, 1, 0)
class_names = ['airplane',  'bird']

print(y_train.shape, y_test.shape)
# Out:
# (10000, 1) (2000, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

X = np.concatenate((X_test, X_train))
Y = np.concatenate((y_test, y_train)).reshape(-1,1)

# X, y = shuffle(X, Y, random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.15)

print(y_train.shape, y_test.shape)
print(X_train.shape, X_test.shape)

print("------------------concatenate train-------------------")
plt.figure(figsize=(10,10))
for i in range(25):
    j = random.randint(0,10200)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[j])
    plt.xlabel(class_names[y_train[j][0]])
plt.show()

print("------------------concatenate test-------------------")
plt.figure(figsize=(10,10))
for i in range(25):
    j = random.randint(0,1800) 
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_test[j])
    plt.xlabel(class_names[y_test[j][0]])
plt.show()
# Out:
# (10200, 1) (1800, 1)
# (10200, 32, 32, 3) (1800, 32, 32, 3)
# ------------------concatenate train-------------------
# ------------------concatenate test-------------------

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.
X_test = X_test / 255.

X_train_mean = np.mean(X_train)
X_train -= X_train_mean
X_test_mean = np.mean(X_test)
X_test -= X_test_mean

y_train = np_utils.to_categorical(y_train,)
y_test = np_utils.to_categorical(y_test,)
y_train = np.delete(y_train,1,1)
y_test = np.delete(y_test,1,1)
print(y_train.shape, y_test.shape)
# Out:
# (10200, 1) (1800, 1)

# %%
from tensorflow.keras.layers import Dropout
def vgg16(input_shape=(32,32,3), num_classes=2):
  model = Sequential()
  model.add(Conv2D(input_shape=input_shape,filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))


  model.add(Dropout(0.8))

  model.add(Conv2D(filters=16, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=16, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Flatten())
  model.add(Dense(units=4096,activation="relu"))
  model.add(Dense(units=4096,activation="relu"))
  model.add(Dense(units=1, activation="sigmoid"))

  return model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
# Prepare callbacks for model saving and for learning rate adjustment.

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler,early_stopping]

# %%
 model = vgg16(input_shape,num_classes)

# Compile model

# optimizer = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss= 'binary_crossentropy' , optimizer=optimizer, metrics=['accuracy'])
print("Model Summary of ",model_type)
print(model.summary())
# Out:
# Model Summary of  vgg16
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 16)        9232
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          4640
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 32)          9248
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 32)          9248
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 64)          18496
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 64)          36928
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 18,003,841
# Trainable params: 18,003,841
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Score trained model.
history = model.fit(X_train, y_train,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=(X_test, y_test),
      shuffle=True,
      callbacks=callbacks)
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Learning rate:  0.001
# Epoch 1/200
# 319/319 [==============================] - ETA: 0s - loss: 0.4904 - accuracy: 0.7730
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 12s 14ms/step - loss: 0.4904 - accuracy: 0.7730 - val_loss: 0.4250 - val_accuracy: 0.8183 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/200
# 317/319 [============================>.] - ETA: 0s - loss: 0.3751 - accuracy: 0.8408
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.3746 - accuracy: 0.8413 - val_loss: 0.4627 - val_accuracy: 0.7811 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.3450 - accuracy: 0.8524
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.3450 - accuracy: 0.8524 - val_loss: 0.3425 - val_accuracy: 0.8522 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 315/319 [============================>.] - ETA: 0s - loss: 0.3352 - accuracy: 0.8593
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.3360 - accuracy: 0.8588 - val_loss: 0.3360 - val_accuracy: 0.8622 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 315/319 [============================>.] - ETA: 0s - loss: 0.3143 - accuracy: 0.8664
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.3136 - accuracy: 0.8669 - val_loss: 0.3228 - val_accuracy: 0.8583 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.3096 - accuracy: 0.8693
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.3100 - accuracy: 0.8690 - val_loss: 0.3158 - val_accuracy: 0.8750 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2929 - accuracy: 0.8773
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.2943 - accuracy: 0.8768 - val_loss: 0.3459 - val_accuracy: 0.8667 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2854 - accuracy: 0.8839
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2848 - accuracy: 0.8840 - val_loss: 0.3722 - val_accuracy: 0.8478 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2797 - accuracy: 0.8854
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2789 - accuracy: 0.8858 - val_loss: 0.3037 - val_accuracy: 0.8667 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/200
# 319/319 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.8836
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2784 - accuracy: 0.8836 - val_loss: 0.2947 - val_accuracy: 0.8894 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2617 - accuracy: 0.8951
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.2616 - accuracy: 0.8950 - val_loss: 0.2844 - val_accuracy: 0.8889 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2526 - accuracy: 0.8949
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.2534 - accuracy: 0.8948 - val_loss: 0.3192 - val_accuracy: 0.8800 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2491 - accuracy: 0.9003
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2490 - accuracy: 0.9002 - val_loss: 0.2839 - val_accuracy: 0.8922 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2407 - accuracy: 0.9057
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2402 - accuracy: 0.9061 - val_loss: 0.3082 - val_accuracy: 0.8933 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2399 - accuracy: 0.9016
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2390 - accuracy: 0.9021 - val_loss: 0.2877 - val_accuracy: 0.8800 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/200
# 318/319 [============================>.] - ETA: 0s - loss: 0.2258 - accuracy: 0.9095
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 13ms/step - loss: 0.2258 - accuracy: 0.9093 - val_loss: 0.2696 - val_accuracy: 0.8944 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2263 - accuracy: 0.9104
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 13ms/step - loss: 0.2262 - accuracy: 0.9105 - val_loss: 0.2735 - val_accuracy: 0.8911 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.2267 - accuracy: 0.9092
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2269 - accuracy: 0.9094 - val_loss: 0.3007 - val_accuracy: 0.8817 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/200
# 315/319 [============================>.] - ETA: 0s - loss: 0.2085 - accuracy: 0.9153
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2084 - accuracy: 0.9153 - val_loss: 0.2979 - val_accuracy: 0.8839 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9206
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.1991 - accuracy: 0.9204 - val_loss: 0.2693 - val_accuracy: 0.8972 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.1932 - accuracy: 0.9220
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.1941 - accuracy: 0.9215 - val_loss: 0.2799 - val_accuracy: 0.9017 - lr: 0.0010
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2696 - accuracy: 0.8944
# Test loss: 0.26961299777030945
# Test accuracy: 0.894444465637207

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
from sklearn.metrics import roc_curve, auc

y_pred = model.predict(X_test).ravel()

nn_fpr_keras, nn_tpr_keras, nn_thresholds_keras = roc_curve(y_test, y_pred)
auc_keras = auc(nn_fpr_keras, nn_tpr_keras)
plt.plot(nn_fpr_keras, nn_tpr_keras, marker='.', label='Neural Network (auc = %0.3f)' % auc_keras)
plt.title('ROC Curve')
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.show()

print(auc_keras)
# Out:
# 57/57 [==============================] - 0s 3ms/step
# 0.9558118678321368

# %%
from matplotlib import pyplot
predict_x=model.predict(X_test) 

airplane_index = np.where(y_test.reshape(-1) == 0.)
airplane  = predict_x[airplane_index]

bird_index = np.where(y_test.reshape(-1) == 1.)
bird = predict_x[bird_index]



bins = np.linspace(0, 1, 100)

pyplot.hist(airplane, bins, alpha=0.5, label='airplane')
pyplot.hist(bird, bins, alpha=0.5, label='bird')
pyplot.legend(loc='upper right')
pyplot.show()
# Out:
# 57/57 [==============================] - 0s 3ms/step

# %%
for X,Y in zip(predict_x,y_test):
    print("Model Score:", X, "actual score:", Y)
# Out:
# Model Score: [0.02968447] actual score: [0.]
# Model Score: [0.19379903] actual score: [0.]
# Model Score: [0.02250065] actual score: [0.]
# Model Score: [0.7408528] actual score: [0.]
# Model Score: [0.8365811] actual score: [1.]
# Model Score: [0.9364376] actual score: [1.]
# Model Score: [0.13578005] actual score: [1.]
# Model Score: [0.97938204] actual score: [1.]
# Model Score: [0.22718802] actual score: [0.]
# Model Score: [0.03664371] actual score: [1.]
# Model Score: [0.9931524] actual score: [1.]
# Model Score: [0.544103] actual score: [0.]
# Model Score: [0.99863976] actual score: [1.]
# Model Score: [0.01637437] actual score: [0.]
# Model Score: [0.6903386] actual score: [0.]
# Model Score: [0.6353028] actual score: [0.]
# Model Score: [0.9122487] actual score: [1.]
# Model Score: [0.15091814] actual score: [0.]
# Model Score: [0.98925775] actual score: [1.]
# Model Score: [0.895468] actual score: [0.]
# Model Score: [0.9479602] actual score: [1.]
# Model Score: [0.05852589] actual score: [0.]
# Model Score: [0.5451894] actual score: [0.]
# Model Score: [0.94237703] actual score: [1.]
# Model Score: [0.1690168] actual score: [1.]
# Model Score: [0.00400899] actual score: [0.]
# Model Score: [0.7549635] actual score: [1.]
# Model Score: [0.9700243] actual score: [1.]
# Model Score: [0.09150789] actual score: [0.]
# Model Score: [0.96827984] actual score: [1.]
# Model Score: [0.8456712] actual score: [1.]
# Model Score: [0.99851304] actual score: [1.]
# Model Score: [0.01944051] actual score: [0.]
# Model Score: [0.9996124] actual score: [1.]
# Model Score: [0.03669035] actual score: [0.]
# Model Score: [0.71866673] actual score: [1.]
# Model Score: [0.09008295] actual score: [0.]
# Model Score: [0.07434838] actual score: [0.]
# Model Score: [0.9940923] actual score: [1.]
# Model Score: [0.82634145] actual score: [1.]
# Model Score: [0.9310011] actual score: [1.]
# Model Score: [0.9736647] actual score: [1.]
# Model Score: [0.0068742] actual score: [0.]
# Model Score: [0.43306622] actual score: [0.]
# Model Score: [0.5442378] actual score: [1.]
# Model Score: [0.906083] actual score: [1.]
# Model Score: [0.07738233] actual score: [0.]
# Model Score: [0.01773526] actual score: [0.]
# Model Score: [0.9846438] actual score: [1.]
# Model Score: [0.55580014] actual score: [0.]
# Model Score: [0.0128341] actual score: [0.]
# Model Score: [0.9451518] actual score: [1.]
# Model Score: [0.03290394] actual score: [0.]
# Model Score: [0.01742915] actual score: [0.]
# Model Score: [0.6957264] actual score: [1.]
# Model Score: [0.00754012] actual score: [0.]
# Model Score: [0.98320377] actual score: [1.]
# Model Score: [0.8365519] actual score: [1.]
# Model Score: [0.94897527] actual score: [1.]
# Model Score: [0.01725084] actual score: [0.]
# Model Score: [0.9935846] actual score: [1.]
# Model Score: [0.9945623] actual score: [1.]
# Model Score: [0.5561741] actual score: [0.]
# Model Score: [0.9781722] actual score: [1.]
# Model Score: [0.02282004] actual score: [0.]
# Model Score: [0.8540784] actual score: [1.]
# Model Score: [0.30943602] actual score: [0.]
# Model Score: [0.9790003] actual score: [1.]
# Model Score: [0.92246157] actual score: [1.]
# Model Score: [0.49479505] actual score: [1.]
# Model Score: [0.01086643] actual score: [0.]
# Model Score: [0.01115526] actual score: [0.]
# Model Score: [0.77407575] actual score: [1.]
# Model Score: [0.05536773] actual score: [0.]
# Model Score: [0.9896025] actual score: [1.]
# Model Score: [0.05806552] actual score: [0.]
# Model Score: [0.8906511] actual score: [1.]
# Model Score: [0.00679572] actual score: [0.]
# Model Score: [0.9791464] actual score: [1.]
# Model Score: [0.9137729] actual score: [1.]
# Model Score: [0.9992754] actual score: [1.]
# Model Score: [0.641098] actual score: [1.]
# Model Score: [0.19297077] actual score: [0.]
# Model Score: [0.6587328] actual score: [1.]
# Model Score: [0.5276067] actual score: [1.]
# Model Score: [0.96540004] actual score: [1.]
# Model Score: [0.10304032] actual score: [0.]
# Model Score: [0.9775614] actual score: [1.]
# Model Score: [0.744048] actual score: [1.]
# Model Score: [0.47511104] actual score: [0.]
# Model Score: [0.03447764] actual score: [0.]
# Model Score: [0.6414801] actual score: [1.]
# Model Score: [0.99523133] actual score: [1.]
# Model Score: [0.31095895] actual score: [0.]
# Model Score: [0.07854699] actual score: [0.]
# Model Score: [0.92640394] actual score: [1.]
# Model Score: [0.00030145] actual score: [0.]
# Model Score: [0.8489316] actual score: [0.]
# Model Score: [0.9934908] actual score: [1.]
# Model Score: [0.01943217] actual score: [0.]
# Model Score: [0.9890197] actual score: [1.]
# Model Score: [0.03390531] actual score: [0.]
# Model Score: [0.05493651] actual score: [0.]
# Model Score: [0.95447373] actual score: [1.]
# Model Score: [0.90610474] actual score: [1.]
# Model Score: [0.99779236] actual score: [1.]
# Model Score: [0.0389201] actual score: [0.]
# Model Score: [0.01528194] actual score: [0.]
# Model Score: [0.0538327] actual score: [0.]
# Model Score: [0.9702811] actual score: [1.]
# Model Score: [0.01054335] actual score: [0.]
# Model Score: [0.03763195] actual score: [0.]
# Model Score: [0.23194371] actual score: [0.]
# Model Score: [0.04085412] actual score: [0.]
# Model Score: [0.13162687] actual score: [0.]
# Model Score: [0.99950194] actual score: [1.]
# Model Score: [0.07822182] actual score: [0.]
# Model Score: [0.82028157] actual score: [0.]
# Model Score: [0.84889656] actual score: [1.]
# Model Score: [0.9997887] actual score: [1.]
# Model Score: [0.99900705] actual score: [1.]
# Model Score: [0.7450743] actual score: [1.]
# Model Score: [0.9775548] actual score: [1.]
# Model Score: [0.01902761] actual score: [0.]
# Model Score: [0.6929272] actual score: [1.]
# Model Score: [0.96949244] actual score: [1.]
# Model Score: [0.9988121] actual score: [1.]
# Model Score: [0.9752005] actual score: [1.]
# Model Score: [0.94178444] actual score: [0.]
# Model Score: [0.00954019] actual score: [0.]
# Model Score: [0.99847287] actual score: [1.]
# Model Score: [0.97199935] actual score: [1.]
# Model Score: [0.83644414] actual score: [1.]
# Model Score: [0.97546583] actual score: [1.]
# Model Score: [0.99861217] actual score: [1.]
# Model Score: [0.927864] actual score: [0.]
# Model Score: [0.9463713] actual score: [1.]
# Model Score: [0.0102519] actual score: [0.]
# Model Score: [0.40063038] actual score: [0.]
# Model Score: [0.02351914] actual score: [0.]
# Model Score: [0.04346226] actual score: [0.]
# Model Score: [0.83762497] actual score: [0.]
# Model Score: [0.03110488] actual score: [0.]
# Model Score: [0.999848] actual score: [1.]
# Model Score: [0.98225594] actual score: [1.]
# Model Score: [0.55535525] actual score: [0.]
# Model Score: [0.17776282] actual score: [0.]
# Model Score: [0.9776152] actual score: [1.]
# Model Score: [0.6743169] actual score: [0.]
# Model Score: [0.9307001] actual score: [1.]
# Model Score: [0.7161786] actual score: [1.]
# Model Score: [0.11016975] actual score: [0.]
# Model Score: [0.99832684] actual score: [1.]
# Model Score: [0.9963355] actual score: [1.]
# Model Score: [0.96505183] actual score: [1.]
# Model Score: [0.97421896] actual score: [0.]
# Model Score: [0.94204134] actual score: [1.]
# Model Score: [0.02817947] actual score: [0.]
# Model Score: [0.8908745] actual score: [1.]
# Model Score: [0.06896298] actual score: [0.]
# Model Score: [0.9900559] actual score: [1.]
# Model Score: [0.01454903] actual score: [0.]
# Model Score: [0.92445683] actual score: [1.]
# Model Score: [0.20320185] actual score: [1.]
# Model Score: [0.97593147] actual score: [1.]
# Model Score: [0.03158057] actual score: [0.]
# Model Score: [0.31896615] actual score: [1.]
# Model Score: [0.6827411] actual score: [1.]
# Model Score: [0.99997354] actual score: [1.]
# Model Score: [0.01320823] actual score: [0.]
# Model Score: [0.73809016] actual score: [0.]
# Model Score: [0.02376329] actual score: [0.]
# Model Score: [0.58139044] actual score: [1.]
# Model Score: [0.23067388] actual score: [1.]
# Model Score: [7.1226605e-05] actual score: [0.]
# Model Score: [0.00356247] actual score: [0.]
# Model Score: [0.27990243] actual score: [0.]
# Model Score: [0.68304694] actual score: [1.]
# Model Score: [0.01556207] actual score: [0.]
# Model Score: [0.0150403] actual score: [0.]
# Model Score: [0.6581114] actual score: [0.]
# Model Score: [0.01557315] actual score: [0.]
# Model Score: [0.0527255] actual score: [0.]
# Model Score: [0.77849805] actual score: [1.]
# Model Score: [0.6367588] actual score: [1.]
# Model Score: [0.01012415] actual score: [0.]
# Model Score: [0.04956411] actual score: [0.]
# Model Score: [0.40436223] actual score: [1.]
# Model Score: [0.03091264] actual score: [0.]
# Model Score: [0.05516071] actual score: [0.]
# Model Score: [0.94620425] actual score: [1.]
# Model Score: [0.9869713] actual score: [1.]
# Model Score: [0.89547145] actual score: [1.]
# Model Score: [0.9998529] actual score: [1.]
# Model Score: [0.991098] actual score: [1.]
# Model Score: [0.71440995] actual score: [0.]
# Model Score: [0.03337694] actual score: [0.]
# Model Score: [0.98703706] actual score: [1.]
# Model Score: [0.9459868] actual score: [1.]
# Model Score: [0.99892956] actual score: [1.]
# Model Score: [0.00867958] actual score: [0.]
# Model Score: [0.16427743] actual score: [0.]
# Model Score: [0.3225782] actual score: [0.]
# Model Score: [0.08600053] actual score: [0.]
# Model Score: [0.9899741] actual score: [1.]
# Model Score: [0.9813579] actual score: [1.]
# Model Score: [0.8743206] actual score: [1.]
# Model Score: [0.9996393] actual score: [1.]
# Model Score: [0.7461701] actual score: [1.]
# Model Score: [0.897172] actual score: [1.]
# Model Score: [0.5404364] actual score: [1.]
# Model Score: [0.9999033] actual score: [1.]
# Model Score: [0.02026049] actual score: [0.]
# Model Score: [0.0181562] actual score: [0.]
# Model Score: [0.03630023] actual score: [0.]
# Model Score: [0.01359937] actual score: [0.]
# Model Score: [0.8614915] actual score: [1.]
# Model Score: [0.9257912] actual score: [1.]
# Model Score: [0.95686877] actual score: [1.]
# Model Score: [0.999954] actual score: [1.]
# Model Score: [0.9980819] actual score: [1.]
# Model Score: [0.7685911] actual score: [1.]
# Model Score: [0.04556483] actual score: [0.]
# Model Score: [0.9021937] actual score: [0.]
# Model Score: [0.01528484] actual score: [0.]
# Model Score: [0.64906305] actual score: [1.]
# Model Score: [0.6934054] actual score: [1.]
# Model Score: [0.99283373] actual score: [1.]
# Model Score: [0.95613825] actual score: [1.]
# Model Score: [0.9218988] actual score: [1.]
# Model Score: [0.7669988] actual score: [1.]
# Model Score: [0.20162772] actual score: [0.]
# Model Score: [0.01205774] actual score: [0.]
# Model Score: [0.2843535] actual score: [0.]
# Model Score: [0.6468163] actual score: [0.]
# Model Score: [0.8719633] actual score: [1.]
# Model Score: [0.14524299] actual score: [1.]
# Model Score: [0.11268523] actual score: [0.]
# Model Score: [0.981415] actual score: [1.]
# Model Score: [0.98545235] actual score: [0.]
# Model Score: [0.7392641] actual score: [1.]
# Model Score: [0.03958886] actual score: [0.]
# Model Score: [0.0922075] actual score: [0.]
# Model Score: [0.76245683] actual score: [1.]
# Model Score: [0.9716844] actual score: [1.]
# Model Score: [0.2079553] actual score: [0.]
# Model Score: [0.94926333] actual score: [1.]
# Model Score: [0.8742677] actual score: [0.]
# Model Score: [0.01182444] actual score: [0.]
# Model Score: [0.994635] actual score: [1.]
# Model Score: [0.57882] actual score: [0.]
# Model Score: [0.9993512] actual score: [1.]
# Model Score: [0.997647] actual score: [1.]
# Model Score: [0.84022415] actual score: [1.]
# Model Score: [0.04776132] actual score: [1.]
# Model Score: [0.7849028] actual score: [1.]
# Model Score: [0.1525621] actual score: [0.]
# Model Score: [0.9670737] actual score: [1.]
# Model Score: [0.35053194] actual score: [1.]
# Model Score: [0.70811] actual score: [0.]
# Model Score: [0.9944635] actual score: [1.]
# Model Score: [0.903331] actual score: [1.]
# Model Score: [0.6668182] actual score: [1.]
# Model Score: [0.85211664] actual score: [1.]
# Model Score: [0.85652035] actual score: [1.]
# Model Score: [0.8707358] actual score: [1.]
# Model Score: [0.03142733] actual score: [0.]
# Model Score: [0.04044458] actual score: [0.]
# Model Score: [0.02468253] actual score: [0.]
# Model Score: [0.05650512] actual score: [0.]
# Model Score: [0.34936154] actual score: [0.]
# Model Score: [0.00725764] actual score: [1.]
# Model Score: [0.01913243] actual score: [0.]
# Model Score: [0.03078421] actual score: [0.]
# Model Score: [0.05200289] actual score: [0.]
# Model Score: [0.02982558] actual score: [0.]
# Model Score: [0.9938176] actual score: [1.]
# Model Score: [0.03499893] actual score: [0.]
# Model Score: [0.01491858] actual score: [0.]
# Model Score: [0.18108313] actual score: [0.]
# Model Score: [0.66009605] actual score: [1.]
# Model Score: [0.05822338] actual score: [0.]
# Model Score: [0.99695706] actual score: [1.]
# Model Score: [0.50589013] actual score: [0.]
# Model Score: [0.07569968] actual score: [0.]
# Model Score: [0.00978535] actual score: [0.]
# Model Score: [0.9717054] actual score: [1.]
# Model Score: [0.0290729] actual score: [0.]
# Model Score: [0.9828509] actual score: [1.]
# Model Score: [0.7417656] actual score: [1.]
# Model Score: [0.08766474] actual score: [0.]
# Model Score: [0.8648442] actual score: [1.]
# Model Score: [0.9932394] actual score: [1.]
# Model Score: [0.01131439] actual score: [0.]
# Model Score: [0.9915194] actual score: [1.]
# Model Score: [0.05396706] actual score: [0.]
# Model Score: [0.99974304] actual score: [1.]
# Model Score: [0.9670224] actual score: [1.]
# Model Score: [0.6288738] actual score: [1.]
# Model Score: [0.04954703] actual score: [0.]
# Model Score: [0.00396837] actual score: [0.]
# Model Score: [0.9732991] actual score: [1.]
# Model Score: [0.819924] actual score: [1.]
# Model Score: [0.0113689] actual score: [0.]
# Model Score: [0.6420501] actual score: [0.]
# Model Score: [0.81887454] actual score: [0.]
# Model Score: [0.02489659] actual score: [0.]
# Model Score: [0.8866871] actual score: [1.]
# Model Score: [0.7547261] actual score: [0.]
# Model Score: [0.9999981] actual score: [1.]
# Model Score: [0.01093715] actual score: [0.]
# Model Score: [0.01898117] actual score: [0.]
# Model Score: [0.00369291] actual score: [0.]
# Model Score: [0.09989036] actual score: [0.]
# Model Score: [0.01102666] actual score: [0.]
# Model Score: [0.9996362] actual score: [1.]
# Model Score: [0.00414788] actual score: [0.]
# Model Score: [0.9959545] actual score: [1.]
# Model Score: [0.02119012] actual score: [0.]
# Model Score: [0.6386656] actual score: [1.]
# Model Score: [0.8972131] actual score: [1.]
# Model Score: [0.9629572] actual score: [1.]
# Model Score: [0.99997306] actual score: [1.]
# Model Score: [0.9926157] actual score: [1.]
# Model Score: [0.27757666] actual score: [0.]
# Model Score: [0.02077842] actual score: [0.]
# Model Score: [0.6297114] actual score: [1.]
# Model Score: [0.98672116] actual score: [1.]
# Model Score: [0.02448678] actual score: [0.]
# Model Score: [0.10900952] actual score: [1.]
# Model Score: [0.00293366] actual score: [0.]
# Model Score: [0.41951522] actual score: [0.]
# Model Score: [0.01873401] actual score: [0.]
# Model Score: [0.03808878] actual score: [0.]
# Model Score: [0.9476782] actual score: [0.]
# Model Score: [0.7987556] actual score: [1.]
# Model Score: [0.02503081] actual score: [1.]
# Model Score: [0.9916754] actual score: [1.]
# Model Score: [0.76062816] actual score: [1.]
# Model Score: [0.97703105] actual score: [1.]
# Model Score: [0.9917596] actual score: [1.]
# Model Score: [0.5594395] actual score: [0.]
# Model Score: [0.97580576] actual score: [1.]
# Model Score: [0.02473275] actual score: [0.]
# Model Score: [0.02921483] actual score: [0.]
# Model Score: [0.99996614] actual score: [1.]
# Model Score: [0.9723689] actual score: [1.]
# Model Score: [0.9288986] actual score: [1.]
# Model Score: [0.46506622] actual score: [0.]
# Model Score: [0.09000717] actual score: [0.]
# Model Score: [0.61753273] actual score: [0.]
# Model Score: [0.83247364] actual score: [1.]
# Model Score: [0.0929011] actual score: [0.]
# Model Score: [0.0260224] actual score: [0.]
# Model Score: [0.9545] actual score: [1.]
# Model Score: [0.53335065] actual score: [0.]
# Model Score: [0.8077147] actual score: [0.]
# Model Score: [0.01295279] actual score: [0.]
# Model Score: [0.99922025] actual score: [1.]
# Model Score: [0.7680157] actual score: [1.]
# Model Score: [0.91935444] actual score: [1.]
# Model Score: [0.49154034] actual score: [0.]
# Model Score: [0.14678583] actual score: [0.]
# Model Score: [0.8821068] actual score: [1.]
# Model Score: [0.9951363] actual score: [1.]
# Model Score: [0.01417048] actual score: [0.]
# Model Score: [0.9514096] actual score: [1.]
# Model Score: [0.7195442] actual score: [1.]
# Model Score: [0.841897] actual score: [1.]
# Model Score: [0.24212074] actual score: [1.]
# Model Score: [0.01572781] actual score: [0.]
# Model Score: [0.00561118] actual score: [0.]
# Model Score: [0.9946267] actual score: [1.]
# Model Score: [0.00522231] actual score: [0.]
# Model Score: [0.9988558] actual score: [1.]
# Model Score: [0.6777098] actual score: [1.]
# Model Score: [0.9471446] actual score: [1.]
# Model Score: [0.9595838] actual score: [1.]
# Model Score: [0.9948067] actual score: [1.]
# Model Score: [0.03027837] actual score: [0.]
# Model Score: [0.9926917] actual score: [1.]
# Model Score: [0.01202501] actual score: [0.]
# Model Score: [0.9074342] actual score: [1.]
# Model Score: [0.9995466] actual score: [1.]
# Model Score: [0.7848771] actual score: [1.]
# Model Score: [0.39654735] actual score: [0.]
# Model Score: [0.2698326] actual score: [0.]
# Model Score: [9.895597e-06] actual score: [0.]
# Model Score: [0.7965159] actual score: [1.]
# Model Score: [0.7504896] actual score: [1.]
# Model Score: [0.01020239] actual score: [0.]
# Model Score: [0.7216448] actual score: [1.]
# Model Score: [0.4783594] actual score: [0.]
# Model Score: [0.88553363] actual score: [1.]
# Model Score: [0.5664722] actual score: [0.]
# Model Score: [0.0141755] actual score: [0.]
# Model Score: [0.9853102] actual score: [1.]
# Model Score: [0.9978446] actual score: [1.]
# Model Score: [0.2824028] actual score: [0.]
# Model Score: [0.13729489] actual score: [0.]
# Model Score: [0.7674136] actual score: [0.]
# Model Score: [0.90692466] actual score: [1.]
# Model Score: [0.73768747] actual score: [1.]
# Model Score: [0.68207157] actual score: [0.]
# Model Score: [0.26616076] actual score: [0.]
# Model Score: [0.0147538] actual score: [0.]
# Model Score: [0.8536181] actual score: [1.]
# Model Score: [0.9973355] actual score: [1.]
# Model Score: [0.03336279] actual score: [0.]
# Model Score: [0.9999385] actual score: [1.]
# Model Score: [0.99947447] actual score: [1.]
# Model Score: [0.41626418] actual score: [1.]
# Model Score: [0.01736574] actual score: [0.]
# Model Score: [0.9246122] actual score: [1.]
# Model Score: [0.99899644] actual score: [1.]
# Model Score: [0.757649] actual score: [1.]
# Model Score: [0.156346] actual score: [0.]
# Model Score: [0.03092809] actual score: [0.]
# Model Score: [0.9962658] actual score: [1.]
# Model Score: [0.01756833] actual score: [0.]
# Model Score: [0.75057876] actual score: [1.]
# Model Score: [0.9820925] actual score: [1.]
# Model Score: [0.9100186] actual score: [1.]
# Model Score: [0.8844358] actual score: [1.]
# Model Score: [0.9976272] actual score: [1.]
# Model Score: [0.01746676] actual score: [0.]
# Model Score: [0.98838425] actual score: [1.]
# Model Score: [0.01119149] actual score: [0.]
# Model Score: [0.01377928] actual score: [0.]
# Model Score: [0.011755] actual score: [0.]
# Model Score: [0.8942313] actual score: [1.]
# Model Score: [0.9163319] actual score: [1.]
# Model Score: [0.07632493] actual score: [0.]
# Model Score: [0.70845443] actual score: [1.]
# Model Score: [0.03406259] actual score: [0.]
# Model Score: [0.9180279] actual score: [1.]
# Model Score: [0.00651816] actual score: [0.]
# Model Score: [0.03182466] actual score: [0.]
# Model Score: [0.9957384] actual score: [1.]
# Model Score: [0.99196106] actual score: [1.]
# Model Score: [0.22346844] actual score: [0.]
# Model Score: [0.01519488] actual score: [0.]
# Model Score: [0.7589586] actual score: [1.]
# Model Score: [0.19041161] actual score: [0.]
# Model Score: [0.3017609] actual score: [1.]
# Model Score: [0.66804916] actual score: [1.]
# Model Score: [0.28349265] actual score: [0.]
# Model Score: [0.6324783] actual score: [1.]
# Model Score: [0.02545658] actual score: [0.]
# Model Score: [0.9970174] actual score: [1.]
# Model Score: [0.02710271] actual score: [0.]
# Model Score: [0.00815624] actual score: [0.]
# Model Score: [0.01547141] actual score: [0.]
# Model Score: [0.99867755] actual score: [1.]
# Model Score: [0.01495114] actual score: [0.]
# Model Score: [0.940361] actual score: [1.]
# Model Score: [0.8547807] actual score: [0.]
# Model Score: [0.9256946] actual score: [1.]
# Model Score: [0.9638995] actual score: [1.]
# Model Score: [0.94471955] actual score: [1.]
# Model Score: [0.17018926] actual score: [0.]
# Model Score: [0.6558481] actual score: [0.]
# Model Score: [0.99881613] actual score: [1.]
# Model Score: [0.00574661] actual score: [0.]
# Model Score: [0.9996569] actual score: [1.]
# Model Score: [0.04646778] actual score: [1.]
# Model Score: [0.99984443] actual score: [1.]
# Model Score: [0.0045317] actual score: [0.]
# Model Score: [0.38438982] actual score: [1.]
# Model Score: [0.9489895] actual score: [1.]
# Model Score: [0.968971] actual score: [1.]
# Model Score: [0.9829298] actual score: [1.]
# Model Score: [0.9982798] actual score: [1.]
# Model Score: [0.9875688] actual score: [1.]
# Model Score: [0.9103157] actual score: [1.]
# Model Score: [0.5836698] actual score: [1.]
# Model Score: [0.96891296] actual score: [1.]
# Model Score: [0.7903196] actual score: [1.]
# Model Score: [0.77202654] actual score: [1.]
# Model Score: [0.15988117] actual score: [0.]
# Model Score: [0.01351668] actual score: [0.]
# Model Score: [0.99760216] actual score: [1.]
# Model Score: [0.99951434] actual score: [1.]
# Model Score: [0.00900798] actual score: [0.]
# Model Score: [0.01181375] actual score: [0.]
# Model Score: [0.83793354] actual score: [1.]
# Model Score: [0.05738318] actual score: [0.]
# Model Score: [0.9997843] actual score: [1.]
# Model Score: [0.7350342] actual score: [0.]
# Model Score: [0.95307255] actual score: [1.]
# Model Score: [0.18653826] actual score: [0.]
# Model Score: [0.02816979] actual score: [0.]
# Model Score: [0.01409729] actual score: [0.]
# Model Score: [0.0114095] actual score: [0.]
# Model Score: [0.87594885] actual score: [1.]
# Model Score: [0.43774745] actual score: [0.]
# Model Score: [0.5675479] actual score: [1.]
# Model Score: [0.5595357] actual score: [0.]
# Model Score: [0.8917966] actual score: [1.]
# Model Score: [0.01130293] actual score: [0.]
# Model Score: [0.8612419] actual score: [1.]
# Model Score: [0.0298955] actual score: [1.]
# Model Score: [0.73751277] actual score: [1.]
# Model Score: [0.02947492] actual score: [0.]
# Model Score: [0.9686846] actual score: [1.]
# Model Score: [0.9952142] actual score: [1.]
# Model Score: [0.970112] actual score: [1.]
# Model Score: [0.9771851] actual score: [1.]
# Model Score: [0.00459643] actual score: [0.]
# Model Score: [0.11866098] actual score: [0.]
# Model Score: [0.14394708] actual score: [0.]
# Model Score: [0.576286] actual score: [1.]
# Model Score: [0.7723279] actual score: [1.]
# Model Score: [0.99281365] actual score: [1.]
# Model Score: [0.9985417] actual score: [1.]
# Model Score: [0.0571318] actual score: [0.]
# Model Score: [0.17269538] actual score: [1.]
# Model Score: [0.99475914] actual score: [1.]
# Model Score: [0.04916779] actual score: [0.]
# Model Score: [0.23201284] actual score: [0.]
# Model Score: [0.03645251] actual score: [0.]
# Model Score: [0.00837044] actual score: [0.]
# Model Score: [0.03140087] actual score: [0.]
# Model Score: [0.01314868] actual score: [0.]
# Model Score: [0.6722137] actual score: [1.]
# Model Score: [0.6552615] actual score: [1.]
# Model Score: [0.9394842] actual score: [1.]
# Model Score: [0.86393476] actual score: [1.]
# Model Score: [0.95171714] actual score: [1.]
# Model Score: [0.25035334] actual score: [0.]
# Model Score: [0.33390105] actual score: [0.]
# Model Score: [0.83595186] actual score: [0.]
# Model Score: [0.99998856] actual score: [1.]
# Model Score: [0.6572542] actual score: [1.]
# Model Score: [0.99362755] actual score: [1.]
# Model Score: [0.57001567] actual score: [1.]
# Model Score: [0.01042534] actual score: [0.]
# Model Score: [0.9999858] actual score: [1.]
# Model Score: [0.05240394] actual score: [0.]
# Model Score: [0.01815257] actual score: [0.]
# Model Score: [0.16081922] actual score: [0.]
# Model Score: [0.1313618] actual score: [0.]
# Model Score: [0.02180501] actual score: [0.]
# Model Score: [0.88177216] actual score: [1.]
# Model Score: [0.9916951] actual score: [1.]
# Model Score: [0.02272528] actual score: [0.]
# Model Score: [0.99182105] actual score: [1.]
# Model Score: [0.17230913] actual score: [0.]
# Model Score: [0.85722303] actual score: [1.]
# Model Score: [0.70884836] actual score: [0.]
# Model Score: [0.00668232] actual score: [0.]
# Model Score: [0.29057592] actual score: [0.]
# Model Score: [0.99988544] actual score: [1.]
# Model Score: [0.9914097] actual score: [1.]
# Model Score: [0.971847] actual score: [1.]
# Model Score: [0.9679204] actual score: [1.]
# Model Score: [0.00439112] actual score: [0.]
# Model Score: [0.7277534] actual score: [1.]
# Model Score: [0.9682237] actual score: [1.]
# Model Score: [0.02052255] actual score: [0.]
# Model Score: [0.03694861] actual score: [0.]
# Model Score: [0.206763] actual score: [0.]
# Model Score: [0.14669284] actual score: [0.]
# Model Score: [0.0508391] actual score: [0.]
# Model Score: [0.98993266] actual score: [1.]
# Model Score: [0.12232574] actual score: [0.]
# Model Score: [0.26087007] actual score: [0.]
# Model Score: [0.0394529] actual score: [1.]
# Model Score: [0.59982616] actual score: [0.]
# Model Score: [0.9571811] actual score: [1.]
# Model Score: [0.11205441] actual score: [0.]
# Model Score: [0.8548198] actual score: [1.]
# Model Score: [0.00318538] actual score: [0.]
# Model Score: [0.81834275] actual score: [0.]
# Model Score: [0.55739576] actual score: [0.]
# Model Score: [0.03463126] actual score: [0.]
# Model Score: [0.99999547] actual score: [1.]
# Model Score: [0.99166965] actual score: [1.]
# Model Score: [0.00791841] actual score: [0.]
# Model Score: [0.01821526] actual score: [0.]
# Model Score: [0.9940408] actual score: [1.]
# Model Score: [0.97995675] actual score: [1.]
# Model Score: [0.9679378] actual score: [0.]
# Model Score: [0.00169965] actual score: [0.]
# Model Score: [0.9389609] actual score: [1.]
# Model Score: [0.04827612] actual score: [0.]
# Model Score: [0.01047213] actual score: [0.]
# Model Score: [0.01444662] actual score: [0.]
# Model Score: [0.94178796] actual score: [1.]
# Model Score: [0.82822645] actual score: [1.]
# Model Score: [0.9731617] actual score: [1.]
# Model Score: [0.96663684] actual score: [1.]
# Model Score: [0.9788087] actual score: [1.]
# Model Score: [0.99442816] actual score: [1.]
# Model Score: [0.98721004] actual score: [1.]
# Model Score: [0.08685382] actual score: [0.]
# Model Score: [0.00811508] actual score: [0.]
# Model Score: [0.85140395] actual score: [1.]
# Model Score: [0.03443022] actual score: [0.]
# Model Score: [0.9930655] actual score: [1.]
# Model Score: [0.95283175] actual score: [1.]
# Model Score: [0.00357761] actual score: [0.]
# Model Score: [0.02642031] actual score: [1.]
# Model Score: [0.9760342] actual score: [1.]
# Model Score: [0.8522201] actual score: [1.]
# Model Score: [0.23138772] actual score: [0.]
# Model Score: [0.990458] actual score: [1.]
# Model Score: [0.98534656] actual score: [1.]
# Model Score: [0.11915137] actual score: [0.]
# Model Score: [0.92167485] actual score: [1.]
# Model Score: [0.9994785] actual score: [1.]
# Model Score: [0.14431532] actual score: [0.]
# Model Score: [0.5988555] actual score: [1.]
# Model Score: [0.873231] actual score: [1.]
# Model Score: [0.82927847] actual score: [1.]
# Model Score: [0.9381678] actual score: [1.]
# Model Score: [0.88039476] actual score: [1.]
# Model Score: [0.70179856] actual score: [1.]
# Model Score: [0.7458617] actual score: [1.]
# Model Score: [0.9720668] actual score: [1.]
# Model Score: [0.89924634] actual score: [1.]
# Model Score: [0.88501495] actual score: [1.]
# Model Score: [0.9947195] actual score: [1.]
# Model Score: [0.9999279] actual score: [1.]
# Model Score: [0.9991621] actual score: [1.]
# Model Score: [0.99414283] actual score: [1.]
# Model Score: [0.01629297] actual score: [0.]
# Model Score: [0.00576414] actual score: [0.]
# Model Score: [0.2855457] actual score: [0.]
# Model Score: [0.01607951] actual score: [0.]
# Model Score: [0.02200656] actual score: [0.]
# Model Score: [0.21979025] actual score: [0.]
# Model Score: [0.70963573] actual score: [1.]
# Model Score: [0.09810252] actual score: [1.]
# Model Score: [0.01675096] actual score: [0.]
# Model Score: [0.78153306] actual score: [1.]
# Model Score: [0.01208018] actual score: [0.]
# Model Score: [0.02369203] actual score: [0.]
# Model Score: [0.948778] actual score: [1.]
# Model Score: [0.9916819] actual score: [1.]
# Model Score: [0.64675564] actual score: [0.]
# Model Score: [0.03556343] actual score: [0.]
# Model Score: [0.70971566] actual score: [1.]
# Model Score: [0.04199671] actual score: [0.]
# Model Score: [0.00693789] actual score: [0.]
# Model Score: [0.9654916] actual score: [1.]
# Model Score: [0.99591607] actual score: [1.]
# Model Score: [0.00808444] actual score: [0.]
# Model Score: [0.02573909] actual score: [0.]
# Model Score: [0.16550031] actual score: [0.]
# Model Score: [0.01842533] actual score: [0.]
# Model Score: [0.02278814] actual score: [1.]
# Model Score: [0.08986008] actual score: [0.]
# Model Score: [0.9998603] actual score: [1.]
# Model Score: [0.00701023] actual score: [0.]
# Model Score: [0.8262006] actual score: [1.]
# Model Score: [0.99726593] actual score: [1.]
# Model Score: [0.83129] actual score: [1.]
# Model Score: [0.0356711] actual score: [0.]
# Model Score: [0.02703377] actual score: [0.]
# Model Score: [0.99209917] actual score: [1.]
# Model Score: [0.04007284] actual score: [0.]
# Model Score: [0.9996158] actual score: [1.]
# Model Score: [0.631504] actual score: [0.]
# Model Score: [0.18585949] actual score: [0.]
# Model Score: [0.01420674] actual score: [0.]
# Model Score: [0.04136295] actual score: [0.]
# Model Score: [0.79960376] actual score: [1.]
# Model Score: [0.99434125] actual score: [1.]
# Model Score: [0.9854064] actual score: [1.]
# Model Score: [0.07691518] actual score: [0.]
# Model Score: [0.99925345] actual score: [1.]
# Model Score: [0.9993931] actual score: [1.]
# Model Score: [0.823722] actual score: [1.]
# Model Score: [0.01878457] actual score: [0.]
# Model Score: [0.0406844] actual score: [0.]
# Model Score: [0.04275937] actual score: [0.]
# Model Score: [0.9990362] actual score: [1.]
# Model Score: [0.93810844] actual score: [1.]
# Model Score: [0.9970487] actual score: [1.]
# Model Score: [0.14657459] actual score: [0.]
# Model Score: [0.01180087] actual score: [0.]
# Model Score: [0.9998354] actual score: [1.]
# Model Score: [0.02187414] actual score: [0.]
# Model Score: [0.9963264] actual score: [1.]
# Model Score: [0.01427573] actual score: [0.]
# Model Score: [0.9532652] actual score: [1.]
# Model Score: [0.03152345] actual score: [0.]
# Model Score: [0.9988193] actual score: [1.]
# Model Score: [0.8253042] actual score: [1.]
# Model Score: [0.17652056] actual score: [1.]
# Model Score: [0.05376817] actual score: [0.]
# Model Score: [0.0067075] actual score: [0.]
# Model Score: [0.9988091] actual score: [1.]
# Model Score: [0.46414044] actual score: [0.]
# Model Score: [0.8898648] actual score: [1.]
# Model Score: [0.9489774] actual score: [1.]
# Model Score: [0.22621666] actual score: [0.]
# Model Score: [0.00156751] actual score: [0.]
# Model Score: [0.00150703] actual score: [0.]
# Model Score: [0.01830477] actual score: [0.]
# Model Score: [0.02839909] actual score: [0.]
# Model Score: [0.8535866] actual score: [1.]
# Model Score: [1.9429148e-05] actual score: [0.]
# Model Score: [0.00082281] actual score: [0.]
# Model Score: [0.3287395] actual score: [1.]
# Model Score: [0.881841] actual score: [1.]
# Model Score: [0.26140636] actual score: [0.]
# Model Score: [0.7721881] actual score: [1.]
# Model Score: [0.17129631] actual score: [1.]
# Model Score: [0.02277694] actual score: [0.]
# Model Score: [0.09129172] actual score: [0.]
# Model Score: [0.00796199] actual score: [0.]
# Model Score: [0.9814952] actual score: [1.]
# Model Score: [0.6789474] actual score: [1.]
# Model Score: [0.79076093] actual score: [1.]
# Model Score: [0.95713437] actual score: [1.]
# Model Score: [0.21230365] actual score: [0.]
# Model Score: [0.8641544] actual score: [1.]
# Model Score: [0.5412074] actual score: [0.]
# Model Score: [0.0127279] actual score: [0.]
# Model Score: [0.97578466] actual score: [1.]
# Model Score: [0.9428455] actual score: [1.]
# Model Score: [0.91754305] actual score: [1.]
# Model Score: [0.99941814] actual score: [1.]
# Model Score: [0.00681547] actual score: [0.]
# Model Score: [0.94476265] actual score: [1.]
# Model Score: [0.0445408] actual score: [0.]
# Model Score: [0.9994649] actual score: [1.]
# Model Score: [0.98380935] actual score: [1.]
# Model Score: [0.99978334] actual score: [1.]
# Model Score: [0.7502489] actual score: [1.]
# Model Score: [0.03447767] actual score: [0.]
# Model Score: [0.6701927] actual score: [0.]
# Model Score: [0.0058662] actual score: [0.]
# Model Score: [0.01294269] actual score: [0.]
# Model Score: [0.8401872] actual score: [1.]
# Model Score: [0.6052074] actual score: [1.]
# Model Score: [0.949206] actual score: [1.]
# Model Score: [0.02425453] actual score: [0.]
# Model Score: [0.00940872] actual score: [0.]
# Model Score: [0.93077004] actual score: [1.]
# Model Score: [0.9579614] actual score: [1.]
# Model Score: [0.9151343] actual score: [1.]
# Model Score: [0.01311783] actual score: [0.]
# Model Score: [0.00819586] actual score: [0.]
# Model Score: [0.24861912] actual score: [0.]
# Model Score: [0.01778832] actual score: [0.]
# Model Score: [0.8662289] actual score: [1.]
# Model Score: [0.02115516] actual score: [0.]
# Model Score: [0.9999503] actual score: [1.]
# Model Score: [0.91733366] actual score: [1.]
# Model Score: [0.00539133] actual score: [0.]
# Model Score: [0.37684697] actual score: [1.]
# Model Score: [0.6593504] actual score: [1.]
# Model Score: [0.01152984] actual score: [0.]
# Model Score: [0.02374611] actual score: [0.]
# Model Score: [0.347971] actual score: [0.]
# Model Score: [0.19484992] actual score: [0.]
# Model Score: [0.02265937] actual score: [0.]
# Model Score: [0.00539202] actual score: [0.]
# Model Score: [0.8495211] actual score: [1.]
# Model Score: [0.86310506] actual score: [0.]
# Model Score: [0.9833481] actual score: [1.]
# Model Score: [0.99745995] actual score: [1.]
# Model Score: [0.06993285] actual score: [0.]
# Model Score: [0.801092] actual score: [1.]
# Model Score: [0.09802646] actual score: [0.]
# Model Score: [0.30196452] actual score: [0.]
# Model Score: [0.01237323] actual score: [0.]
# Model Score: [0.9985493] actual score: [1.]
# Model Score: [0.33543116] actual score: [0.]
# Model Score: [0.9991835] actual score: [1.]
# Model Score: [0.03653693] actual score: [0.]
# Model Score: [0.8897305] actual score: [1.]
# Model Score: [0.00856703] actual score: [0.]
# Model Score: [0.01453719] actual score: [0.]
# Model Score: [0.0056366] actual score: [0.]
# Model Score: [0.01537361] actual score: [0.]
# Model Score: [0.8991913] actual score: [1.]
# Model Score: [0.00072595] actual score: [0.]
# Model Score: [0.76657885] actual score: [1.]
# Model Score: [0.8513794] actual score: [1.]
# Model Score: [0.92161787] actual score: [1.]
# Model Score: [0.01240565] actual score: [0.]
# Model Score: [0.96282023] actual score: [1.]
# Model Score: [0.04004574] actual score: [0.]
# Model Score: [0.00018285] actual score: [0.]
# Model Score: [0.98781246] actual score: [1.]
# Model Score: [0.0267952] actual score: [0.]
# Model Score: [0.9921125] actual score: [1.]
# Model Score: [0.99490404] actual score: [1.]
# Model Score: [0.8366377] actual score: [1.]
# Model Score: [0.0481411] actual score: [0.]
# Model Score: [0.00950885] actual score: [0.]
# Model Score: [0.19984798] actual score: [1.]
# Model Score: [0.815635] actual score: [1.]
# Model Score: [0.99869484] actual score: [1.]
# Model Score: [0.97984374] actual score: [1.]
# Model Score: [0.78279126] actual score: [1.]
# Model Score: [0.01322712] actual score: [0.]
# Model Score: [0.10656393] actual score: [0.]
# Model Score: [0.96085566] actual score: [1.]
# Model Score: [0.00678058] actual score: [0.]
# Model Score: [0.8476455] actual score: [1.]
# Model Score: [0.92822665] actual score: [0.]
# Model Score: [0.05295241] actual score: [0.]
# Model Score: [0.5171762] actual score: [1.]
# Model Score: [0.07163669] actual score: [0.]
# Model Score: [0.99219644] actual score: [1.]
# Model Score: [0.08230018] actual score: [0.]
# Model Score: [0.01372097] actual score: [0.]
# Model Score: [0.78700083] actual score: [1.]
# Model Score: [0.09379256] actual score: [1.]
# Model Score: [0.01210319] actual score: [0.]
# Model Score: [0.37687755] actual score: [1.]
# Model Score: [0.02816023] actual score: [0.]
# Model Score: [0.9901564] actual score: [0.]
# Model Score: [0.8643101] actual score: [1.]
# Model Score: [0.24200495] actual score: [0.]
# Model Score: [0.86098254] actual score: [1.]
# Model Score: [0.11340731] actual score: [0.]
# Model Score: [0.02405483] actual score: [0.]
# Model Score: [0.02060388] actual score: [0.]
# Model Score: [0.01528051] actual score: [0.]
# Model Score: [0.95614064] actual score: [1.]
# Model Score: [0.4332026] actual score: [1.]
# Model Score: [0.6676207] actual score: [0.]
# Model Score: [0.00439382] actual score: [0.]
# Model Score: [0.98134536] actual score: [1.]
# Model Score: [0.01444816] actual score: [0.]
# Model Score: [0.7745113] actual score: [1.]
# Model Score: [0.9994711] actual score: [1.]
# Model Score: [0.01834308] actual score: [0.]
# Model Score: [0.01769409] actual score: [0.]
# Model Score: [0.9965712] actual score: [1.]
# Model Score: [0.7358306] actual score: [1.]
# Model Score: [0.06392651] actual score: [0.]
# Model Score: [0.29371616] actual score: [0.]
# Model Score: [0.0159355] actual score: [0.]
# Model Score: [0.9993356] actual score: [1.]
# Model Score: [0.8375102] actual score: [1.]
# Model Score: [0.9990507] actual score: [1.]
# Model Score: [0.9899367] actual score: [1.]
# Model Score: [0.00818838] actual score: [0.]
# Model Score: [0.00961342] actual score: [0.]
# Model Score: [0.5163245] actual score: [1.]
# Model Score: [0.41180027] actual score: [0.]
# Model Score: [0.52402025] actual score: [1.]
# Model Score: [0.67705494] actual score: [1.]
# Model Score: [0.95095944] actual score: [1.]
# Model Score: [0.02833989] actual score: [0.]
# Model Score: [0.92105067] actual score: [1.]
# Model Score: [0.540864] actual score: [0.]
# Model Score: [0.2656899] actual score: [1.]
# Model Score: [0.02986024] actual score: [0.]
# Model Score: [0.9662348] actual score: [1.]
# Model Score: [0.5660888] actual score: [0.]
# Model Score: [0.79860365] actual score: [0.]
# Model Score: [0.914281] actual score: [1.]
# Model Score: [0.9914744] actual score: [1.]
# Model Score: [0.94130445] actual score: [1.]
# Model Score: [0.00764816] actual score: [0.]
# Model Score: [0.9498443] actual score: [1.]
# Model Score: [0.21721071] actual score: [0.]
# Model Score: [0.99603456] actual score: [1.]
# Model Score: [0.93542874] actual score: [1.]
# Model Score: [0.35883206] actual score: [1.]
# Model Score: [0.05523186] actual score: [0.]
# Model Score: [0.01188238] actual score: [0.]
# Model Score: [0.9932806] actual score: [1.]
# Model Score: [0.23738922] actual score: [0.]
# Model Score: [0.99046165] actual score: [1.]
# Model Score: [0.9905285] actual score: [1.]
# Model Score: [0.2576722] actual score: [0.]
# Model Score: [0.9978719] actual score: [1.]
# Model Score: [0.95564216] actual score: [1.]
# Model Score: [0.96513647] actual score: [1.]
# Model Score: [0.9995209] actual score: [1.]
# Model Score: [0.00510918] actual score: [0.]
# Model Score: [0.07807723] actual score: [0.]
# Model Score: [0.00529677] actual score: [0.]
# Model Score: [0.9523185] actual score: [1.]
# Model Score: [0.19436762] actual score: [0.]
# Model Score: [0.06439195] actual score: [0.]
# Model Score: [0.9996792] actual score: [1.]
# Model Score: [0.36965638] actual score: [0.]
# Model Score: [0.00653325] actual score: [0.]
# Model Score: [0.5038297] actual score: [0.]
# Model Score: [0.99989235] actual score: [1.]
# Model Score: [0.989284] actual score: [1.]
# Model Score: [0.7086084] actual score: [1.]
# Model Score: [0.7194812] actual score: [1.]
# Model Score: [0.01383316] actual score: [0.]
# Model Score: [0.988596] actual score: [1.]
# Model Score: [0.00491877] actual score: [0.]
# Model Score: [0.15053028] actual score: [0.]
# Model Score: [0.9283911] actual score: [1.]
# Model Score: [0.9977216] actual score: [1.]
# Model Score: [0.9947448] actual score: [1.]
# Model Score: [0.29516187] actual score: [0.]
# Model Score: [0.14779574] actual score: [0.]
# Model Score: [0.0612412] actual score: [0.]
# Model Score: [0.02332689] actual score: [0.]
# Model Score: [0.9155356] actual score: [0.]
# Model Score: [0.98684883] actual score: [1.]
# Model Score: [0.9151512] actual score: [1.]
# Model Score: [0.02769993] actual score: [0.]
# Model Score: [0.9697971] actual score: [1.]
# Model Score: [0.01787048] actual score: [0.]
# Model Score: [0.01262605] actual score: [0.]
# Model Score: [0.58193684] actual score: [0.]
# Model Score: [0.40460116] actual score: [1.]
# Model Score: [0.92316914] actual score: [1.]
# Model Score: [0.99209857] actual score: [1.]
# Model Score: [0.98257715] actual score: [1.]
# Model Score: [0.02298434] actual score: [0.]
# Model Score: [0.9778952] actual score: [1.]
# Model Score: [0.06729583] actual score: [0.]
# Model Score: [0.03719469] actual score: [0.]
# Model Score: [0.00563022] actual score: [0.]
# Model Score: [0.9288736] actual score: [1.]
# Model Score: [0.76403195] actual score: [0.]
# Model Score: [0.02888457] actual score: [0.]
# Model Score: [0.9986897] actual score: [1.]
# Model Score: [0.308565] actual score: [1.]
# Model Score: [0.9733002] actual score: [1.]
# Model Score: [0.00502227] actual score: [0.]
# Model Score: [0.7196] actual score: [0.]
# Model Score: [0.01783918] actual score: [0.]
# Model Score: [0.98992354] actual score: [1.]
# Model Score: [0.94557714] actual score: [1.]
# Model Score: [0.9784208] actual score: [1.]
# Model Score: [0.01152509] actual score: [0.]
# Model Score: [0.9833687] actual score: [1.]
# Model Score: [0.01186465] actual score: [0.]
# Model Score: [0.8634567] actual score: [1.]
# Model Score: [0.08060332] actual score: [0.]
# Model Score: [0.01964684] actual score: [0.]
# Model Score: [0.0144342] actual score: [0.]
# Model Score: [0.8632774] actual score: [1.]
# Model Score: [0.99775046] actual score: [1.]
# Model Score: [0.92560184] actual score: [0.]
# Model Score: [0.03544409] actual score: [0.]
# Model Score: [0.02876114] actual score: [0.]
# Model Score: [0.00684539] actual score: [0.]
# Model Score: [0.9999604] actual score: [1.]
# Model Score: [0.04744627] actual score: [0.]
# Model Score: [0.00876455] actual score: [0.]
# Model Score: [0.5579867] actual score: [0.]
# Model Score: [0.85203815] actual score: [1.]
# Model Score: [0.01110049] actual score: [0.]
# Model Score: [0.2111384] actual score: [0.]
# Model Score: [0.08375587] actual score: [0.]
# Model Score: [0.99749243] actual score: [1.]
# Model Score: [0.5934964] actual score: [0.]
# Model Score: [0.03962107] actual score: [0.]
# Model Score: [0.99920434] actual score: [1.]
# Model Score: [0.9395154] actual score: [1.]
# Model Score: [0.99518555] actual score: [1.]
# Model Score: [0.01245917] actual score: [0.]
# Model Score: [0.97420055] actual score: [1.]
# Model Score: [0.2112896] actual score: [0.]
# Model Score: [0.00444554] actual score: [0.]
# Model Score: [0.9999776] actual score: [1.]
# Model Score: [0.999506] actual score: [1.]
# Model Score: [0.14872125] actual score: [0.]
# Model Score: [0.938347] actual score: [1.]
# Model Score: [0.01808647] actual score: [0.]
# Model Score: [0.00511695] actual score: [0.]
# Model Score: [0.01238489] actual score: [0.]
# Model Score: [0.7873706] actual score: [1.]
# Model Score: [0.26827443] actual score: [0.]
# Model Score: [0.00700342] actual score: [0.]
# Model Score: [0.9834922] actual score: [1.]
# Model Score: [0.9778285] actual score: [1.]
# Model Score: [0.6804226] actual score: [1.]
# Model Score: [0.00539192] actual score: [0.]
# Model Score: [0.00652485] actual score: [0.]
# Model Score: [0.02057084] actual score: [0.]
# Model Score: [0.04012989] actual score: [0.]
# Model Score: [0.37630084] actual score: [0.]
# Model Score: [0.02051544] actual score: [0.]
# Model Score: [0.05874129] actual score: [0.]
# Model Score: [0.01451422] actual score: [0.]
# Model Score: [0.9973002] actual score: [1.]
# Model Score: [0.8967762] actual score: [1.]
# Model Score: [0.01324202] actual score: [0.]
# Model Score: [0.9519758] actual score: [1.]
# Model Score: [0.02766598] actual score: [1.]
# Model Score: [0.99944025] actual score: [1.]
# Model Score: [0.21840626] actual score: [1.]
# Model Score: [0.90496606] actual score: [0.]
# Model Score: [0.97861344] actual score: [1.]
# Model Score: [0.97181964] actual score: [1.]
# Model Score: [0.94635594] actual score: [1.]
# Model Score: [0.02150203] actual score: [0.]
# Model Score: [0.99874794] actual score: [1.]
# Model Score: [0.00684313] actual score: [0.]
# Model Score: [0.02229471] actual score: [0.]
# Model Score: [0.00485339] actual score: [0.]
# Model Score: [0.00662525] actual score: [0.]
# Model Score: [0.01214782] actual score: [0.]
# Model Score: [0.97493184] actual score: [1.]
# Model Score: [0.01300545] actual score: [0.]
# Model Score: [0.00517719] actual score: [0.]
# Model Score: [0.7134653] actual score: [1.]
# Model Score: [0.53852725] actual score: [1.]
# Model Score: [0.15401666] actual score: [0.]
# Model Score: [0.24041726] actual score: [0.]
# Model Score: [0.91745883] actual score: [1.]
# Model Score: [0.9378229] actual score: [1.]
# Model Score: [0.9413913] actual score: [1.]
# Model Score: [0.9991393] actual score: [1.]
# Model Score: [0.03706173] actual score: [0.]
# Model Score: [0.2118742] actual score: [0.]
# Model Score: [0.02301138] actual score: [0.]
# Model Score: [0.98572737] actual score: [1.]
# Model Score: [0.89831465] actual score: [0.]
# Model Score: [0.02510266] actual score: [0.]
# Model Score: [0.32537818] actual score: [0.]
# Model Score: [0.85101205] actual score: [1.]
# Model Score: [0.88544035] actual score: [0.]
# Model Score: [0.9508429] actual score: [1.]
# Model Score: [0.9430283] actual score: [1.]
# Model Score: [0.9937589] actual score: [1.]
# Model Score: [0.69999254] actual score: [1.]
# Model Score: [0.00481791] actual score: [0.]
# Model Score: [0.99910235] actual score: [1.]
# Model Score: [0.99676204] actual score: [1.]
# Model Score: [0.14557216] actual score: [0.]
# Model Score: [0.13521306] actual score: [0.]
# Model Score: [0.90856254] actual score: [1.]
# Model Score: [0.70505244] actual score: [1.]
# Model Score: [0.9445322] actual score: [1.]
# Model Score: [0.998676] actual score: [1.]
# Model Score: [0.76728016] actual score: [0.]
# Model Score: [0.00329285] actual score: [0.]
# Model Score: [0.04975338] actual score: [1.]
# Model Score: [0.04768244] actual score: [0.]
# Model Score: [0.01258045] actual score: [0.]
# Model Score: [0.92054087] actual score: [1.]
# Model Score: [0.0267999] actual score: [0.]
# Model Score: [0.40890184] actual score: [0.]
# Model Score: [0.712268] actual score: [1.]
# Model Score: [0.02424551] actual score: [0.]
# Model Score: [0.09841883] actual score: [0.]
# Model Score: [0.9991879] actual score: [1.]
# Model Score: [0.8921285] actual score: [1.]
# Model Score: [0.9179564] actual score: [1.]
# Model Score: [0.00747922] actual score: [0.]
# Model Score: [0.4673574] actual score: [1.]
# Model Score: [0.6376965] actual score: [1.]
# Model Score: [0.55668336] actual score: [0.]
# Model Score: [0.12947804] actual score: [1.]
# Model Score: [0.08362738] actual score: [0.]
# Model Score: [0.03108908] actual score: [0.]
# Model Score: [0.01440547] actual score: [0.]
# Model Score: [0.988993] actual score: [1.]
# Model Score: [0.20074971] actual score: [0.]
# Model Score: [0.97874033] actual score: [1.]
# Model Score: [0.68975407] actual score: [0.]
# Model Score: [0.6287321] actual score: [1.]
# Model Score: [0.63949454] actual score: [1.]
# Model Score: [0.9955462] actual score: [1.]
# Model Score: [0.8489089] actual score: [1.]
# Model Score: [0.9625888] actual score: [1.]
# Model Score: [0.14498445] actual score: [0.]
# Model Score: [0.779746] actual score: [1.]
# Model Score: [0.02323346] actual score: [0.]
# Model Score: [0.83432764] actual score: [1.]
# Model Score: [0.91682523] actual score: [1.]
# Model Score: [0.29666245] actual score: [1.]
# Model Score: [0.05035046] actual score: [0.]
# Model Score: [0.03368603] actual score: [0.]
# Model Score: [0.84212327] actual score: [1.]
# Model Score: [0.00367777] actual score: [0.]
# ...
# Model Score: [0.00079708] actual score: [0.]
# Model Score: [0.01543656] actual score: [0.]
# Model Score: [0.70945764] actual score: [1.]
# Model Score: [0.9996197] actual score: [1.]
# Model Score: [0.9752219] actual score: [1.]
# Model Score: [0.9990181] actual score: [1.]
# Model Score: [0.12694253] actual score: [0.]
# Model Score: [0.9904855] actual score: [1.]
# Model Score: [0.69399375] actual score: [0.]
# Model Score: [0.99961543] actual score: [1.]
# Model Score: [0.94057906] actual score: [1.]
# Model Score: [0.90785116] actual score: [0.]
# Model Score: [0.8009492] actual score: [1.]
# Model Score: [0.01276461] actual score: [0.]
# Model Score: [0.99885964] actual score: [1.]
# Model Score: [0.869476] actual score: [0.]
# Model Score: [0.79157245] actual score: [1.]
# Model Score: [0.04507408] actual score: [0.]
# Model Score: [0.01537342] actual score: [0.]
# Model Score: [0.99965966] actual score: [1.]
# Model Score: [0.4391976] actual score: [0.]
# Model Score: [0.94789094] actual score: [1.]
# Model Score: [0.0928907] actual score: [0.]
# Model Score: [0.12966533] actual score: [1.]
# Model Score: [0.99855155] actual score: [1.]
# Model Score: [0.98608357] actual score: [1.]
# Model Score: [0.00982096] actual score: [0.]
# Model Score: [0.05542437] actual score: [0.]
# Model Score: [0.88067895] actual score: [1.]
# Model Score: [0.00491245] actual score: [0.]
# Model Score: [0.02071658] actual score: [0.]
# Model Score: [0.15082417] actual score: [0.]
# Model Score: [0.21403244] actual score: [1.]
# Model Score: [0.84129953] actual score: [0.]
# Model Score: [0.8977638] actual score: [1.]
# Model Score: [0.01672358] actual score: [0.]
# Model Score: [0.01238785] actual score: [0.]
# Model Score: [0.9917601] actual score: [0.]
# Model Score: [0.9093022] actual score: [1.]
# Model Score: [0.02283394] actual score: [0.]
# Model Score: [0.03604016] actual score: [0.]
# Model Score: [0.9744274] actual score: [1.]
# Model Score: [0.0529811] actual score: [0.]
# Model Score: [0.9557356] actual score: [1.]
# Model Score: [0.88269603] actual score: [1.]
# Model Score: [0.9492972] actual score: [1.]
# Model Score: [0.61282593] actual score: [0.]
# Model Score: [0.90211326] actual score: [1.]
# Model Score: [0.9991524] actual score: [1.]
# Model Score: [0.03988918] actual score: [0.]
# Model Score: [0.01203611] actual score: [0.]
# Model Score: [0.95545995] actual score: [1.]
# Model Score: [0.02413507] actual score: [0.]
# Model Score: [0.12033179] actual score: [0.]
# Model Score: [0.9680599] actual score: [1.]
# Model Score: [0.6393818] actual score: [1.]
# Model Score: [0.12003265] actual score: [0.]
# Model Score: [0.9938451] actual score: [1.]
# Model Score: [0.02726374] actual score: [0.]
# Model Score: [0.48178592] actual score: [0.]
# Model Score: [0.98743266] actual score: [1.]
# Model Score: [0.9324078] actual score: [1.]
# Model Score: [0.00043532] actual score: [0.]
# Model Score: [0.03488853] actual score: [0.]
# Model Score: [0.04497396] actual score: [0.]
# Model Score: [0.9279322] actual score: [1.]
# Model Score: [0.03381399] actual score: [0.]
# Model Score: [0.99897206] actual score: [1.]
# Model Score: [0.07449862] actual score: [0.]
# Model Score: [0.07191154] actual score: [0.]
# Model Score: [0.74174607] actual score: [1.]
# Model Score: [0.94047457] actual score: [1.]
# Model Score: [0.86615676] actual score: [1.]
# Model Score: [0.9689725] actual score: [1.]
# Model Score: [0.9922009] actual score: [1.]
# Model Score: [0.06785855] actual score: [0.]
# Model Score: [0.8291228] actual score: [0.]
# Model Score: [0.0155076] actual score: [0.]
# Model Score: [0.70488584] actual score: [0.]
# Model Score: [0.807997] actual score: [1.]
# Model Score: [0.08462314] actual score: [0.]
# Model Score: [0.01463987] actual score: [0.]
# Model Score: [0.42493272] actual score: [0.]
# Model Score: [0.92197055] actual score: [1.]
# Model Score: [0.9307048] actual score: [1.]
# Model Score: [0.9815392] actual score: [1.]
# Model Score: [0.0301054] actual score: [0.]
# Model Score: [0.67128605] actual score: [0.]
# Model Score: [0.75041157] actual score: [1.]
# Model Score: [0.98232687] actual score: [1.]
# Model Score: [0.01396456] actual score: [0.]
# Model Score: [0.03523306] actual score: [0.]
# Model Score: [0.89210296] actual score: [1.]
# Model Score: [0.00013501] actual score: [0.]
# Model Score: [0.99755293] actual score: [1.]
# Model Score: [0.09882244] actual score: [0.]
# Model Score: [0.99891376] actual score: [1.]
# Model Score: [0.73059344] actual score: [1.]
# Model Score: [0.9967842] actual score: [1.]
# Model Score: [0.75735044] actual score: [1.]
# Model Score: [0.6909814] actual score: [1.]
# Model Score: [0.7259369] actual score: [1.]
# Model Score: [0.9951427] actual score: [1.]
# Model Score: [0.9366284] actual score: [1.]
# Model Score: [0.9750582] actual score: [1.]
# Model Score: [0.06007906] actual score: [0.]
# Model Score: [0.00997772] actual score: [0.]
# Model Score: [0.15733136] actual score: [0.]
# Model Score: [0.00569678] actual score: [0.]
# Model Score: [0.8851074] actual score: [1.]
# Model Score: [0.44254112] actual score: [0.]
# Model Score: [0.01289137] actual score: [0.]
# Model Score: [0.05781175] actual score: [0.]
# Model Score: [0.99938893] actual score: [1.]
# Model Score: [0.9970216] actual score: [1.]
# Model Score: [0.6023176] actual score: [1.]
# Model Score: [0.9169024] actual score: [1.]
# Model Score: [0.70663077] actual score: [1.]
# Model Score: [0.75127107] actual score: [1.]
# Model Score: [0.07963368] actual score: [0.]
# Model Score: [0.99017286] actual score: [1.]
# Model Score: [0.02493759] actual score: [0.]
# Model Score: [0.9899741] actual score: [1.]
# Model Score: [0.9923833] actual score: [1.]
# Model Score: [0.99974304] actual score: [1.]
# Model Score: [0.9997254] actual score: [1.]
# Model Score: [0.03813085] actual score: [0.]
# Model Score: [0.00093044] actual score: [0.]
# Model Score: [0.8513606] actual score: [1.]
# Model Score: [0.7819918] actual score: [1.]
# Model Score: [0.41719404] actual score: [0.]
# Model Score: [0.85013837] actual score: [0.]
# Model Score: [0.00918722] actual score: [0.]
# Model Score: [0.00072432] actual score: [0.]
# Model Score: [0.35533568] actual score: [1.]
# Model Score: [0.81204164] actual score: [1.]
# Model Score: [0.9641307] actual score: [1.]
# Model Score: [0.9187886] actual score: [1.]
# Model Score: [0.01090218] actual score: [0.]
# Model Score: [0.01832506] actual score: [0.]
# Model Score: [0.05426964] actual score: [1.]
# Model Score: [0.9986066] actual score: [1.]
# Model Score: [0.9975228] actual score: [1.]
# Model Score: [0.00150449] actual score: [0.]
# Model Score: [0.7162649] actual score: [1.]
# Model Score: [0.6608792] actual score: [1.]
# Model Score: [0.9807794] actual score: [1.]
# Model Score: [0.0163465] actual score: [0.]
# Model Score: [0.8236048] actual score: [1.]
# Model Score: [0.03140444] actual score: [0.]
# Model Score: [0.9996635] actual score: [1.]
# Model Score: [0.95111996] actual score: [1.]
# Model Score: [0.64944345] actual score: [1.]
# Model Score: [0.00127353] actual score: [0.]
# Model Score: [0.98758847] actual score: [1.]
# Model Score: [0.03021341] actual score: [0.]
# Model Score: [0.42694905] actual score: [0.]
# Model Score: [0.8924238] actual score: [1.]
# Model Score: [0.02343157] actual score: [0.]
# Model Score: [0.11246388] actual score: [0.]
# Model Score: [0.95738924] actual score: [1.]
# Model Score: [0.02718567] actual score: [0.]
# Model Score: [0.98296434] actual score: [1.]
# Model Score: [0.8790045] actual score: [0.]
# Model Score: [0.9823393] actual score: [1.]
# Model Score: [0.90303963] actual score: [1.]
# Model Score: [0.9431188] actual score: [1.]
# Model Score: [0.01704434] actual score: [0.]
# Model Score: [0.00090833] actual score: [0.]
# Model Score: [0.95562357] actual score: [1.]
# Model Score: [0.3965124] actual score: [1.]
# Model Score: [0.00888399] actual score: [0.]
# Model Score: [0.9923977] actual score: [1.]
# Model Score: [0.02022495] actual score: [0.]
# Model Score: [0.00131657] actual score: [0.]
# Model Score: [0.96415937] actual score: [1.]
# Model Score: [0.24455807] actual score: [0.]
# Model Score: [0.96197206] actual score: [0.]
# Model Score: [0.99942374] actual score: [1.]
# Model Score: [0.83284026] actual score: [1.]
# Model Score: [0.99838734] actual score: [1.]
# Model Score: [0.99572337] actual score: [1.]
# Model Score: [0.01696293] actual score: [0.]
# Model Score: [0.9675386] actual score: [1.]
# Model Score: [0.04032993] actual score: [1.]
# Model Score: [0.13275793] actual score: [0.]
# Model Score: [0.95054305] actual score: [1.]
# Model Score: [0.945297] actual score: [1.]
# Model Score: [0.28416854] actual score: [1.]
# Model Score: [0.00846317] actual score: [0.]
# Model Score: [0.25785682] actual score: [0.]
# Model Score: [0.75574535] actual score: [1.]
# Model Score: [0.9987105] actual score: [1.]
# Model Score: [0.11747812] actual score: [1.]
# Model Score: [0.903727] actual score: [1.]
# Model Score: [0.01494255] actual score: [1.]
# Model Score: [0.8983939] actual score: [1.]
# Model Score: [0.94800127] actual score: [1.]
# Model Score: [0.19512771] actual score: [0.]
# Model Score: [0.01222818] actual score: [0.]
# Model Score: [0.71260333] actual score: [0.]
# Model Score: [0.00141548] actual score: [0.]
# Model Score: [0.9995819] actual score: [1.]
# Model Score: [0.7601544] actual score: [1.]
# Model Score: [0.9697999] actual score: [1.]
# Model Score: [0.7120516] actual score: [1.]
# Model Score: [0.90196663] actual score: [1.]
# Model Score: [0.01962929] actual score: [0.]
# Model Score: [0.00597771] actual score: [0.]
# Model Score: [0.99890924] actual score: [1.]
# Model Score: [0.01091464] actual score: [0.]
# Model Score: [0.04371074] actual score: [0.]
# Model Score: [0.9984291] actual score: [1.]
# Model Score: [0.07726039] actual score: [0.]
# Model Score: [0.989521] actual score: [1.]
# Model Score: [0.78922236] actual score: [0.]
# Model Score: [0.5503759] actual score: [1.]
# Model Score: [0.93561435] actual score: [1.]
# Model Score: [0.3549895] actual score: [0.]
# Model Score: [0.9989139] actual score: [1.]
# Model Score: [0.97966206] actual score: [1.]
# Model Score: [0.991154] actual score: [1.]
# Model Score: [0.94414824] actual score: [1.]
# Model Score: [0.9999802] actual score: [1.]
# Model Score: [0.13521867] actual score: [0.]
# Model Score: [0.9380518] actual score: [1.]
# Model Score: [0.62000334] actual score: [0.]
# Model Score: [0.03702142] actual score: [0.]
# Model Score: [0.97693074] actual score: [1.]
# Model Score: [0.00941922] actual score: [0.]
# Model Score: [0.99747485] actual score: [1.]
# Model Score: [0.5593959] actual score: [1.]
# Model Score: [0.9669105] actual score: [1.]
# Model Score: [0.09602946] actual score: [0.]
# Model Score: [0.01560123] actual score: [0.]
# Model Score: [0.648584] actual score: [1.]
# Model Score: [0.00333671] actual score: [0.]
# Model Score: [0.40656862] actual score: [1.]
# Model Score: [0.05946719] actual score: [0.]
# Model Score: [0.9873657] actual score: [1.]
# Model Score: [0.8784588] actual score: [1.]
# Model Score: [0.00032761] actual score: [0.]
# Model Score: [0.97512394] actual score: [1.]
# Model Score: [0.00998894] actual score: [0.]
# Model Score: [0.00909599] actual score: [0.]
# Model Score: [0.8708466] actual score: [1.]
# Model Score: [0.01296422] actual score: [0.]
# Model Score: [0.9421914] actual score: [1.]
# Model Score: [0.9706227] actual score: [1.]
# Model Score: [0.9999299] actual score: [1.]
# Model Score: [0.97255355] actual score: [1.]
# Model Score: [0.9822563] actual score: [1.]
# Model Score: [0.9825768] actual score: [1.]
# Model Score: [0.99989986] actual score: [1.]
# Model Score: [0.33893093] actual score: [0.]
# Model Score: [0.2509071] actual score: [1.]
# Model Score: [0.00285321] actual score: [0.]
# Model Score: [0.5483325] actual score: [0.]
# Model Score: [0.9996704] actual score: [1.]
# Model Score: [0.5972422] actual score: [1.]
# Model Score: [0.13350621] actual score: [0.]
# Model Score: [0.04603105] actual score: [0.]
# Model Score: [0.7616032] actual score: [1.]
# Model Score: [0.01182355] actual score: [0.]
# Model Score: [0.46704957] actual score: [0.]
# Model Score: [0.04921672] actual score: [0.]
# Model Score: [0.0028518] actual score: [0.]
# Model Score: [0.01400282] actual score: [0.]
# Model Score: [0.24622552] actual score: [1.]
# Model Score: [0.997832] actual score: [1.]
# Model Score: [0.00019126] actual score: [0.]
# Model Score: [0.30492988] actual score: [0.]
# Model Score: [0.7795301] actual score: [1.]
# Model Score: [0.33943647] actual score: [0.]
# Model Score: [0.6297958] actual score: [1.]
# Model Score: [0.91804403] actual score: [0.]
# Model Score: [0.9989097] actual score: [1.]
# Model Score: [0.9910658] actual score: [1.]
# Model Score: [0.98437345] actual score: [1.]
# Model Score: [0.998287] actual score: [1.]
# Model Score: [0.03459257] actual score: [0.]
# Model Score: [0.00618129] actual score: [0.]
# Model Score: [0.01630268] actual score: [0.]
# Model Score: [0.01399246] actual score: [1.]
# Model Score: [0.999373] actual score: [1.]
# Model Score: [0.38301045] actual score: [1.]
# Model Score: [0.00140045] actual score: [0.]
# Model Score: [0.00949536] actual score: [0.]
# Model Score: [0.9892475] actual score: [1.]
# Model Score: [0.04752764] actual score: [1.]
# Model Score: [0.88853496] actual score: [1.]
# Model Score: [0.02243052] actual score: [0.]
# Model Score: [0.8462865] actual score: [1.]
# Model Score: [0.8404101] actual score: [1.]
# Model Score: [0.01743929] actual score: [0.]
# Model Score: [0.3649564] actual score: [1.]
# Model Score: [0.97755855] actual score: [1.]
# Model Score: [0.3426195] actual score: [1.]
# Model Score: [0.8995898] actual score: [1.]
# Model Score: [0.00455792] actual score: [0.]
# Model Score: [0.00392818] actual score: [0.]
# Model Score: [0.83290625] actual score: [1.]
# Model Score: [0.8000324] actual score: [1.]
# Model Score: [0.11659164] actual score: [0.]
# Model Score: [0.9095785] actual score: [1.]
# Model Score: [0.996111] actual score: [1.]
# Model Score: [0.9917481] actual score: [0.]
# Model Score: [0.03566994] actual score: [0.]
# Model Score: [0.0068346] actual score: [0.]
# Model Score: [0.99914] actual score: [1.]
# Model Score: [0.9563253] actual score: [1.]
# Model Score: [0.9507347] actual score: [1.]
# Model Score: [0.00036654] actual score: [0.]
# Model Score: [0.820349] actual score: [1.]
# Model Score: [0.8106092] actual score: [1.]
# Model Score: [0.90952057] actual score: [1.]
# Model Score: [0.3562061] actual score: [1.]
# Model Score: [0.6654011] actual score: [1.]
# Model Score: [0.97695446] actual score: [1.]
# Model Score: [0.89231247] actual score: [1.]
# Model Score: [0.9319373] actual score: [1.]
# Model Score: [0.5566304] actual score: [0.]
# Model Score: [0.87371397] actual score: [1.]
# Model Score: [0.9847403] actual score: [1.]
# Model Score: [0.01303262] actual score: [0.]
# Model Score: [0.8079457] actual score: [1.]
# Model Score: [0.9895705] actual score: [1.]
# Model Score: [0.00700532] actual score: [0.]
# Model Score: [0.8366572] actual score: [1.]
# Model Score: [0.11968248] actual score: [0.]
# Model Score: [0.2106265] actual score: [0.]
# Model Score: [0.01284282] actual score: [0.]
# Model Score: [0.9053104] actual score: [1.]
# Model Score: [0.6405126] actual score: [1.]
# Model Score: [0.9715116] actual score: [1.]
# Model Score: [0.98200905] actual score: [1.]
# Model Score: [0.03610009] actual score: [0.]
# Model Score: [0.01591461] actual score: [0.]
# Model Score: [0.24275391] actual score: [0.]
# Model Score: [0.00987979] actual score: [0.]
# Model Score: [0.01483232] actual score: [0.]
# Model Score: [0.01533006] actual score: [0.]
# Model Score: [0.62603337] actual score: [1.]
# Model Score: [0.9523626] actual score: [1.]
# Model Score: [0.09838492] actual score: [0.]
# Model Score: [0.01965605] actual score: [0.]
# Model Score: [0.00547079] actual score: [0.]
# Model Score: [0.25506] actual score: [0.]
# Model Score: [0.74196446] actual score: [0.]
# Model Score: [0.00961147] actual score: [0.]
# Model Score: [0.9986125] actual score: [1.]
# Model Score: [0.9736443] actual score: [1.]
# Model Score: [0.02717855] actual score: [1.]
# Model Score: [0.98365885] actual score: [1.]
# Model Score: [0.5535622] actual score: [1.]
# Model Score: [0.5968026] actual score: [1.]
# Model Score: [0.78195125] actual score: [1.]
# Model Score: [0.88446057] actual score: [0.]
