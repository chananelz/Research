# %%
import os
import matplotlib.pyplot as plt
import random
import numpy as np
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.datasets import cifar10
from keras.layers import Dense, Conv2D
from keras.layers import Flatten
from keras.layers.convolutional import MaxPooling2D
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils
# %matplotlib inline

# %%
# print(tf.version.VERSION)
# tf.config.list_physical_devices('GPU')

# %%
model_type = 'vgg16'

# %%
model_home_dir = os.path.join(os.getcwd(), 'CNN_TASK_ODED',"model_type")
print(model_home_dir)
if not os.path.isdir(model_home_dir):
    print('Inside mkdir')
    os.makedirs(model_home_dir)
# Out:
# /home/ec2-user/SageMaker/Research/AWS/CNN_TASK_ODED/model_type

# %%
#Defining Variables

#Data set information
DATASET = 'cifar-10'
num_classes = 2
input_shape=(32,32,3)
epochs = 200
lrate = 0.01
decay = lrate/epochs
batch_size = 32
seed = 7
np.random.seed(seed)

validate_dir = os.path.join("data","test")
train_dir = os.path.join("data","train")

# Prepare model model saving directory.
save_dir = os.path.join(model_home_dir, 'saved_models')

model_name = DATASET+'_'+'%s_model.{epoch:03d}.h5' % model_type

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print("Model Type: ",model_type)
print("Model File: ",filepath)
# Out:
# Model Type:  vgg16
# Model File:  /home/ec2-user/SageMaker/Research/AWS/CNN_TASK_ODED/model_type/saved_models/cifar-10_vgg16_model.{epoch:03d}.h5

# %%
import numpy

(X_train, y_train),(X_test,y_test) = cifar10.load_data()
X_train.shape, X_test.shape, X_train.shape[1:],X_train.dtype

class_1_index = np.where(y_train.reshape(-1) == 1)
X_train_class_1 = X_train[class_1_index]
y_train_class_1 = y_train[class_1_index]

class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# print("------------------y_train_class_1-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train_class_1[i])
#     plt.xlabel(class_names[y_train_class_1[i][0]])
# plt.show()

class_9_index = np.where(y_train.reshape(-1) == 9)
X_train_class_9 = X_train[class_9_index]
y_train_class_9 = y_train[class_9_index]

# print("------------------y_train_class_9-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train_class_9[i])
#     plt.xlabel(class_names[y_train_class_9[i][0]])
# plt.show()


X_train = np.concatenate((X_train_class_1, X_train_class_9))
y_train = np.concatenate((y_train_class_1, y_train_class_9)).reshape(-1,1)

# print("------------------concatenate train-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     j = random.randint(0,10000)
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train[j])
#     plt.xlabel(class_names[y_train[j][0]])
# plt.show()

# ---------------------------------------------------------------------------

class_1_index = np.where(y_test.reshape(-1) == 1)
X_test_class_1 = X_test[class_1_index]
y_test_class_1 = y_test[class_1_index]

# print("------------------y_test_class_1-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test_class_1[i])
#     plt.xlabel(class_names[y_test_class_1[i][0]])
# plt.show()

class_9_index = np.where(y_test.reshape(-1) == 9)
X_test_class_9 = X_test[class_9_index]
y_test_class_9 = y_test[class_9_index]


# print("------------------y_test_class_9-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test_class_9[i])
#     plt.xlabel(class_names[y_test_class_9[i][0]])
# plt.show()


X_test = np.concatenate((X_test_class_1, X_test_class_9))
y_test = np.concatenate((y_test_class_1, y_test_class_9)).reshape(-1,1)

# print("------------------concatenate test-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     j = random.randint(0,2000) 
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test[j])
#     plt.xlabel(class_names[y_test[j][0]])
# plt.show()

print(y_train.shape, y_test.shape)
print(X_train.shape, X_test.shape)
# Out:
# (10000, 1) (2000, 1)
# (10000, 32, 32, 3) (2000, 32, 32, 3)

# %%
y_train = np.where(y_train > 8, 1, 0)
y_test = np.where(y_test > 8, 1, 0)
class_names = ['automobile',  'truck']

print(y_train.shape, y_test.shape)
# Out:
# (10000, 1) (2000, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

X = np.concatenate((X_test, X_train))
Y = np.concatenate((y_test, y_train)).reshape(-1,1)

# X, y = shuffle(X, Y, random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.15)

print(y_train.shape, y_test.shape)
print(X_train.shape, X_test.shape)

print("------------------concatenate train-------------------")
plt.figure(figsize=(10,10))
for i in range(25):
    j = random.randint(0,10200)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[j])
    plt.xlabel(class_names[y_train[j][0]])
plt.show()

print("------------------concatenate test-------------------")
plt.figure(figsize=(10,10))
for i in range(25):
    j = random.randint(0,1800) 
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_test[j])
    plt.xlabel(class_names[y_test[j][0]])
plt.show()
# Out:
# (10200, 1) (1800, 1)
# (10200, 32, 32, 3) (1800, 32, 32, 3)
# ------------------concatenate train-------------------
# ------------------concatenate test-------------------

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.
X_test = X_test / 255.

X_train_mean = np.mean(X_train)
X_train -= X_train_mean
X_test_mean = np.mean(X_test)
X_test -= X_test_mean

y_train = np_utils.to_categorical(y_train,)
y_test = np_utils.to_categorical(y_test,)
y_train = np.delete(y_train,1,1)
y_test = np.delete(y_test,1,1)
print(y_train.shape, y_test.shape)
# Out:
# (10200, 1) (1800, 1)

# %%
import seaborn as sns
import pandas as pd


plt.title('Distribution')
sns.countplot(y = 0, data=pd.DataFrame(y_test))
plt.show()

print(f'y_test automobile: {np.count_nonzero(y_test == 0)}')
print(f'y_test truck: {np.count_nonzero(y_test == 1)}')

print('---------------------------------------------------------')

print(f'train automobile: {np.count_nonzero(y_train == 0)}')
print(f'train truck: {np.count_nonzero(y_train == 1)}')
# Out:
# y_test automobile: 878
# y_test truck: 922
# ---------------------------------------------------------
# train automobile: 5122
# train truck: 5078

# %%
from tensorflow.keras.layers import Dropout
def vgg16(input_shape=(32,32,3), num_classes=2):
  model = Sequential()
  model.add(Conv2D(input_shape=input_shape,filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))


  model.add(Dropout(0.8))

  model.add(Conv2D(filters=16, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=16, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  # model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  # model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Flatten())
  model.add(Dense(units=4096,activation="relu"))
  model.add(Dense(units=4096,activation="relu"))
  model.add(Dense(units=1, activation="sigmoid"))

  return model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
# Prepare callbacks for model saving and for learning rate adjustment.

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler,early_stopping]

# %%
import keras 
model = vgg16(input_shape,num_classes)

# Compile model

# optimizer = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(optimizer=optimizer,
              loss=keras.losses.BinaryCrossentropy(label_smoothing = 0.1),
              metrics=[keras.metrics.BinaryAccuracy()])

print("Model Summary of ",model_type)
print(model.summary())
# Out:
# Model Summary of  vgg16
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 16)        9232
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 4096)              4198400
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 21,034,081
# Trainable params: 21,034,081
# Non-trainable params: 0
# _________________________________________________________________
# None
# /home/ec2-user/anaconda3/envs/tensorflow2_p38/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Score trained model.
history = model.fit(X_train, y_train,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=(X_test, y_test),
      shuffle=True,
      callbacks=callbacks)
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Learning rate:  0.001
# Epoch 1/200
# 319/319 [==============================] - ETA: 0s - loss: 0.6575 - binary_accuracy: 0.6112WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 5s 7ms/step - loss: 0.6575 - binary_accuracy: 0.6112 - val_loss: 0.5572 - val_binary_accuracy: 0.7494 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/200
# 319/319 [==============================] - ETA: 0s - loss: 0.5097 - binary_accuracy: 0.7892WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.5097 - binary_accuracy: 0.7892 - val_loss: 0.4470 - val_binary_accuracy: 0.8517 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/200
# 319/319 [==============================] - ETA: 0s - loss: 0.4385 - binary_accuracy: 0.8470WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4385 - binary_accuracy: 0.8470 - val_loss: 0.4198 - val_binary_accuracy: 0.8517 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 319/319 [==============================] - ETA: 0s - loss: 0.4139 - binary_accuracy: 0.8640WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4139 - binary_accuracy: 0.8640 - val_loss: 0.4349 - val_binary_accuracy: 0.8583 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 319/319 [==============================] - ETA: 0s - loss: 0.4010 - binary_accuracy: 0.8732WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.4010 - binary_accuracy: 0.8732 - val_loss: 0.3983 - val_binary_accuracy: 0.8733 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 319/319 [==============================] - ETA: 0s - loss: 0.3832 - binary_accuracy: 0.8866WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3832 - binary_accuracy: 0.8866 - val_loss: 0.3793 - val_binary_accuracy: 0.8894 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 312/319 [============================>.] - ETA: 0s - loss: 0.3762 - binary_accuracy: 0.8881WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3753 - binary_accuracy: 0.8884 - val_loss: 0.3735 - val_binary_accuracy: 0.8906 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/200
# 312/319 [============================>.] - ETA: 0s - loss: 0.3667 - binary_accuracy: 0.8968WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3658 - binary_accuracy: 0.8974 - val_loss: 0.3576 - val_binary_accuracy: 0.9017 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/200
# 311/319 [============================>.] - ETA: 0s - loss: 0.3606 - binary_accuracy: 0.9013WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3607 - binary_accuracy: 0.9010 - val_loss: 0.3536 - val_binary_accuracy: 0.9056 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/200
# 313/319 [============================>.] - ETA: 0s - loss: 0.3491 - binary_accuracy: 0.9063WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3498 - binary_accuracy: 0.9060 - val_loss: 0.3487 - val_binary_accuracy: 0.9067 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/200
# 312/319 [============================>.] - ETA: 0s - loss: 0.3433 - binary_accuracy: 0.9111WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3439 - binary_accuracy: 0.9108 - val_loss: 0.3576 - val_binary_accuracy: 0.8994 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/200
# 311/319 [============================>.] - ETA: 0s - loss: 0.3396 - binary_accuracy: 0.9123WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3392 - binary_accuracy: 0.9129 - val_loss: 0.3458 - val_binary_accuracy: 0.9122 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/200
# 315/319 [============================>.] - ETA: 0s - loss: 0.3248 - binary_accuracy: 0.9243WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.3240 - binary_accuracy: 0.9249 - val_loss: 0.3387 - val_binary_accuracy: 0.9139 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/200
# 314/319 [============================>.] - ETA: 0s - loss: 0.3204 - binary_accuracy: 0.9245WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3207 - binary_accuracy: 0.9243 - val_loss: 0.3853 - val_binary_accuracy: 0.8861 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/200
# 315/319 [============================>.] - ETA: 0s - loss: 0.3192 - binary_accuracy: 0.9244WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3197 - binary_accuracy: 0.9242 - val_loss: 0.3615 - val_binary_accuracy: 0.8972 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/200
# 311/319 [============================>.] - ETA: 0s - loss: 0.3067 - binary_accuracy: 0.9350WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 5ms/step - loss: 0.3071 - binary_accuracy: 0.9345 - val_loss: 0.3609 - val_binary_accuracy: 0.9000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/200
# 311/319 [============================>.] - ETA: 0s - loss: 0.2998 - binary_accuracy: 0.9403WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.2998 - binary_accuracy: 0.9402 - val_loss: 0.3370 - val_binary_accuracy: 0.9172 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/200
# 311/319 [============================>.] - ETA: 0s - loss: 0.2996 - binary_accuracy: 0.9381WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 5ms/step - loss: 0.2991 - binary_accuracy: 0.9385 - val_loss: 0.3557 - val_binary_accuracy: 0.9028 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/200
# 311/319 [============================>.] - ETA: 0s - loss: 0.2901 - binary_accuracy: 0.9469WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 5ms/step - loss: 0.2904 - binary_accuracy: 0.9466 - val_loss: 0.3735 - val_binary_accuracy: 0.8878 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/200
# 311/319 [============================>.] - ETA: 0s - loss: 0.2806 - binary_accuracy: 0.9519WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 5ms/step - loss: 0.2808 - binary_accuracy: 0.9519 - val_loss: 0.3456 - val_binary_accuracy: 0.9061 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/200
# 312/319 [============================>.] - ETA: 0s - loss: 0.2774 - binary_accuracy: 0.9545WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 5ms/step - loss: 0.2777 - binary_accuracy: 0.9544 - val_loss: 0.3532 - val_binary_accuracy: 0.9028 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/200
# 312/319 [============================>.] - ETA: 0s - loss: 0.2737 - binary_accuracy: 0.9554WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 2s 6ms/step - loss: 0.2743 - binary_accuracy: 0.9548 - val_loss: 0.3591 - val_binary_accuracy: 0.9011 - lr: 3.1623e-04
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3370 - binary_accuracy: 0.9172
# Test loss: 0.33700886368751526
# Test accuracy: 0.9172222018241882

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy', 'lr'])

# %%
from sklearn.metrics import roc_curve, auc

y_pred = model.predict(X_test).ravel()

nn_fpr_keras, nn_tpr_keras, nn_thresholds_keras = roc_curve(y_test, y_pred)
auc_keras = auc(nn_fpr_keras, nn_tpr_keras)
plt.plot(nn_fpr_keras, nn_tpr_keras, marker='.', label='Neural Network (auc = %0.3f)' % auc_keras)
plt.title('ROC Curve')
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.show()

print(auc_keras)
# Out:
# 0.9694558229855864

# %%
from matplotlib import pyplot
predict_x=model.predict(X_test) 

automobile_index = np.where(y_test.reshape(-1) == 0.)
automobile = predict_x[automobile_index]

truck_index = np.where(y_test.reshape(-1) == 1.)
truck = predict_x[truck_index]



bins = np.linspace(0, 1, 100)

pyplot.hist(automobile, bins, alpha=0.5, label='automobile')
pyplot.hist(truck, bins, alpha=0.5, label='truck')
pyplot.legend(loc='upper right')
pyplot.show()

# %%
len(automobile)
# Out:
# 878

# %%
len(truck)
# Out:
# 922

# %%
# for X,Y in zip(predict_x,y_test):
#     print("Model Score:", X, "actual score:", Y)
