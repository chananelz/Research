# %%
import os
import matplotlib.pyplot as plt
import random
import numpy as np
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.datasets import cifar10
from keras.layers import Add, Dense, Activation, BatchNormalization, Conv2D
from keras.layers import Flatten
from keras.layers.convolutional import MaxPooling2D
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils
from keras.initializers import glorot_uniform
# %matplotlib inline

# %%
model_type = 'vgg16'

# %%
model_home_dir = os.path.join(os.getcwd(), 'CNN_TASK_ODED',"model_type")
print(model_home_dir)
if not os.path.isdir(model_home_dir):
    print('Inside mkdir')
    os.makedirs(model_home_dir)
# Out:
# /content/CNN_TASK_ODED/model_type

# %%
#Defining Variables

#Data set information
DATASET = 'cifar-10'
num_classes = 2
input_shape=(32,32,3)
epochs = 200
lrate = 0.01
decay = lrate/epochs
batch_size = 32
seed = 7
np.random.seed(seed)

validate_dir = os.path.join("data","test")
train_dir = os.path.join("data","train")

# Prepare model model saving directory.
save_dir = os.path.join(model_home_dir, 'saved_models')

model_name = DATASET+'_'+'%s_model.{epoch:03d}.h5' % model_type

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print("Model Type: ",model_type)
print("Model File: ",filepath)
# Out:
# Model Type:  vgg16
# Model File:  /content/CNN_TASK_ODED/model_type/saved_models/cifar-10_vgg16_model.{epoch:03d}.h5

# %%
import numpy

(X_train, y_train),(X_test,y_test) = cifar10.load_data()
X_train.shape, X_test.shape, X_train.shape[1:],X_train.dtype

class_4_index = np.where(y_train.reshape(-1) == 4)
X_train_class_4 = X_train[class_4_index]
y_train_class_4 = y_train[class_4_index]

class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# print("------------------y_train_class_4-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train_class_4[i])
#     plt.xlabel(class_names[y_train_class_4[i][0]])
# plt.show()

class_7_index = np.where(y_train.reshape(-1) == 7)
X_train_class_7 = X_train[class_7_index]
y_train_class_7 = y_train[class_7_index]

# print("------------------y_train_class_7-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train_class_7[i])
#     plt.xlabel(class_names[y_train_class_7[i][0]])
# plt.show()


X_train = np.concatenate((X_train_class_4, X_train_class_7))
y_train = np.concatenate((y_train_class_4, y_train_class_7)).reshape(-1,1)

# print("------------------concatenate train-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     j = random.randint(0,10000)
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_train[j])
#     plt.xlabel(class_names[y_train[j][0]])
# plt.show()

# ---------------------------------------------------------------------------

class_4_index = np.where(y_test.reshape(-1) == 4)
X_test_class_4 = X_test[class_4_index]
y_test_class_4 = y_test[class_4_index]

# print("------------------y_test_class_4-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test_class_4[i])
#     plt.xlabel(class_names[y_test_class_4[i][0]])
# plt.show()

class_7_index = np.where(y_test.reshape(-1) == 7)
X_test_class_7 = X_test[class_7_index]
y_test_class_7 = y_test[class_7_index]


# print("------------------y_test_class_7-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test_class_7[i])
#     plt.xlabel(class_names[y_test_class_7[i][0]])
# plt.show()


X_test = np.concatenate((X_test_class_4, X_test_class_7))
y_test = np.concatenate((y_test_class_4, y_test_class_7)).reshape(-1,1)

# print("------------------concatenate test-------------------")
# plt.figure(figsize=(10,10))
# for i in range(25):
#     j = random.randint(0,2000) 
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(X_test[j])
#     plt.xlabel(class_names[y_test[j][0]])
# plt.show()

print(y_train.shape, y_test.shape)
print(X_train.shape, X_test.shape)
# Out:
# (10000, 1) (2000, 1)
# (10000, 32, 32, 3) (2000, 32, 32, 3)

# %%
y_train = np.where(y_train > 5, 1, 0)
y_test = np.where(y_test > 5, 1, 0)
class_names = ["deer","horse",]

print(y_train.shape, y_test.shape)
# Out:
# (10000, 1) (2000, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

X = np.concatenate((X_test, X_train))
Y = np.concatenate((y_test, y_train)).reshape(-1,1)

# X, y = shuffle(X, Y, random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.15)

print(y_train.shape, y_test.shape)
print(X_train.shape, X_test.shape)

print("------------------concatenate train-------------------")
plt.figure(figsize=(10,10))
for i in range(25):
    j = random.randint(0,10200)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[j])
    plt.xlabel(class_names[y_train[j][0]])
plt.show()

print("------------------concatenate test-------------------")
plt.figure(figsize=(10,10))
for i in range(25):
    j = random.randint(0,1800) 
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_test[j])
    plt.xlabel(class_names[y_test[j][0]])
plt.show()
# Out:
# (10200, 1) (1800, 1)
# (10200, 32, 32, 3) (1800, 32, 32, 3)
# ------------------concatenate train-------------------
# ------------------concatenate test-------------------

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.
X_test = X_test / 255.

X_train_mean = np.mean(X_train)
X_train -= X_train_mean
X_test_mean = np.mean(X_test)
X_test -= X_test_mean

y_train = np_utils.to_categorical(y_train,)
y_test = np_utils.to_categorical(y_test,)
y_train = np.delete(y_train,1,1)
y_test = np.delete(y_test,1,1)
print(y_train.shape, y_test.shape)
# Out:
# (10200, 1) (1800, 1)

# %%
from tensorflow.keras.layers import Dropout
def vgg16(input_shape=(32,32,3), num_classes=2):
  model = Sequential()
  model.add(Conv2D(input_shape=input_shape,filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))


  model.add(Dropout(0.8))

  model.add(Conv2D(filters=16, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=16, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
  # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Flatten())
  model.add(Dense(units=4096,activation="relu"))
  model.add(Dense(units=4096,activation="relu"))
  model.add(Dense(units=1, activation="sigmoid"))

  return model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
# Prepare callbacks for model saving and for learning rate adjustment.

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler,early_stopping]

# %%
 model = vgg16(input_shape,num_classes)

# Compile model

# optimizer = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss= 'binary_crossentropy' , optimizer=optimizer, metrics=['accuracy'])
print("Model Summary of ",model_type)
print(model.summary())
# Out:
# Model Summary of  vgg16
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 16)        9232
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          4640
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 32)          9248
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 32)          9248
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 64)          18496
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 64)          36928
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 18,003,841
# Trainable params: 18,003,841
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Score trained model.
history = model.fit(X_train, y_train,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=(X_test, y_test),
      shuffle=True,
      callbacks=callbacks)
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Learning rate:  0.001
# Epoch 1/200
# 319/319 [==============================] - ETA: 0s - loss: 0.5986 - accuracy: 0.6697
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 13s 13ms/step - loss: 0.5986 - accuracy: 0.6697 - val_loss: 0.5634 - val_accuracy: 0.7417 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/200
# 316/319 [============================>.] - ETA: 0s - loss: 0.4960 - accuracy: 0.7654
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.4951 - accuracy: 0.7659 - val_loss: 0.5197 - val_accuracy: 0.7583 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/200
# 315/319 [============================>.] - ETA: 0s - loss: 0.4459 - accuracy: 0.7929
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.4457 - accuracy: 0.7930 - val_loss: 0.4685 - val_accuracy: 0.7661 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 318/319 [============================>.] - ETA: 0s - loss: 0.4249 - accuracy: 0.8025
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 3s 11ms/step - loss: 0.4248 - accuracy: 0.8026 - val_loss: 0.4800 - val_accuracy: 0.7844 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 317/319 [============================>.] - ETA: 0s - loss: 0.4001 - accuracy: 0.8193
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.3999 - accuracy: 0.8193 - val_loss: 0.3839 - val_accuracy: 0.8239 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 317/319 [============================>.] - ETA: 0s - loss: 0.3845 - accuracy: 0.8282
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.3848 - accuracy: 0.8280 - val_loss: 0.4446 - val_accuracy: 0.7872 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 318/319 [============================>.] - ETA: 0s - loss: 0.3675 - accuracy: 0.8368
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.3674 - accuracy: 0.8368 - val_loss: 0.4217 - val_accuracy: 0.8039 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/200
# 314/319 [============================>.] - ETA: 0s - loss: 0.3499 - accuracy: 0.8478
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.3498 - accuracy: 0.8478 - val_loss: 0.4512 - val_accuracy: 0.7950 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/200
# 317/319 [============================>.] - ETA: 0s - loss: 0.3390 - accuracy: 0.8521
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.3392 - accuracy: 0.8518 - val_loss: 0.3517 - val_accuracy: 0.8394 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/200
# 315/319 [============================>.] - ETA: 0s - loss: 0.3327 - accuracy: 0.8568
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 3s 11ms/step - loss: 0.3322 - accuracy: 0.8570 - val_loss: 0.3658 - val_accuracy: 0.8428 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/200
# 319/319 [==============================] - ETA: 0s - loss: 0.3095 - accuracy: 0.8659
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.3095 - accuracy: 0.8659 - val_loss: 0.3507 - val_accuracy: 0.8383 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/200
# 319/319 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.8697
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2994 - accuracy: 0.8697 - val_loss: 0.3844 - val_accuracy: 0.8306 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/200
# 318/319 [============================>.] - ETA: 0s - loss: 0.2935 - accuracy: 0.8763
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2933 - accuracy: 0.8764 - val_loss: 0.3460 - val_accuracy: 0.8417 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/200
# 317/319 [============================>.] - ETA: 0s - loss: 0.2813 - accuracy: 0.8795
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2812 - accuracy: 0.8795 - val_loss: 0.3178 - val_accuracy: 0.8583 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/200
# 319/319 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.8847
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2702 - accuracy: 0.8847 - val_loss: 0.3386 - val_accuracy: 0.8550 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/200
# 315/319 [============================>.] - ETA: 0s - loss: 0.2656 - accuracy: 0.8886
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2650 - accuracy: 0.8889 - val_loss: 0.3313 - val_accuracy: 0.8600 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/200
# 319/319 [==============================] - ETA: 0s - loss: 0.2709 - accuracy: 0.8871
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2709 - accuracy: 0.8871 - val_loss: 0.3397 - val_accuracy: 0.8528 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/200
# 317/319 [============================>.] - ETA: 0s - loss: 0.2617 - accuracy: 0.8898
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2611 - accuracy: 0.8903 - val_loss: 0.3358 - val_accuracy: 0.8611 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/200
# 317/319 [============================>.] - ETA: 0s - loss: 0.2495 - accuracy: 0.8965
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 319/319 [==============================] - 4s 12ms/step - loss: 0.2494 - accuracy: 0.8965 - val_loss: 0.3437 - val_accuracy: 0.8622 - lr: 3.1623e-04
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3178 - accuracy: 0.8583
# Test loss: 0.3178069293498993
# Test accuracy: 0.8583333492279053

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
from sklearn.metrics import roc_curve, auc

y_pred = model.predict(X_test).ravel()

nn_fpr_keras, nn_tpr_keras, nn_thresholds_keras = roc_curve(y_test, y_pred)
auc_keras = auc(nn_fpr_keras, nn_tpr_keras)
plt.plot(nn_fpr_keras, nn_tpr_keras, marker='.', label='Neural Network (auc = %0.3f)' % auc_keras)
plt.title('ROC Curve')
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.show()

print(auc_keras)
# Out:
# 57/57 [==============================] - 0s 5ms/step
# 0.9398504785575579

# %%
from matplotlib import pyplot
predict_x=model.predict(X_test) 

deer_index = np.where(y_test.reshape(-1) == 0.)
deer  = predict_x[deer_index]

horse_index = np.where(y_test.reshape(-1) == 1.)
horse = predict_x[horse_index]



bins = np.linspace(0, 1, 100)

pyplot.hist(deer, bins, alpha=0.5, label='deer')
pyplot.hist(horse, bins, alpha=0.5, label='horse')
pyplot.legend(loc='upper right')
pyplot.show()
# Out:
# 57/57 [==============================] - 0s 3ms/step

# %%
for X,Y in zip(predict_x,y_test):
    print("Model Score:", X, "actual score:", Y)
# Out:
# Model Score: [0.9543255] actual score: [0.]
# Model Score: [0.15837255] actual score: [0.]
# Model Score: [0.35727578] actual score: [0.]
# Model Score: [0.09720694] actual score: [0.]
# Model Score: [0.8431374] actual score: [1.]
# Model Score: [0.936567] actual score: [1.]
# Model Score: [0.9370985] actual score: [1.]
# Model Score: [0.99327385] actual score: [1.]
# Model Score: [0.01136125] actual score: [0.]
# Model Score: [0.28099093] actual score: [1.]
# Model Score: [0.99793553] actual score: [1.]
# Model Score: [0.6141834] actual score: [0.]
# Model Score: [0.83486205] actual score: [1.]
# Model Score: [0.04844467] actual score: [0.]
# Model Score: [0.8554062] actual score: [0.]
# Model Score: [0.10930762] actual score: [0.]
# Model Score: [0.9349622] actual score: [1.]
# Model Score: [0.01126919] actual score: [0.]
# Model Score: [0.90922153] actual score: [1.]
# Model Score: [0.8012713] actual score: [0.]
# Model Score: [0.14537509] actual score: [1.]
# Model Score: [0.15565304] actual score: [0.]
# Model Score: [8.8283385e-05] actual score: [0.]
# Model Score: [0.54383373] actual score: [1.]
# Model Score: [0.8039659] actual score: [1.]
# Model Score: [0.3427018] actual score: [0.]
# Model Score: [0.6858688] actual score: [1.]
# Model Score: [0.13738587] actual score: [1.]
# Model Score: [0.00483099] actual score: [0.]
# Model Score: [0.769001] actual score: [1.]
# Model Score: [0.577144] actual score: [1.]
# Model Score: [0.96909285] actual score: [1.]
# Model Score: [0.0149256] actual score: [0.]
# Model Score: [0.9904123] actual score: [1.]
# Model Score: [0.12077019] actual score: [0.]
# Model Score: [0.8903491] actual score: [1.]
# Model Score: [0.12749724] actual score: [0.]
# Model Score: [0.5432338] actual score: [0.]
# Model Score: [0.86698127] actual score: [1.]
# Model Score: [0.87646455] actual score: [1.]
# Model Score: [0.6894433] actual score: [1.]
# Model Score: [0.2495069] actual score: [1.]
# Model Score: [0.0664977] actual score: [0.]
# Model Score: [0.07119746] actual score: [0.]
# Model Score: [0.98712254] actual score: [1.]
# Model Score: [0.9080176] actual score: [1.]
# Model Score: [0.58588636] actual score: [0.]
# Model Score: [0.5568984] actual score: [0.]
# Model Score: [0.96568274] actual score: [1.]
# Model Score: [0.14901239] actual score: [0.]
# Model Score: [0.37331742] actual score: [0.]
# Model Score: [0.9831859] actual score: [1.]
# Model Score: [0.05657821] actual score: [0.]
# Model Score: [0.49195325] actual score: [0.]
# Model Score: [0.9533013] actual score: [1.]
# Model Score: [0.3040508] actual score: [0.]
# Model Score: [0.9683737] actual score: [1.]
# Model Score: [0.9400668] actual score: [1.]
# Model Score: [0.99329007] actual score: [1.]
# Model Score: [0.17569071] actual score: [0.]
# Model Score: [0.8621548] actual score: [1.]
# Model Score: [0.27238548] actual score: [1.]
# Model Score: [0.37115666] actual score: [0.]
# Model Score: [0.44419798] actual score: [1.]
# Model Score: [0.8355259] actual score: [0.]
# Model Score: [0.9855643] actual score: [1.]
# Model Score: [0.08242431] actual score: [0.]
# Model Score: [0.7416333] actual score: [1.]
# Model Score: [0.9948866] actual score: [1.]
# Model Score: [0.9331823] actual score: [1.]
# Model Score: [0.04769596] actual score: [0.]
# Model Score: [2.0217672e-05] actual score: [0.]
# Model Score: [0.46180904] actual score: [1.]
# Model Score: [0.4364405] actual score: [0.]
# Model Score: [0.8712492] actual score: [1.]
# Model Score: [0.29887137] actual score: [0.]
# Model Score: [0.73331136] actual score: [1.]
# Model Score: [0.01174451] actual score: [0.]
# Model Score: [0.999532] actual score: [1.]
# Model Score: [0.9042496] actual score: [1.]
# Model Score: [0.945041] actual score: [1.]
# Model Score: [0.46748418] actual score: [1.]
# Model Score: [0.00684419] actual score: [0.]
# Model Score: [0.9707127] actual score: [1.]
# Model Score: [0.9898191] actual score: [1.]
# Model Score: [0.8086647] actual score: [1.]
# Model Score: [0.00919968] actual score: [0.]
# Model Score: [0.9909189] actual score: [1.]
# Model Score: [0.95758736] actual score: [1.]
# Model Score: [0.00138339] actual score: [0.]
# Model Score: [0.8382292] actual score: [0.]
# Model Score: [0.9706462] actual score: [1.]
# Model Score: [0.7526711] actual score: [1.]
# Model Score: [0.649446] actual score: [0.]
# Model Score: [0.27643025] actual score: [0.]
# Model Score: [0.9898022] actual score: [1.]
# Model Score: [0.05604399] actual score: [0.]
# Model Score: [0.30713835] actual score: [0.]
# Model Score: [0.98919487] actual score: [1.]
# Model Score: [0.06238183] actual score: [0.]
# Model Score: [0.8964987] actual score: [1.]
# Model Score: [0.01668874] actual score: [0.]
# Model Score: [0.7411468] actual score: [0.]
# Model Score: [0.9924038] actual score: [1.]
# Model Score: [0.9831872] actual score: [1.]
# Model Score: [0.43495554] actual score: [1.]
# Model Score: [0.41731367] actual score: [0.]
# Model Score: [0.1195685] actual score: [0.]
# Model Score: [0.4152112] actual score: [0.]
# Model Score: [0.55368143] actual score: [1.]
# Model Score: [0.00451657] actual score: [0.]
# Model Score: [0.0257455] actual score: [0.]
# Model Score: [0.42995125] actual score: [0.]
# Model Score: [0.67475414] actual score: [0.]
# Model Score: [0.4088033] actual score: [0.]
# Model Score: [0.8386969] actual score: [1.]
# Model Score: [0.02231809] actual score: [0.]
# Model Score: [0.8116746] actual score: [0.]
# Model Score: [0.85537595] actual score: [1.]
# Model Score: [0.85423553] actual score: [1.]
# Model Score: [0.90237] actual score: [1.]
# Model Score: [0.95034784] actual score: [1.]
# Model Score: [0.9996061] actual score: [1.]
# Model Score: [0.12728761] actual score: [0.]
# Model Score: [0.9995347] actual score: [1.]
# Model Score: [0.9835671] actual score: [1.]
# Model Score: [0.9576892] actual score: [1.]
# Model Score: [0.9953431] actual score: [1.]
# Model Score: [0.21705505] actual score: [0.]
# Model Score: [0.03869424] actual score: [0.]
# Model Score: [0.97396] actual score: [1.]
# Model Score: [0.9809645] actual score: [1.]
# Model Score: [0.99797577] actual score: [1.]
# Model Score: [0.8275433] actual score: [1.]
# Model Score: [0.9755585] actual score: [1.]
# Model Score: [0.00254478] actual score: [0.]
# Model Score: [0.9717311] actual score: [1.]
# Model Score: [0.01768853] actual score: [0.]
# Model Score: [0.47208634] actual score: [0.]
# Model Score: [0.1627147] actual score: [0.]
# Model Score: [0.00298041] actual score: [0.]
# Model Score: [0.00395788] actual score: [0.]
# Model Score: [0.82884437] actual score: [0.]
# Model Score: [0.9606195] actual score: [1.]
# Model Score: [0.9949138] actual score: [1.]
# Model Score: [0.14179896] actual score: [0.]
# Model Score: [0.11359029] actual score: [0.]
# Model Score: [0.9265351] actual score: [1.]
# Model Score: [0.5936246] actual score: [0.]
# Model Score: [0.7295127] actual score: [1.]
# Model Score: [0.90781707] actual score: [1.]
# Model Score: [0.5352648] actual score: [0.]
# Model Score: [0.9989153] actual score: [1.]
# Model Score: [0.93340266] actual score: [1.]
# Model Score: [0.91506845] actual score: [1.]
# Model Score: [0.5165983] actual score: [0.]
# Model Score: [0.38168108] actual score: [1.]
# Model Score: [0.13703904] actual score: [0.]
# Model Score: [0.95112115] actual score: [1.]
# Model Score: [0.14987926] actual score: [0.]
# Model Score: [0.19623668] actual score: [1.]
# Model Score: [0.5577554] actual score: [0.]
# Model Score: [0.98426694] actual score: [1.]
# Model Score: [0.9984261] actual score: [1.]
# Model Score: [0.61302876] actual score: [1.]
# Model Score: [0.52576303] actual score: [0.]
# Model Score: [0.7077026] actual score: [1.]
# Model Score: [0.3272383] actual score: [1.]
# Model Score: [0.96357685] actual score: [1.]
# Model Score: [0.00515852] actual score: [0.]
# Model Score: [0.05445853] actual score: [0.]
# Model Score: [0.22933622] actual score: [0.]
# Model Score: [0.66924196] actual score: [1.]
# Model Score: [0.9618654] actual score: [1.]
# Model Score: [0.0617361] actual score: [0.]
# Model Score: [0.3213597] actual score: [0.]
# Model Score: [0.11137874] actual score: [0.]
# Model Score: [0.2563429] actual score: [1.]
# Model Score: [0.29903185] actual score: [0.]
# Model Score: [0.14642364] actual score: [0.]
# Model Score: [0.51235694] actual score: [0.]
# Model Score: [1.0061191e-05] actual score: [0.]
# Model Score: [0.24993967] actual score: [0.]
# Model Score: [0.3591727] actual score: [1.]
# Model Score: [0.809912] actual score: [1.]
# Model Score: [0.12324386] actual score: [0.]
# Model Score: [0.00022304] actual score: [0.]
# Model Score: [0.49279332] actual score: [1.]
# Model Score: [0.8989197] actual score: [0.]
# Model Score: [0.23795466] actual score: [0.]
# Model Score: [0.9890463] actual score: [1.]
# Model Score: [0.5404502] actual score: [1.]
# Model Score: [0.6587787] actual score: [1.]
# Model Score: [0.95266956] actual score: [1.]
# Model Score: [0.98608893] actual score: [1.]
# Model Score: [0.93884814] actual score: [0.]
# Model Score: [0.00828497] actual score: [0.]
# Model Score: [0.9763055] actual score: [1.]
# Model Score: [0.8587535] actual score: [1.]
# Model Score: [0.99068683] actual score: [1.]
# Model Score: [0.07266581] actual score: [0.]
# Model Score: [0.0081495] actual score: [0.]
# Model Score: [0.15706836] actual score: [0.]
# Model Score: [0.9233873] actual score: [0.]
# Model Score: [0.9595654] actual score: [1.]
# Model Score: [0.98211205] actual score: [1.]
# Model Score: [0.71628094] actual score: [1.]
# Model Score: [0.92694] actual score: [1.]
# Model Score: [0.93576896] actual score: [1.]
# Model Score: [0.98506016] actual score: [1.]
# Model Score: [0.98571646] actual score: [1.]
# Model Score: [0.8175988] actual score: [1.]
# Model Score: [0.00165852] actual score: [0.]
# Model Score: [0.46891248] actual score: [0.]
# Model Score: [0.9331495] actual score: [0.]
# Model Score: [0.12747385] actual score: [0.]
# Model Score: [0.8889603] actual score: [1.]
# Model Score: [0.33901206] actual score: [1.]
# Model Score: [0.838037] actual score: [1.]
# Model Score: [0.96503663] actual score: [1.]
# Model Score: [0.9902254] actual score: [1.]
# Model Score: [0.9038936] actual score: [1.]
# Model Score: [0.27218747] actual score: [0.]
# Model Score: [0.19417238] actual score: [0.]
# Model Score: [0.12507452] actual score: [0.]
# Model Score: [0.91169244] actual score: [1.]
# Model Score: [0.9978733] actual score: [1.]
# Model Score: [0.8432851] actual score: [1.]
# Model Score: [0.56266516] actual score: [1.]
# Model Score: [0.9907782] actual score: [1.]
# Model Score: [0.9957034] actual score: [1.]
# Model Score: [0.22164595] actual score: [0.]
# Model Score: [0.71520597] actual score: [0.]
# Model Score: [0.05272864] actual score: [0.]
# Model Score: [0.10352254] actual score: [0.]
# Model Score: [0.28327727] actual score: [1.]
# Model Score: [0.4827719] actual score: [1.]
# Model Score: [0.3030561] actual score: [0.]
# Model Score: [0.9555491] actual score: [1.]
# Model Score: [0.40900287] actual score: [0.]
# Model Score: [0.89172524] actual score: [1.]
# Model Score: [0.64225835] actual score: [0.]
# Model Score: [0.59428185] actual score: [0.]
# Model Score: [0.8122002] actual score: [1.]
# Model Score: [0.8868565] actual score: [1.]
# Model Score: [0.09501918] actual score: [0.]
# Model Score: [0.9800816] actual score: [1.]
# Model Score: [0.30197978] actual score: [0.]
# Model Score: [0.02187969] actual score: [0.]
# Model Score: [0.99424595] actual score: [1.]
# Model Score: [0.08015385] actual score: [0.]
# Model Score: [0.9905317] actual score: [1.]
# Model Score: [0.89322925] actual score: [1.]
# Model Score: [0.13813005] actual score: [1.]
# Model Score: [0.97604173] actual score: [1.]
# Model Score: [0.8378735] actual score: [1.]
# Model Score: [0.3349756] actual score: [0.]
# Model Score: [0.7595973] actual score: [1.]
# Model Score: [0.14650163] actual score: [1.]
# Model Score: [0.10204584] actual score: [0.]
# Model Score: [0.9656163] actual score: [1.]
# Model Score: [0.99290717] actual score: [1.]
# Model Score: [0.90541214] actual score: [1.]
# Model Score: [0.9819978] actual score: [1.]
# Model Score: [0.9393312] actual score: [1.]
# Model Score: [0.9336002] actual score: [1.]
# Model Score: [0.17317714] actual score: [0.]
# Model Score: [0.07205039] actual score: [0.]
# Model Score: [0.8985565] actual score: [0.]
# Model Score: [0.0022211] actual score: [0.]
# Model Score: [9.52873e-06] actual score: [0.]
# Model Score: [0.57821417] actual score: [1.]
# Model Score: [0.19659275] actual score: [0.]
# Model Score: [0.00548275] actual score: [0.]
# Model Score: [0.1695136] actual score: [0.]
# Model Score: [0.06243107] actual score: [0.]
# Model Score: [0.9642121] actual score: [1.]
# Model Score: [0.00672568] actual score: [0.]
# Model Score: [0.227465] actual score: [0.]
# Model Score: [0.10712461] actual score: [0.]
# Model Score: [0.9989919] actual score: [1.]
# Model Score: [0.00045011] actual score: [0.]
# Model Score: [0.9942298] actual score: [1.]
# Model Score: [0.01939811] actual score: [0.]
# Model Score: [0.07125928] actual score: [0.]
# Model Score: [0.4152306] actual score: [0.]
# Model Score: [0.94229186] actual score: [1.]
# Model Score: [0.10161999] actual score: [0.]
# Model Score: [0.2243258] actual score: [1.]
# Model Score: [0.99681866] actual score: [1.]
# Model Score: [0.40461424] actual score: [0.]
# Model Score: [0.7169964] actual score: [1.]
# Model Score: [0.9777517] actual score: [1.]
# Model Score: [0.01500358] actual score: [0.]
# Model Score: [0.98503774] actual score: [1.]
# Model Score: [0.00651683] actual score: [0.]
# Model Score: [0.8216794] actual score: [1.]
# Model Score: [0.961301] actual score: [1.]
# Model Score: [0.8753369] actual score: [1.]
# Model Score: [0.21563907] actual score: [0.]
# Model Score: [6.376098e-06] actual score: [0.]
# Model Score: [0.93413967] actual score: [1.]
# Model Score: [0.9167742] actual score: [1.]
# Model Score: [0.17497699] actual score: [0.]
# Model Score: [0.210285] actual score: [0.]
# Model Score: [0.00204472] actual score: [0.]
# Model Score: [0.23418114] actual score: [0.]
# Model Score: [0.98844063] actual score: [1.]
# Model Score: [0.23832887] actual score: [0.]
# Model Score: [0.962993] actual score: [1.]
# Model Score: [0.35896456] actual score: [0.]
# Model Score: [0.01189592] actual score: [0.]
# Model Score: [0.40209064] actual score: [0.]
# Model Score: [0.00682693] actual score: [0.]
# Model Score: [0.4582918] actual score: [0.]
# Model Score: [0.9566334] actual score: [1.]
# Model Score: [0.00050425] actual score: [0.]
# Model Score: [0.951686] actual score: [1.]
# Model Score: [0.02091196] actual score: [0.]
# Model Score: [0.99318933] actual score: [1.]
# Model Score: [0.91880953] actual score: [1.]
# Model Score: [0.12655948] actual score: [1.]
# Model Score: [0.5738274] actual score: [1.]
# Model Score: [0.9204592] actual score: [1.]
# Model Score: [0.1027741] actual score: [0.]
# Model Score: [0.27929613] actual score: [0.]
# Model Score: [0.93767864] actual score: [1.]
# Model Score: [0.99891245] actual score: [1.]
# Model Score: [0.15903936] actual score: [0.]
# Model Score: [0.91491735] actual score: [1.]
# Model Score: [0.6214926] actual score: [0.]
# Model Score: [0.3182167] actual score: [0.]
# Model Score: [0.00024829] actual score: [0.]
# Model Score: [0.00725894] actual score: [0.]
# Model Score: [0.00048066] actual score: [0.]
# Model Score: [0.32807982] actual score: [1.]
# Model Score: [0.46759066] actual score: [1.]
# Model Score: [0.3309924] actual score: [1.]
# Model Score: [0.9332479] actual score: [1.]
# Model Score: [0.88462704] actual score: [1.]
# Model Score: [0.8251024] actual score: [1.]
# Model Score: [0.7710459] actual score: [0.]
# Model Score: [0.7714422] actual score: [1.]
# Model Score: [0.02271275] actual score: [0.]
# Model Score: [0.00341901] actual score: [0.]
# Model Score: [0.9866623] actual score: [1.]
# Model Score: [0.66751236] actual score: [1.]
# Model Score: [0.9575016] actual score: [1.]
# Model Score: [0.28650194] actual score: [0.]
# Model Score: [0.36265546] actual score: [0.]
# Model Score: [0.0421614] actual score: [0.]
# Model Score: [0.45389128] actual score: [1.]
# Model Score: [0.47772184] actual score: [0.]
# Model Score: [0.38922286] actual score: [0.]
# Model Score: [0.9988599] actual score: [1.]
# Model Score: [4.52217e-07] actual score: [0.]
# Model Score: [0.2278408] actual score: [0.]
# Model Score: [0.07629607] actual score: [0.]
# Model Score: [0.9892246] actual score: [1.]
# Model Score: [0.796743] actual score: [1.]
# Model Score: [0.9360654] actual score: [1.]
# Model Score: [0.2148267] actual score: [0.]
# Model Score: [0.00171763] actual score: [0.]
# Model Score: [0.7157337] actual score: [1.]
# Model Score: [0.98256403] actual score: [1.]
# Model Score: [0.09801586] actual score: [0.]
# Model Score: [0.5037749] actual score: [1.]
# Model Score: [0.9898896] actual score: [1.]
# Model Score: [0.99489355] actual score: [1.]
# Model Score: [0.9994242] actual score: [1.]
# Model Score: [0.29416686] actual score: [0.]
# Model Score: [0.01170978] actual score: [0.]
# Model Score: [0.5922567] actual score: [1.]
# Model Score: [0.03140414] actual score: [0.]
# Model Score: [0.6787885] actual score: [1.]
# Model Score: [0.23514181] actual score: [1.]
# Model Score: [0.9902362] actual score: [1.]
# Model Score: [0.9961377] actual score: [1.]
# Model Score: [0.988967] actual score: [1.]
# Model Score: [0.00205433] actual score: [0.]
# Model Score: [0.9029977] actual score: [1.]
# Model Score: [0.01445748] actual score: [0.]
# Model Score: [0.7750079] actual score: [1.]
# Model Score: [0.8349387] actual score: [1.]
# Model Score: [0.9615063] actual score: [1.]
# Model Score: [0.20341069] actual score: [0.]
# Model Score: [0.19860929] actual score: [0.]
# Model Score: [0.01959625] actual score: [0.]
# Model Score: [0.62318873] actual score: [1.]
# Model Score: [0.95219254] actual score: [1.]
# Model Score: [0.54402614] actual score: [0.]
# Model Score: [0.63640434] actual score: [1.]
# Model Score: [0.16801523] actual score: [0.]
# Model Score: [0.94841915] actual score: [1.]
# Model Score: [0.42546442] actual score: [0.]
# Model Score: [0.5306096] actual score: [0.]
# Model Score: [0.8050441] actual score: [1.]
# Model Score: [0.6195269] actual score: [1.]
# Model Score: [0.52727926] actual score: [0.]
# Model Score: [0.8362457] actual score: [0.]
# Model Score: [0.31944066] actual score: [0.]
# Model Score: [0.83026904] actual score: [1.]
# Model Score: [0.65286016] actual score: [1.]
# Model Score: [0.10025521] actual score: [0.]
# Model Score: [0.00424602] actual score: [0.]
# Model Score: [0.35251448] actual score: [0.]
# Model Score: [0.5348584] actual score: [1.]
# Model Score: [0.9895587] actual score: [1.]
# Model Score: [0.00134876] actual score: [0.]
# Model Score: [0.90204114] actual score: [1.]
# Model Score: [0.9845638] actual score: [1.]
# Model Score: [0.933521] actual score: [1.]
# Model Score: [0.27434495] actual score: [0.]
# Model Score: [0.95487124] actual score: [1.]
# Model Score: [0.33924672] actual score: [1.]
# Model Score: [0.8136202] actual score: [1.]
# Model Score: [0.0024268] actual score: [0.]
# Model Score: [0.3219577] actual score: [0.]
# Model Score: [0.97811604] actual score: [1.]
# Model Score: [0.19251259] actual score: [0.]
# Model Score: [0.5727158] actual score: [1.]
# Model Score: [0.48708382] actual score: [1.]
# Model Score: [0.8950521] actual score: [1.]
# Model Score: [0.970705] actual score: [1.]
# Model Score: [0.7049275] actual score: [1.]
# Model Score: [0.14381617] actual score: [0.]
# Model Score: [0.6760561] actual score: [1.]
# Model Score: [0.44043657] actual score: [0.]
# Model Score: [0.0119136] actual score: [0.]
# Model Score: [0.0007099] actual score: [0.]
# Model Score: [0.95162773] actual score: [1.]
# Model Score: [0.9886983] actual score: [1.]
# Model Score: [0.44080874] actual score: [0.]
# Model Score: [0.72789735] actual score: [1.]
# Model Score: [0.20873123] actual score: [0.]
# Model Score: [0.9898801] actual score: [1.]
# Model Score: [0.04241907] actual score: [0.]
# Model Score: [0.03310212] actual score: [0.]
# Model Score: [0.9896187] actual score: [1.]
# Model Score: [0.9484425] actual score: [1.]
# Model Score: [0.5125553] actual score: [0.]
# Model Score: [0.35314038] actual score: [0.]
# Model Score: [0.21555142] actual score: [1.]
# Model Score: [0.3841625] actual score: [0.]
# Model Score: [0.9893824] actual score: [1.]
# Model Score: [0.72173107] actual score: [1.]
# Model Score: [0.00109303] actual score: [0.]
# Model Score: [0.58904153] actual score: [1.]
# Model Score: [0.9839221] actual score: [0.]
# Model Score: [0.9826925] actual score: [1.]
# Model Score: [0.00238094] actual score: [0.]
# Model Score: [0.7848541] actual score: [0.]
# Model Score: [0.8761017] actual score: [0.]
# Model Score: [0.9646265] actual score: [1.]
# Model Score: [0.2903785] actual score: [0.]
# Model Score: [0.9451973] actual score: [1.]
# Model Score: [0.39513087] actual score: [0.]
# Model Score: [0.9933215] actual score: [1.]
# Model Score: [0.89566505] actual score: [1.]
# Model Score: [0.30000383] actual score: [1.]
# Model Score: [0.9255943] actual score: [0.]
# Model Score: [0.02999188] actual score: [0.]
# Model Score: [0.993103] actual score: [1.]
# Model Score: [0.04146424] actual score: [0.]
# Model Score: [0.99585587] actual score: [1.]
# Model Score: [0.9622296] actual score: [1.]
# Model Score: [0.9860778] actual score: [1.]
# Model Score: [0.27826267] actual score: [0.]
# Model Score: [0.6963552] actual score: [1.]
# Model Score: [0.9114665] actual score: [1.]
# Model Score: [0.49232423] actual score: [1.]
# Model Score: [0.8916696] actual score: [1.]
# Model Score: [0.9148807] actual score: [1.]
# Model Score: [0.89116466] actual score: [1.]
# Model Score: [0.822065] actual score: [1.]
# Model Score: [0.9057932] actual score: [1.]
# Model Score: [0.3417085] actual score: [1.]
# Model Score: [0.99015474] actual score: [1.]
# Model Score: [0.76320547] actual score: [1.]
# Model Score: [0.57030755] actual score: [0.]
# Model Score: [0.0969962] actual score: [0.]
# Model Score: [0.9208361] actual score: [1.]
# Model Score: [0.38482854] actual score: [1.]
# Model Score: [0.24980216] actual score: [0.]
# Model Score: [0.01770978] actual score: [0.]
# Model Score: [0.7015042] actual score: [1.]
# Model Score: [0.31523985] actual score: [0.]
# Model Score: [0.9168942] actual score: [1.]
# Model Score: [0.11448761] actual score: [0.]
# Model Score: [0.1195844] actual score: [1.]
# Model Score: [0.61991096] actual score: [0.]
# Model Score: [0.11863075] actual score: [0.]
# Model Score: [0.02104234] actual score: [0.]
# Model Score: [0.41736454] actual score: [0.]
# Model Score: [0.829864] actual score: [1.]
# Model Score: [0.30618373] actual score: [0.]
# Model Score: [0.73254484] actual score: [1.]
# Model Score: [0.39170483] actual score: [0.]
# Model Score: [0.7195093] actual score: [1.]
# Model Score: [0.20625241] actual score: [0.]
# Model Score: [0.33551994] actual score: [1.]
# Model Score: [0.9900838] actual score: [1.]
# Model Score: [0.92170197] actual score: [1.]
# Model Score: [0.09665128] actual score: [0.]
# Model Score: [0.94461244] actual score: [1.]
# Model Score: [0.9695911] actual score: [1.]
# Model Score: [0.9889747] actual score: [1.]
# Model Score: [0.98990774] actual score: [1.]
# Model Score: [0.14933752] actual score: [0.]
# Model Score: [0.04374797] actual score: [0.]
# Model Score: [0.0831142] actual score: [0.]
# Model Score: [0.9968342] actual score: [1.]
# Model Score: [0.9867225] actual score: [1.]
# Model Score: [0.96175504] actual score: [1.]
# Model Score: [0.9876117] actual score: [1.]
# Model Score: [0.2976405] actual score: [0.]
# Model Score: [0.83941305] actual score: [1.]
# Model Score: [0.8075399] actual score: [1.]
# Model Score: [0.00136371] actual score: [0.]
# Model Score: [0.5326163] actual score: [0.]
# Model Score: [0.00802406] actual score: [0.]
# Model Score: [0.4643448] actual score: [0.]
# Model Score: [0.5953454] actual score: [0.]
# Model Score: [0.00324994] actual score: [0.]
# Model Score: [0.6559442] actual score: [1.]
# Model Score: [0.9385868] actual score: [1.]
# Model Score: [0.97542113] actual score: [1.]
# Model Score: [0.7941834] actual score: [1.]
# Model Score: [0.91356504] actual score: [1.]
# Model Score: [0.3829307] actual score: [0.]
# Model Score: [0.2918286] actual score: [0.]
# Model Score: [0.32631502] actual score: [0.]
# Model Score: [0.9955113] actual score: [1.]
# Model Score: [0.64311075] actual score: [1.]
# Model Score: [0.99150157] actual score: [1.]
# Model Score: [0.99673563] actual score: [1.]
# Model Score: [0.640917] actual score: [0.]
# Model Score: [0.6530725] actual score: [1.]
# Model Score: [0.11689602] actual score: [0.]
# Model Score: [0.19955894] actual score: [0.]
# Model Score: [0.61576414] actual score: [0.]
# Model Score: [0.04500584] actual score: [0.]
# Model Score: [0.6300675] actual score: [0.]
# Model Score: [0.95165193] actual score: [1.]
# Model Score: [0.62663937] actual score: [1.]
# Model Score: [0.03742008] actual score: [0.]
# Model Score: [0.83249] actual score: [1.]
# Model Score: [0.47393313] actual score: [0.]
# Model Score: [0.89741784] actual score: [1.]
# Model Score: [0.09850982] actual score: [0.]
# Model Score: [0.00402453] actual score: [0.]
# Model Score: [0.03099726] actual score: [0.]
# Model Score: [0.7825016] actual score: [1.]
# Model Score: [0.9674292] actual score: [1.]
# Model Score: [0.670286] actual score: [1.]
# Model Score: [0.7438706] actual score: [1.]
# Model Score: [0.692738] actual score: [0.]
# Model Score: [0.19588633] actual score: [1.]
# Model Score: [0.7539018] actual score: [1.]
# Model Score: [0.56372786] actual score: [0.]
# Model Score: [0.00505516] actual score: [0.]
# Model Score: [0.00198249] actual score: [0.]
# Model Score: [0.2907512] actual score: [0.]
# Model Score: [0.2535629] actual score: [0.]
# Model Score: [0.994839] actual score: [1.]
# Model Score: [0.06723966] actual score: [0.]
# Model Score: [0.22812252] actual score: [0.]
# Model Score: [0.8749195] actual score: [1.]
# Model Score: [0.17578167] actual score: [0.]
# Model Score: [0.8986618] actual score: [1.]
# Model Score: [0.00530318] actual score: [0.]
# Model Score: [0.99756706] actual score: [1.]
# Model Score: [0.5761072] actual score: [0.]
# Model Score: [0.08184474] actual score: [0.]
# Model Score: [0.00413415] actual score: [0.]
# Model Score: [0.01819327] actual score: [0.]
# Model Score: [0.90465415] actual score: [1.]
# Model Score: [0.91566056] actual score: [1.]
# Model Score: [0.25666106] actual score: [0.]
# Model Score: [0.27085233] actual score: [0.]
# Model Score: [0.99069035] actual score: [1.]
# Model Score: [0.95805126] actual score: [1.]
# Model Score: [0.94803995] actual score: [0.]
# Model Score: [0.19205426] actual score: [0.]
# Model Score: [0.33098176] actual score: [1.]
# Model Score: [0.03117371] actual score: [0.]
# Model Score: [8.195433e-05] actual score: [0.]
# Model Score: [0.003452] actual score: [0.]
# Model Score: [0.9390251] actual score: [1.]
# Model Score: [0.9714046] actual score: [1.]
# Model Score: [0.9559071] actual score: [1.]
# Model Score: [0.9342873] actual score: [1.]
# Model Score: [0.8781579] actual score: [1.]
# Model Score: [0.84876966] actual score: [1.]
# Model Score: [0.9053767] actual score: [1.]
# Model Score: [0.00074595] actual score: [0.]
# Model Score: [0.25006676] actual score: [0.]
# Model Score: [0.96862644] actual score: [1.]
# Model Score: [0.0167579] actual score: [0.]
# Model Score: [0.8155817] actual score: [1.]
# Model Score: [0.9962082] actual score: [1.]
# Model Score: [0.4833197] actual score: [0.]
# Model Score: [0.97465] actual score: [1.]
# Model Score: [0.77315074] actual score: [1.]
# Model Score: [0.66897] actual score: [1.]
# Model Score: [0.44557244] actual score: [0.]
# Model Score: [0.9811834] actual score: [1.]
# Model Score: [0.9188047] actual score: [1.]
# Model Score: [0.02532973] actual score: [0.]
# Model Score: [0.4449715] actual score: [1.]
# Model Score: [0.9034841] actual score: [1.]
# Model Score: [0.36351255] actual score: [0.]
# Model Score: [0.65461385] actual score: [1.]
# Model Score: [0.9834651] actual score: [1.]
# Model Score: [0.9728548] actual score: [1.]
# Model Score: [0.19166481] actual score: [1.]
# Model Score: [0.78778553] actual score: [1.]
# Model Score: [0.47534645] actual score: [1.]
# Model Score: [0.9767467] actual score: [1.]
# Model Score: [0.18075472] actual score: [1.]
# Model Score: [0.9891284] actual score: [1.]
# Model Score: [0.98719275] actual score: [1.]
# Model Score: [0.27178025] actual score: [1.]
# Model Score: [0.9583585] actual score: [1.]
# Model Score: [0.97092056] actual score: [1.]
# Model Score: [0.90926737] actual score: [1.]
# Model Score: [0.05609248] actual score: [0.]
# Model Score: [0.05354311] actual score: [0.]
# Model Score: [1.7831835e-05] actual score: [0.]
# Model Score: [0.00230847] actual score: [0.]
# Model Score: [0.09029581] actual score: [0.]
# Model Score: [0.08852219] actual score: [0.]
# Model Score: [0.94660604] actual score: [1.]
# Model Score: [0.988154] actual score: [1.]
# Model Score: [0.5994228] actual score: [0.]
# Model Score: [0.71669704] actual score: [1.]
# Model Score: [0.02485618] actual score: [0.]
# Model Score: [0.02080208] actual score: [0.]
# Model Score: [0.93076265] actual score: [1.]
# Model Score: [0.7400008] actual score: [1.]
# Model Score: [0.00225009] actual score: [0.]
# Model Score: [0.86148643] actual score: [0.]
# Model Score: [0.8943181] actual score: [1.]
# Model Score: [0.83413863] actual score: [0.]
# Model Score: [0.5627849] actual score: [0.]
# Model Score: [0.9159511] actual score: [1.]
# Model Score: [0.3749575] actual score: [1.]
# Model Score: [0.14036377] actual score: [0.]
# Model Score: [0.02274558] actual score: [0.]
# Model Score: [0.59445375] actual score: [0.]
# Model Score: [3.9082024e-05] actual score: [0.]
# Model Score: [0.970753] actual score: [1.]
# Model Score: [0.33329955] actual score: [0.]
# Model Score: [0.98778766] actual score: [1.]
# Model Score: [0.29517356] actual score: [0.]
# Model Score: [0.94160235] actual score: [1.]
# Model Score: [0.95179313] actual score: [1.]
# Model Score: [0.97850716] actual score: [1.]
# Model Score: [0.068002] actual score: [0.]
# Model Score: [0.4599887] actual score: [0.]
# Model Score: [0.84614724] actual score: [1.]
# Model Score: [0.8585654] actual score: [0.]
# Model Score: [0.9893293] actual score: [1.]
# Model Score: [0.7038343] actual score: [0.]
# Model Score: [0.7901352] actual score: [0.]
# Model Score: [0.02971141] actual score: [0.]
# Model Score: [0.62125504] actual score: [0.]
# Model Score: [0.9371071] actual score: [1.]
# Model Score: [0.9987846] actual score: [1.]
# Model Score: [0.5162447] actual score: [1.]
# Model Score: [0.3813951] actual score: [0.]
# Model Score: [0.5788645] actual score: [1.]
# Model Score: [0.9047276] actual score: [1.]
# Model Score: [0.5483714] actual score: [1.]
# Model Score: [0.14770593] actual score: [0.]
# Model Score: [0.02325127] actual score: [0.]
# Model Score: [0.50302565] actual score: [0.]
# Model Score: [0.9501288] actual score: [1.]
# Model Score: [0.9987821] actual score: [1.]
# Model Score: [0.9872184] actual score: [1.]
# Model Score: [0.00279279] actual score: [0.]
# Model Score: [0.02195202] actual score: [0.]
# Model Score: [0.94640315] actual score: [1.]
# Model Score: [0.33956116] actual score: [0.]
# Model Score: [0.94597965] actual score: [1.]
# Model Score: [0.9445029] actual score: [0.]
# Model Score: [0.9745889] actual score: [1.]
# Model Score: [0.21749873] actual score: [0.]
# Model Score: [0.7804435] actual score: [1.]
# Model Score: [0.9894219] actual score: [1.]
# Model Score: [0.47124988] actual score: [1.]
# Model Score: [0.8921634] actual score: [0.]
# Model Score: [0.06640369] actual score: [0.]
# Model Score: [0.7138713] actual score: [1.]
# Model Score: [0.02221865] actual score: [0.]
# Model Score: [0.9999027] actual score: [1.]
# Model Score: [0.32278582] actual score: [1.]
# Model Score: [0.16315888] actual score: [0.]
# Model Score: [0.01963221] actual score: [0.]
# Model Score: [0.08364332] actual score: [0.]
# Model Score: [4.8903185e-05] actual score: [0.]
# Model Score: [0.01425193] actual score: [0.]
# Model Score: [0.981447] actual score: [1.]
# Model Score: [0.02462661] actual score: [0.]
# Model Score: [0.684478] actual score: [0.]
# Model Score: [0.9764016] actual score: [1.]
# Model Score: [0.86313426] actual score: [1.]
# Model Score: [0.1144173] actual score: [0.]
# Model Score: [0.6667942] actual score: [1.]
# Model Score: [0.98877174] actual score: [1.]
# Model Score: [0.02889435] actual score: [0.]
# Model Score: [0.08854894] actual score: [0.]
# Model Score: [0.05408452] actual score: [0.]
# Model Score: [0.9376648] actual score: [1.]
# Model Score: [0.48176467] actual score: [1.]
# Model Score: [0.9615799] actual score: [1.]
# Model Score: [0.8931214] actual score: [1.]
# Model Score: [0.4527319] actual score: [0.]
# Model Score: [0.08228667] actual score: [1.]
# Model Score: [0.84882885] actual score: [0.]
# Model Score: [0.02234457] actual score: [0.]
# Model Score: [0.9741167] actual score: [1.]
# Model Score: [0.9336323] actual score: [1.]
# Model Score: [0.99641234] actual score: [1.]
# Model Score: [0.99948007] actual score: [1.]
# Model Score: [0.01755638] actual score: [0.]
# Model Score: [0.94056904] actual score: [1.]
# Model Score: [0.05673314] actual score: [0.]
# Model Score: [0.8452781] actual score: [1.]
# Model Score: [0.9816777] actual score: [1.]
# Model Score: [0.9990595] actual score: [1.]
# Model Score: [0.9977436] actual score: [1.]
# Model Score: [0.32588133] actual score: [0.]
# Model Score: [0.24878764] actual score: [0.]
# Model Score: [0.17369132] actual score: [0.]
# Model Score: [0.2811538] actual score: [0.]
# Model Score: [0.99758434] actual score: [1.]
# Model Score: [0.9988175] actual score: [1.]
# Model Score: [0.9371732] actual score: [1.]
# Model Score: [0.13618103] actual score: [0.]
# Model Score: [0.5588681] actual score: [0.]
# Model Score: [0.9120255] actual score: [1.]
# Model Score: [0.99893254] actual score: [1.]
# Model Score: [0.9883265] actual score: [1.]
# Model Score: [0.07962665] actual score: [0.]
# Model Score: [0.06038222] actual score: [0.]
# Model Score: [0.7458212] actual score: [0.]
# Model Score: [0.00341136] actual score: [0.]
# Model Score: [0.88968766] actual score: [1.]
# Model Score: [0.18749414] actual score: [0.]
# Model Score: [0.4100693] actual score: [1.]
# Model Score: [0.53631586] actual score: [1.]
# Model Score: [0.00358] actual score: [0.]
# Model Score: [0.9869631] actual score: [1.]
# Model Score: [0.94969666] actual score: [1.]
# Model Score: [0.36847755] actual score: [0.]
# Model Score: [0.01473499] actual score: [0.]
# Model Score: [0.00067255] actual score: [0.]
# Model Score: [0.1321473] actual score: [0.]
# Model Score: [0.09221672] actual score: [0.]
# Model Score: [0.13942896] actual score: [0.]
# Model Score: [0.9157146] actual score: [1.]
# Model Score: [0.17964047] actual score: [0.]
# Model Score: [0.76328343] actual score: [1.]
# Model Score: [0.5240587] actual score: [1.]
# Model Score: [0.35047835] actual score: [0.]
# Model Score: [0.76276183] actual score: [1.]
# Model Score: [0.00385491] actual score: [0.]
# Model Score: [0.09684442] actual score: [0.]
# Model Score: [0.3114209] actual score: [0.]
# Model Score: [0.97892696] actual score: [1.]
# Model Score: [0.05231962] actual score: [0.]
# Model Score: [0.99670535] actual score: [1.]
# Model Score: [4.059109e-05] actual score: [0.]
# Model Score: [0.9236041] actual score: [1.]
# Model Score: [0.24654399] actual score: [0.]
# Model Score: [0.0249802] actual score: [0.]
# Model Score: [0.46742588] actual score: [0.]
# Model Score: [0.04396497] actual score: [0.]
# Model Score: [0.9158202] actual score: [1.]
# Model Score: [0.3456222] actual score: [0.]
# Model Score: [0.8824724] actual score: [1.]
# Model Score: [0.6676979] actual score: [1.]
# Model Score: [0.99880695] actual score: [1.]
# Model Score: [0.00677982] actual score: [0.]
# Model Score: [0.991732] actual score: [1.]
# Model Score: [0.42645732] actual score: [0.]
# Model Score: [0.00689699] actual score: [0.]
# Model Score: [0.9849701] actual score: [1.]
# Model Score: [0.04001525] actual score: [0.]
# Model Score: [0.353883] actual score: [1.]
# Model Score: [0.97819316] actual score: [1.]
# Model Score: [0.87355447] actual score: [1.]
# Model Score: [0.2719766] actual score: [0.]
# Model Score: [0.19958952] actual score: [0.]
# Model Score: [0.95051384] actual score: [1.]
# Model Score: [0.6884274] actual score: [1.]
# Model Score: [0.880584] actual score: [1.]
# Model Score: [0.9924234] actual score: [1.]
# Model Score: [0.95823383] actual score: [1.]
# Model Score: [0.0073434] actual score: [0.]
# Model Score: [0.06032874] actual score: [0.]
# Model Score: [0.9867486] actual score: [1.]
# Model Score: [3.3701468e-05] actual score: [0.]
# Model Score: [0.9541937] actual score: [1.]
# Model Score: [0.22315763] actual score: [0.]
# Model Score: [0.91204107] actual score: [0.]
# Model Score: [0.37354755] actual score: [1.]
# Model Score: [0.26485446] actual score: [0.]
# Model Score: [0.95324194] actual score: [1.]
# Model Score: [0.33184388] actual score: [0.]
# Model Score: [0.02194683] actual score: [0.]
# Model Score: [0.7663763] actual score: [1.]
# Model Score: [0.9953074] actual score: [1.]
# Model Score: [0.19748238] actual score: [0.]
# Model Score: [0.89252484] actual score: [1.]
# Model Score: [0.57663447] actual score: [0.]
# Model Score: [0.00252159] actual score: [0.]
# Model Score: [0.90839726] actual score: [1.]
# Model Score: [0.1089265] actual score: [0.]
# Model Score: [0.7827423] actual score: [1.]
# Model Score: [0.00065199] actual score: [0.]
# Model Score: [0.8032394] actual score: [0.]
# Model Score: [0.19518526] actual score: [0.]
# Model Score: [0.00433747] actual score: [0.]
# Model Score: [0.905063] actual score: [1.]
# Model Score: [0.8935399] actual score: [1.]
# Model Score: [0.24773955] actual score: [0.]
# Model Score: [0.29845896] actual score: [0.]
# Model Score: [0.8190055] actual score: [1.]
# Model Score: [0.02131] actual score: [0.]
# Model Score: [0.89945346] actual score: [1.]
# Model Score: [0.8696928] actual score: [1.]
# Model Score: [0.1344106] actual score: [0.]
# Model Score: [0.45405835] actual score: [0.]
# Model Score: [0.98778045] actual score: [1.]
# Model Score: [0.7963118] actual score: [1.]
# Model Score: [0.44076234] actual score: [0.]
# Model Score: [0.27716634] actual score: [0.]
# Model Score: [0.01414046] actual score: [0.]
# Model Score: [0.75577074] actual score: [1.]
# Model Score: [0.11455725] actual score: [1.]
# Model Score: [0.888475] actual score: [1.]
# Model Score: [0.9671806] actual score: [1.]
# Model Score: [0.64752215] actual score: [0.]
# Model Score: [0.23998515] actual score: [0.]
# Model Score: [0.93233055] actual score: [1.]
# Model Score: [0.00044549] actual score: [0.]
# Model Score: [0.98322785] actual score: [1.]
# Model Score: [0.95144975] actual score: [1.]
# Model Score: [0.9997614] actual score: [1.]
# Model Score: [0.20821807] actual score: [0.]
# Model Score: [0.94885707] actual score: [1.]
# Model Score: [0.06578912] actual score: [0.]
# Model Score: [0.9988726] actual score: [1.]
# Model Score: [0.14861006] actual score: [0.]
# Model Score: [0.99718636] actual score: [1.]
# Model Score: [0.6349027] actual score: [0.]
# Model Score: [0.00028929] actual score: [0.]
# Model Score: [0.99122673] actual score: [1.]
# Model Score: [0.95316195] actual score: [1.]
# Model Score: [0.65145063] actual score: [1.]
# Model Score: [0.02368712] actual score: [0.]
# Model Score: [0.6319647] actual score: [1.]
# Model Score: [0.01891564] actual score: [0.]
# Model Score: [0.990227] actual score: [1.]
# Model Score: [0.995745] actual score: [1.]
# Model Score: [0.2534247] actual score: [1.]
# Model Score: [0.56245565] actual score: [0.]
# Model Score: [0.14858761] actual score: [0.]
# Model Score: [0.924867] actual score: [1.]
# Model Score: [0.03127692] actual score: [0.]
# Model Score: [0.9938006] actual score: [1.]
# Model Score: [0.8916742] actual score: [1.]
# Model Score: [0.42850363] actual score: [0.]
# Model Score: [0.62411076] actual score: [1.]
# Model Score: [0.7300607] actual score: [1.]
# Model Score: [0.9988996] actual score: [1.]
# Model Score: [0.4847136] actual score: [1.]
# Model Score: [0.00811168] actual score: [0.]
# Model Score: [0.99119496] actual score: [0.]
# Model Score: [0.7290168] actual score: [0.]
# Model Score: [0.8002932] actual score: [1.]
# Model Score: [0.00481327] actual score: [0.]
# Model Score: [0.02773568] actual score: [0.]
# Model Score: [0.8816357] actual score: [1.]
# Model Score: [0.54155254] actual score: [0.]
# Model Score: [0.14159982] actual score: [0.]
# Model Score: [0.52410346] actual score: [0.]
# Model Score: [0.9736733] actual score: [1.]
# Model Score: [0.42223155] actual score: [1.]
# Model Score: [0.601309] actual score: [1.]
# Model Score: [0.71856654] actual score: [1.]
# Model Score: [0.8234716] actual score: [0.]
# Model Score: [0.74833286] actual score: [1.]
# Model Score: [0.07092807] actual score: [0.]
# Model Score: [0.02297811] actual score: [0.]
# Model Score: [0.78124213] actual score: [1.]
# Model Score: [0.5331211] actual score: [1.]
# Model Score: [0.24709609] actual score: [1.]
# Model Score: [0.45693552] actual score: [0.]
# Model Score: [0.612364] actual score: [0.]
# Model Score: [0.00422888] actual score: [0.]
# Model Score: [0.00848348] actual score: [0.]
# Model Score: [0.02476426] actual score: [0.]
# Model Score: [0.5503711] actual score: [1.]
# Model Score: [0.77391964] actual score: [1.]
# Model Score: [0.08249634] actual score: [0.]
# Model Score: [0.9898331] actual score: [1.]
# Model Score: [0.19944419] actual score: [0.]
# Model Score: [0.10794754] actual score: [0.]
# Model Score: [0.10239647] actual score: [0.]
# Model Score: [0.95133567] actual score: [1.]
# Model Score: [0.992151] actual score: [1.]
# Model Score: [0.90615654] actual score: [1.]
# Model Score: [0.96764517] actual score: [1.]
# Model Score: [0.3079728] actual score: [0.]
# Model Score: [0.90833724] actual score: [1.]
# Model Score: [0.22699936] actual score: [0.]
# Model Score: [0.00310195] actual score: [0.]
# Model Score: [0.23254162] actual score: [0.]
# Model Score: [0.11286951] actual score: [1.]
# Model Score: [0.84241116] actual score: [0.]
# Model Score: [0.00026484] actual score: [0.]
# Model Score: [0.8882435] actual score: [1.]
# Model Score: [0.97608376] actual score: [1.]
# Model Score: [0.9821578] actual score: [1.]
# Model Score: [0.11836582] actual score: [0.]
# Model Score: [0.02419427] actual score: [0.]
# Model Score: [0.41695017] actual score: [0.]
# Model Score: [0.88376296] actual score: [1.]
# Model Score: [0.79167515] actual score: [1.]
# Model Score: [0.5907736] actual score: [1.]
# Model Score: [0.4338565] actual score: [0.]
# Model Score: [0.8477433] actual score: [1.]
# Model Score: [0.4829679] actual score: [0.]
# Model Score: [0.5464831] actual score: [1.]
# Model Score: [0.00916699] actual score: [0.]
# Model Score: [0.00054989] actual score: [0.]
# Model Score: [0.04531729] actual score: [0.]
# Model Score: [0.97967726] actual score: [1.]
# Model Score: [0.9880701] actual score: [1.]
# Model Score: [0.05835409] actual score: [0.]
# Model Score: [0.02772862] actual score: [0.]
# Model Score: [0.09329598] actual score: [0.]
# Model Score: [0.04014931] actual score: [0.]
# Model Score: [0.9950132] actual score: [1.]
# Model Score: [0.32871515] actual score: [0.]
# Model Score: [0.68534243] actual score: [0.]
# Model Score: [0.03232569] actual score: [0.]
# Model Score: [0.91360193] actual score: [1.]
# Model Score: [0.4353657] actual score: [0.]
# Model Score: [0.03717615] actual score: [0.]
# Model Score: [0.2299227] actual score: [0.]
# Model Score: [0.07217524] actual score: [1.]
# Model Score: [0.59249485] actual score: [0.]
# Model Score: [0.2778227] actual score: [0.]
# Model Score: [0.8104314] actual score: [1.]
# Model Score: [0.6033943] actual score: [1.]
# Model Score: [0.30771] actual score: [1.]
# Model Score: [0.40526932] actual score: [0.]
# Model Score: [0.86038816] actual score: [1.]
# Model Score: [3.580181e-05] actual score: [0.]
# Model Score: [0.08792543] actual score: [0.]
# Model Score: [0.9853158] actual score: [1.]
# Model Score: [0.94147617] actual score: [1.]
# Model Score: [0.65576583] actual score: [0.]
# Model Score: [0.9396049] actual score: [1.]
# Model Score: [0.20681912] actual score: [0.]
# Model Score: [0.30615744] actual score: [0.]
# Model Score: [0.22801322] actual score: [0.]
# Model Score: [0.98059547] actual score: [1.]
# Model Score: [0.72529024] actual score: [0.]
# Model Score: [0.7059073] actual score: [0.]
# Model Score: [0.98718566] actual score: [1.]
# Model Score: [0.9111347] actual score: [1.]
# Model Score: [0.9886657] actual score: [1.]
# Model Score: [0.16837989] actual score: [0.]
# Model Score: [0.68363714] actual score: [0.]
# Model Score: [0.48998627] actual score: [0.]
# Model Score: [1.791956e-05] actual score: [0.]
# Model Score: [0.02545026] actual score: [0.]
# Model Score: [0.22033867] actual score: [0.]
# Model Score: [0.05315169] actual score: [0.]
# Model Score: [0.04378767] actual score: [0.]
# Model Score: [0.01344636] actual score: [1.]
# Model Score: [0.5970506] actual score: [1.]
# Model Score: [0.6768027] actual score: [0.]
# Model Score: [0.9898413] actual score: [1.]
# Model Score: [0.00425945] actual score: [1.]
# Model Score: [0.999987] actual score: [1.]
# Model Score: [0.999941] actual score: [1.]
# Model Score: [0.0612462] actual score: [0.]
# Model Score: [0.92976224] actual score: [1.]
# Model Score: [0.86311626] actual score: [1.]
# Model Score: [0.98754674] actual score: [1.]
# Model Score: [0.08478639] actual score: [0.]
# Model Score: [0.99343723] actual score: [1.]
# Model Score: [0.83491665] actual score: [0.]
# Model Score: [4.6104524e-06] actual score: [0.]
# Model Score: [0.28797376] actual score: [0.]
# Model Score: [0.898968] actual score: [0.]
# Model Score: [0.8950013] actual score: [0.]
# Model Score: [0.4156368] actual score: [1.]
# Model Score: [0.41230866] actual score: [0.]
# Model Score: [0.00355762] actual score: [0.]
# Model Score: [0.8470229] actual score: [1.]
# Model Score: [0.8752705] actual score: [1.]
# Model Score: [0.09408782] actual score: [0.]
# Model Score: [0.5472851] actual score: [0.]
# Model Score: [0.96919715] actual score: [1.]
# Model Score: [0.9720248] actual score: [1.]
# Model Score: [0.9661175] actual score: [1.]
# Model Score: [0.9998288] actual score: [1.]
# Model Score: [0.8282535] actual score: [0.]
# Model Score: [0.8907326] actual score: [0.]
# Model Score: [0.7062496] actual score: [0.]
# Model Score: [0.879353] actual score: [1.]
# Model Score: [0.81763875] actual score: [0.]
# Model Score: [0.00984048] actual score: [0.]
# Model Score: [0.00250588] actual score: [0.]
# Model Score: [0.90404993] actual score: [1.]
# Model Score: [0.5015008] actual score: [0.]
# Model Score: [0.8239703] actual score: [1.]
# Model Score: [0.85021937] actual score: [1.]
# Model Score: [0.9092272] actual score: [1.]
# Model Score: [0.75543284] actual score: [1.]
# Model Score: [0.06289017] actual score: [0.]
# Model Score: [0.9843254] actual score: [1.]
# Model Score: [0.999706] actual score: [1.]
# Model Score: [0.00348873] actual score: [0.]
# Model Score: [0.3623173] actual score: [0.]
# Model Score: [0.9467588] actual score: [1.]
# Model Score: [0.8469956] actual score: [1.]
# Model Score: [0.99775946] actual score: [1.]
# Model Score: [0.94774985] actual score: [1.]
# Model Score: [0.14227805] actual score: [0.]
# Model Score: [0.01332875] actual score: [0.]
# Model Score: [0.93098617] actual score: [1.]
# Model Score: [0.41719437] actual score: [0.]
# Model Score: [0.422454] actual score: [0.]
# Model Score: [0.94082046] actual score: [1.]
# Model Score: [0.02440671] actual score: [0.]
# Model Score: [0.29145002] actual score: [0.]
# Model Score: [0.99521] actual score: [1.]
# Model Score: [0.02791418] actual score: [0.]
# Model Score: [0.1964178] actual score: [0.]
# Model Score: [0.8503542] actual score: [1.]
# Model Score: [0.9879318] actual score: [1.]
# Model Score: [0.918833] actual score: [1.]
# Model Score: [0.5023924] actual score: [0.]
# Model Score: [0.98503983] actual score: [1.]
# Model Score: [0.9869381] actual score: [1.]
# Model Score: [0.2017856] actual score: [0.]
# Model Score: [0.9365617] actual score: [1.]
# Model Score: [0.00838458] actual score: [0.]
# Model Score: [5.863681e-05] actual score: [0.]
# Model Score: [0.27048218] actual score: [0.]
# Model Score: [0.9249722] actual score: [1.]
# Model Score: [0.81927866] actual score: [0.]
# Model Score: [0.98334724] actual score: [1.]
# Model Score: [0.25230852] actual score: [0.]
# Model Score: [0.958694] actual score: [1.]
# Model Score: [0.989705] actual score: [1.]
# Model Score: [0.98968494] actual score: [1.]
# Model Score: [0.9890521] actual score: [1.]
# Model Score: [0.47655737] actual score: [1.]
# Model Score: [0.10991487] actual score: [0.]
# Model Score: [0.47522092] actual score: [1.]
# Model Score: [0.2268824] actual score: [0.]
# Model Score: [0.9465941] actual score: [1.]
# Model Score: [0.9870827] actual score: [1.]
# Model Score: [0.9923253] actual score: [1.]
# Model Score: [0.26530293] actual score: [0.]
# Model Score: [0.38532704] actual score: [0.]
# Model Score: [0.75566155] actual score: [1.]
# Model Score: [0.06928383] actual score: [0.]
# ...
# Model Score: [0.45473424] actual score: [0.]
# Model Score: [0.10330087] actual score: [0.]
# Model Score: [0.557327] actual score: [1.]
# Model Score: [0.9171239] actual score: [1.]
# Model Score: [0.46356392] actual score: [1.]
# Model Score: [0.8788333] actual score: [1.]
# Model Score: [0.14749026] actual score: [0.]
# Model Score: [0.99357444] actual score: [1.]
# Model Score: [0.38327438] actual score: [0.]
# Model Score: [0.57916147] actual score: [1.]
# Model Score: [0.8761982] actual score: [1.]
# Model Score: [0.04268705] actual score: [0.]
# Model Score: [0.98626816] actual score: [1.]
# Model Score: [0.01159811] actual score: [0.]
# Model Score: [0.64078397] actual score: [1.]
# Model Score: [0.23608567] actual score: [0.]
# Model Score: [0.75983477] actual score: [1.]
# Model Score: [0.02055305] actual score: [0.]
# Model Score: [0.69899404] actual score: [0.]
# Model Score: [0.19143495] actual score: [1.]
# Model Score: [0.08407752] actual score: [0.]
# Model Score: [0.7991347] actual score: [1.]
# Model Score: [0.7999417] actual score: [0.]
# Model Score: [0.93432] actual score: [1.]
# Model Score: [0.65214103] actual score: [1.]
# Model Score: [0.67202336] actual score: [1.]
# Model Score: [0.70478106] actual score: [0.]
# Model Score: [0.441098] actual score: [0.]
# Model Score: [0.99324447] actual score: [1.]
# Model Score: [0.31744772] actual score: [0.]
# Model Score: [0.5554081] actual score: [0.]
# Model Score: [0.1775643] actual score: [0.]
# Model Score: [0.34695548] actual score: [1.]
# Model Score: [0.02325174] actual score: [0.]
# Model Score: [0.942522] actual score: [1.]
# Model Score: [0.01843175] actual score: [0.]
# Model Score: [0.00670877] actual score: [0.]
# Model Score: [0.00019561] actual score: [0.]
# Model Score: [0.99670285] actual score: [1.]
# Model Score: [0.25898722] actual score: [0.]
# Model Score: [0.09519264] actual score: [0.]
# Model Score: [0.9943897] actual score: [1.]
# Model Score: [0.07454814] actual score: [0.]
# Model Score: [0.8396971] actual score: [1.]
# Model Score: [0.93594974] actual score: [1.]
# Model Score: [0.95712894] actual score: [1.]
# Model Score: [0.1087954] actual score: [0.]
# Model Score: [0.59838915] actual score: [1.]
# Model Score: [0.97981286] actual score: [1.]
# Model Score: [0.87188166] actual score: [0.]
# Model Score: [0.03091682] actual score: [0.]
# Model Score: [0.9979698] actual score: [1.]
# Model Score: [0.26643333] actual score: [0.]
# Model Score: [0.00694951] actual score: [0.]
# Model Score: [0.98652214] actual score: [1.]
# Model Score: [0.18880674] actual score: [1.]
# Model Score: [0.02757082] actual score: [0.]
# Model Score: [0.9786654] actual score: [1.]
# Model Score: [0.07612704] actual score: [0.]
# Model Score: [0.01606484] actual score: [0.]
# Model Score: [0.81055987] actual score: [1.]
# Model Score: [0.8114066] actual score: [1.]
# Model Score: [0.36043373] actual score: [0.]
# Model Score: [0.50369906] actual score: [0.]
# Model Score: [0.5788995] actual score: [0.]
# Model Score: [0.8931278] actual score: [1.]
# Model Score: [0.2565326] actual score: [0.]
# Model Score: [0.9891935] actual score: [1.]
# Model Score: [0.09229385] actual score: [0.]
# Model Score: [0.22708774] actual score: [0.]
# Model Score: [0.99393314] actual score: [1.]
# Model Score: [0.99673045] actual score: [1.]
# Model Score: [0.9922098] actual score: [1.]
# Model Score: [0.24298145] actual score: [1.]
# Model Score: [0.9313927] actual score: [1.]
# Model Score: [0.0043289] actual score: [0.]
# Model Score: [0.29920885] actual score: [0.]
# Model Score: [0.03541268] actual score: [0.]
# Model Score: [0.19411398] actual score: [0.]
# Model Score: [0.99806017] actual score: [1.]
# Model Score: [0.2316095] actual score: [0.]
# Model Score: [0.4286667] actual score: [0.]
# Model Score: [0.89218765] actual score: [0.]
# Model Score: [0.96616304] actual score: [1.]
# Model Score: [0.987645] actual score: [1.]
# Model Score: [0.9859043] actual score: [1.]
# Model Score: [0.6130336] actual score: [0.]
# Model Score: [0.16581863] actual score: [0.]
# Model Score: [0.9937959] actual score: [1.]
# Model Score: [0.4109087] actual score: [1.]
# Model Score: [0.00286829] actual score: [0.]
# Model Score: [0.00295298] actual score: [0.]
# Model Score: [0.9678142] actual score: [1.]
# Model Score: [0.1701979] actual score: [0.]
# Model Score: [0.9595298] actual score: [1.]
# Model Score: [0.00598277] actual score: [0.]
# Model Score: [0.86343807] actual score: [1.]
# Model Score: [0.9434632] actual score: [1.]
# Model Score: [0.9979401] actual score: [1.]
# Model Score: [0.91885746] actual score: [1.]
# Model Score: [0.9019351] actual score: [1.]
# Model Score: [0.54077196] actual score: [1.]
# Model Score: [0.99031633] actual score: [1.]
# Model Score: [0.6036648] actual score: [1.]
# Model Score: [0.88944376] actual score: [1.]
# Model Score: [8.778357e-05] actual score: [0.]
# Model Score: [0.08583038] actual score: [0.]
# Model Score: [1.8007458e-05] actual score: [0.]
# Model Score: [0.14104407] actual score: [0.]
# Model Score: [0.9734634] actual score: [1.]
# Model Score: [0.0328633] actual score: [0.]
# Model Score: [0.431926] actual score: [0.]
# Model Score: [0.2593797] actual score: [0.]
# Model Score: [0.512992] actual score: [1.]
# Model Score: [0.9974027] actual score: [1.]
# Model Score: [0.9929014] actual score: [1.]
# Model Score: [0.9486034] actual score: [1.]
# Model Score: [0.98378676] actual score: [1.]
# Model Score: [0.98053247] actual score: [1.]
# Model Score: [0.02276337] actual score: [0.]
# Model Score: [0.96134895] actual score: [1.]
# Model Score: [6.7469114e-07] actual score: [0.]
# Model Score: [0.81339455] actual score: [1.]
# Model Score: [0.99998796] actual score: [1.]
# Model Score: [0.98639214] actual score: [1.]
# Model Score: [0.5557294] actual score: [1.]
# Model Score: [1.9565625e-06] actual score: [0.]
# Model Score: [0.08036272] actual score: [0.]
# Model Score: [0.9906944] actual score: [1.]
# Model Score: [0.9959638] actual score: [1.]
# Model Score: [0.45786926] actual score: [0.]
# Model Score: [0.169232] actual score: [0.]
# Model Score: [0.46609107] actual score: [0.]
# Model Score: [0.2687605] actual score: [0.]
# Model Score: [0.97990406] actual score: [1.]
# Model Score: [0.9975223] actual score: [1.]
# Model Score: [0.66044974] actual score: [1.]
# Model Score: [0.9841039] actual score: [1.]
# Model Score: [0.00900948] actual score: [0.]
# Model Score: [1.1371414e-05] actual score: [0.]
# Model Score: [0.99342984] actual score: [1.]
# Model Score: [0.9801879] actual score: [1.]
# Model Score: [0.9392846] actual score: [1.]
# Model Score: [0.05214152] actual score: [0.]
# Model Score: [0.9890182] actual score: [1.]
# Model Score: [0.937351] actual score: [1.]
# Model Score: [0.393726] actual score: [1.]
# Model Score: [0.17225897] actual score: [0.]
# Model Score: [0.9942827] actual score: [1.]
# Model Score: [0.36096463] actual score: [0.]
# Model Score: [0.49432278] actual score: [1.]
# Model Score: [0.87572366] actual score: [1.]
# Model Score: [0.3496035] actual score: [1.]
# Model Score: [0.44617584] actual score: [0.]
# Model Score: [0.7870682] actual score: [1.]
# Model Score: [0.7820868] actual score: [0.]
# Model Score: [0.08437209] actual score: [0.]
# Model Score: [0.7588698] actual score: [1.]
# Model Score: [0.03788467] actual score: [0.]
# Model Score: [0.40187776] actual score: [0.]
# Model Score: [0.6079111] actual score: [1.]
# Model Score: [0.23696257] actual score: [0.]
# Model Score: [0.9015718] actual score: [1.]
# Model Score: [0.16177909] actual score: [0.]
# Model Score: [0.97924507] actual score: [1.]
# Model Score: [0.9296187] actual score: [1.]
# Model Score: [0.98717356] actual score: [1.]
# Model Score: [0.1331737] actual score: [0.]
# Model Score: [0.12251284] actual score: [0.]
# Model Score: [0.8272199] actual score: [1.]
# Model Score: [0.9949064] actual score: [1.]
# Model Score: [0.06078845] actual score: [0.]
# Model Score: [0.98973805] actual score: [1.]
# Model Score: [0.0971025] actual score: [0.]
# Model Score: [0.01192754] actual score: [0.]
# Model Score: [0.39496166] actual score: [1.]
# Model Score: [0.18363144] actual score: [0.]
# Model Score: [0.4474563] actual score: [0.]
# Model Score: [0.875142] actual score: [1.]
# Model Score: [0.62603045] actual score: [1.]
# Model Score: [0.97945076] actual score: [1.]
# Model Score: [0.9258149] actual score: [1.]
# Model Score: [0.45687497] actual score: [0.]
# Model Score: [0.578181] actual score: [1.]
# Model Score: [0.88957614] actual score: [1.]
# Model Score: [0.0145242] actual score: [0.]
# Model Score: [0.98171425] actual score: [1.]
# Model Score: [0.894188] actual score: [1.]
# Model Score: [0.9997526] actual score: [1.]
# Model Score: [0.01998368] actual score: [0.]
# Model Score: [0.10986912] actual score: [0.]
# Model Score: [0.6516202] actual score: [1.]
# Model Score: [0.90107524] actual score: [1.]
# Model Score: [0.99337053] actual score: [1.]
# Model Score: [0.98366493] actual score: [1.]
# Model Score: [0.5115826] actual score: [1.]
# Model Score: [0.7312707] actual score: [1.]
# Model Score: [0.98754895] actual score: [1.]
# Model Score: [0.17540705] actual score: [0.]
# Model Score: [0.14419678] actual score: [0.]
# Model Score: [0.20171408] actual score: [0.]
# Model Score: [0.00527336] actual score: [0.]
# Model Score: [0.9984669] actual score: [1.]
# Model Score: [0.371747] actual score: [1.]
# Model Score: [0.35653746] actual score: [1.]
# Model Score: [0.9706208] actual score: [1.]
# Model Score: [0.9792398] actual score: [1.]
# Model Score: [0.368006] actual score: [0.]
# Model Score: [0.05554343] actual score: [0.]
# Model Score: [0.9683141] actual score: [1.]
# Model Score: [0.05924952] actual score: [0.]
# Model Score: [0.53297895] actual score: [0.]
# Model Score: [0.77876747] actual score: [1.]
# Model Score: [0.49210277] actual score: [0.]
# Model Score: [0.98880833] actual score: [1.]
# Model Score: [0.01100767] actual score: [0.]
# Model Score: [0.9458128] actual score: [1.]
# Model Score: [0.9269939] actual score: [1.]
# Model Score: [0.6233251] actual score: [0.]
# Model Score: [0.9919647] actual score: [1.]
# Model Score: [0.9392676] actual score: [1.]
# Model Score: [0.20188166] actual score: [1.]
# Model Score: [0.9778544] actual score: [1.]
# Model Score: [0.9016502] actual score: [1.]
# Model Score: [0.02148074] actual score: [0.]
# Model Score: [0.83499086] actual score: [1.]
# Model Score: [0.02034133] actual score: [0.]
# Model Score: [0.00185333] actual score: [0.]
# Model Score: [0.98376495] actual score: [1.]
# Model Score: [0.22951864] actual score: [0.]
# Model Score: [0.6823017] actual score: [1.]
# Model Score: [0.97541827] actual score: [1.]
# Model Score: [0.49363214] actual score: [1.]
# Model Score: [0.04334311] actual score: [0.]
# Model Score: [0.47970638] actual score: [0.]
# Model Score: [0.98257613] actual score: [1.]
# Model Score: [0.02250874] actual score: [0.]
# Model Score: [0.9999852] actual score: [1.]
# Model Score: [0.07752304] actual score: [0.]
# Model Score: [0.8214795] actual score: [1.]
# Model Score: [0.92793226] actual score: [1.]
# Model Score: [0.004406] actual score: [0.]
# Model Score: [0.9905211] actual score: [1.]
# Model Score: [0.00114235] actual score: [0.]
# Model Score: [0.14605741] actual score: [0.]
# Model Score: [0.9807021] actual score: [1.]
# Model Score: [0.0005269] actual score: [0.]
# Model Score: [0.7601799] actual score: [1.]
# Model Score: [0.9986798] actual score: [1.]
# Model Score: [0.9532055] actual score: [1.]
# Model Score: [0.10851445] actual score: [1.]
# Model Score: [0.72977644] actual score: [1.]
# Model Score: [0.46048075] actual score: [1.]
# Model Score: [0.58500385] actual score: [1.]
# Model Score: [0.69419724] actual score: [0.]
# Model Score: [0.90470505] actual score: [1.]
# Model Score: [0.00076174] actual score: [0.]
# Model Score: [0.0137823] actual score: [0.]
# Model Score: [0.9545125] actual score: [1.]
# Model Score: [0.8875051] actual score: [1.]
# Model Score: [0.22615159] actual score: [0.]
# Model Score: [0.6699626] actual score: [0.]
# Model Score: [0.98646647] actual score: [1.]
# Model Score: [0.8660071] actual score: [0.]
# Model Score: [0.246716] actual score: [0.]
# Model Score: [0.28469014] actual score: [0.]
# Model Score: [0.03546138] actual score: [0.]
# Model Score: [0.08932353] actual score: [0.]
# Model Score: [0.46149674] actual score: [1.]
# Model Score: [0.8117919] actual score: [1.]
# Model Score: [0.24171537] actual score: [0.]
# Model Score: [0.00587549] actual score: [0.]
# Model Score: [0.5642003] actual score: [1.]
# Model Score: [0.02139221] actual score: [0.]
# Model Score: [0.9889558] actual score: [1.]
# Model Score: [0.00261038] actual score: [0.]
# Model Score: [0.99636084] actual score: [1.]
# Model Score: [0.7787517] actual score: [1.]
# Model Score: [0.9999689] actual score: [1.]
# Model Score: [0.95766497] actual score: [1.]
# Model Score: [0.5877196] actual score: [0.]
# Model Score: [0.00183939] actual score: [0.]
# Model Score: [0.476298] actual score: [0.]
# Model Score: [0.9864994] actual score: [1.]
# Model Score: [0.79907274] actual score: [1.]
# Model Score: [0.42377794] actual score: [1.]
# Model Score: [0.10163993] actual score: [0.]
# Model Score: [0.03062393] actual score: [0.]
# Model Score: [0.65732974] actual score: [1.]
# Model Score: [0.86941797] actual score: [1.]
# Model Score: [0.7548392] actual score: [1.]
# Model Score: [0.03869904] actual score: [0.]
# Model Score: [0.9761583] actual score: [1.]
# Model Score: [0.78289974] actual score: [1.]
# Model Score: [0.53539044] actual score: [0.]
# Model Score: [0.50002223] actual score: [1.]
# Model Score: [0.8790078] actual score: [1.]
# Model Score: [0.9684723] actual score: [1.]
# Model Score: [0.7310796] actual score: [1.]
# Model Score: [0.10729558] actual score: [0.]
# Model Score: [0.1236041] actual score: [0.]
# Model Score: [0.5068519] actual score: [1.]
# Model Score: [0.8143582] actual score: [1.]
# Model Score: [0.795145] actual score: [0.]
# Model Score: [0.90072095] actual score: [1.]
# Model Score: [0.40601847] actual score: [1.]
# Model Score: [0.24243887] actual score: [0.]
# Model Score: [0.00015335] actual score: [0.]
# Model Score: [6.7226094e-05] actual score: [0.]
# Model Score: [0.9718034] actual score: [1.]
# Model Score: [0.9806904] actual score: [1.]
# Model Score: [0.93288386] actual score: [1.]
# Model Score: [0.04162875] actual score: [0.]
# Model Score: [0.6547782] actual score: [1.]
# Model Score: [0.9905782] actual score: [1.]
# Model Score: [0.9726635] actual score: [1.]
# Model Score: [0.9886884] actual score: [1.]
# Model Score: [0.97726166] actual score: [1.]
# Model Score: [0.97231424] actual score: [1.]
# Model Score: [0.815041] actual score: [1.]
# Model Score: [0.38419452] actual score: [1.]
# Model Score: [0.14780064] actual score: [0.]
# Model Score: [0.9986406] actual score: [1.]
# Model Score: [0.9780938] actual score: [1.]
# Model Score: [0.36111453] actual score: [0.]
# Model Score: [0.47735983] actual score: [1.]
# Model Score: [0.9966535] actual score: [1.]
# Model Score: [0.33424678] actual score: [0.]
# Model Score: [0.9230898] actual score: [1.]
# Model Score: [0.10588155] actual score: [0.]
# Model Score: [0.12142924] actual score: [0.]
# Model Score: [2.4363228e-06] actual score: [0.]
# Model Score: [0.9121958] actual score: [1.]
# Model Score: [0.8541269] actual score: [1.]
# Model Score: [0.9380855] actual score: [1.]
# Model Score: [0.897041] actual score: [1.]
# Model Score: [0.05208014] actual score: [0.]
# Model Score: [0.01957392] actual score: [0.]
# Model Score: [0.5307287] actual score: [0.]
# Model Score: [0.0497911] actual score: [0.]
# Model Score: [0.16626413] actual score: [0.]
# Model Score: [0.968695] actual score: [0.]
# Model Score: [0.7847523] actual score: [1.]
# Model Score: [0.33123115] actual score: [1.]
# Model Score: [0.5016946] actual score: [0.]
# Model Score: [0.01865634] actual score: [0.]
# Model Score: [5.5374065e-05] actual score: [0.]
# Model Score: [0.00878494] actual score: [0.]
# Model Score: [0.03918828] actual score: [0.]
# Model Score: [0.12290652] actual score: [0.]
# Model Score: [0.4276739] actual score: [1.]
# Model Score: [0.82906324] actual score: [1.]
# Model Score: [0.97653574] actual score: [1.]
# Model Score: [0.99329937] actual score: [1.]
# Model Score: [0.9817571] actual score: [1.]
# Model Score: [0.709635] actual score: [1.]
# Model Score: [0.9881777] actual score: [1.]
# Model Score: [0.38766655] actual score: [0.]
